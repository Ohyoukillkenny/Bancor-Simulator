# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
fw = open('Transaction-Record.txt','w')
# Out:
# /Users/konglingkun/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# here, coin number is saved as float (complying with code from github, while contradicts white paper)
class Smartcoin(object):
	def __init__(self, name='kennycoin', reservetokenName='aCoin', initCRR=0.5, initPrice=1, initIssueNum=100):
		self._Name = name
		self._ReservetokenName = reservetokenName
		self._CRR = float(initCRR)
		self._Price = float(initPrice)
		self._Supply = float(initIssueNum)
		self._ReserveBalance = float(initCRR * initIssueNum)
		self._budget = float(0)     

	def printInfo(self):
		print '---------'
		print 'NAME:', self._Name, '| RESERVE NAME:', self._ReservetokenName, 'CRR:', self._CRR
		print 'PRICE:',self._Price
		print 'SUPPLY:', self._Supply, '| RESERVE BALANCE:', self._ReserveBalance
		print 'BUDGET:', self._budget

	def saveInfo(self, fw):
		fw.write('---------\n')
		fw.write('NAME: '+str(self._Name)+' | RESERVE NAME: '+str(self._ReservetokenName) + ' | CRR: '+str(self._CRR)+'\n')
		fw.write('PRICE: '+str(self._Price))
		fw.write('SUPPLY: '+str(self._Supply)+' | RESERVE BALANCE: '+str(self._ReserveBalance)+'\n')
        
	def updatePrice(self, reserveBalance, supply, CRR):
		newPrice = reserveBalance/(supply * CRR)
		return newPrice
    
	def setCRR(self, newCRR = 0.5):
		oldCRR = self._CRR
		self._CRR = newCRR
		print 'CRR', oldCRR, '->', newCRR

	def getPrice(self):
		return self._Price

	def purchasing(self, convertIntoNum=0):
		# ETH be convert into BNT
		issuedtokenNum = self._Supply * (((self._ReserveBalance + convertIntoNum)/self._ReserveBalance)**(self._CRR) - 1)
		self._Supply = self._Supply + issuedtokenNum
		self._ReserveBalance = self._ReserveBalance + convertIntoNum
		oldPrice = self._Price
		self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
		increaseRatio = (self._Price - oldPrice)/oldPrice
# 		print '&&&&&&&&&&'
# 		print round(convertIntoNum,2), self._ReservetokenName+" be converted into as", round(issuedtokenNum,2), self._Name
# 		print "Current price of "+self._Name+" is", self._Price, "with", round(increaseRatio*100,4), "% increasing."
		self._budget = self._budget + self._Price*self._Supply - oldPrice*(self._Supply - issuedtokenNum)
		return issuedtokenNum

	def destroying(self, convertOutNum=0):
		# BNT be converted out to ETH
		destroyedtokenNum = convertOutNum      
		reserveReceivedNum = self._ReserveBalance*(1 - ((self._Supply - convertOutNum)/self._Supply)**(1/self._CRR))
		self._Supply = self._Supply - destroyedtokenNum
		self._ReserveBalance = self._ReserveBalance - reserveReceivedNum
		oldPrice = self._Price
		self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
		decreaseRatio = (oldPrice-self._Price)/oldPrice
# 		print '**********'
# 		print round(convertOutNum,2), self._Name+" be converted out as", round(reserveReceivedNum,2), self._ReservetokenName
# 		print "Current price of "+self._Name+" is", self._Price, "with", round(decreaseRatio*100,4), "% decreasing."
		self._budget = self._budget + self._Price*self._Supply - oldPrice*(self._Supply + destroyedtokenNum)
		return reserveReceivedNum

# %%
class Customers(object):
    def __init__(self, smartToken, ownedSmartTokens = float(0), reserveValue = float(500),expectedPrice = 0):
        # _smartToken is the token customers want to buy -- SmartToken()
        self._smartToken = smartToken
        # _ownedSmartToken refers to smart token's number customers have
        self._ownedSmartToken = float(ownedSmartTokens)
        # _smartValue is the value of ownedSmartTokens -- currentPrice * owned#
        self._smartValue = smartToken.getPrice() * ownedSmartTokens
        self._reserveValue = float(reserveValue)
        # _ownedvalue = _reserveValue + _smartValue
        self._ownedvalue = float(reserveValue)
        # gain or lose money comparing to the original state
        self._budget = float(0)
        # expectedPrice denotes the how much money customers are willing to finish the transaction 
        self._expectedPrice = expectedPrice
        
    def printinfo(self):
        # since new reserve will be converted into or out the kenny coin, the budget could change
        # when print info, update the budget
        oldownedValue = self._ownedvalue
        self._ownedvalue = self._smartToken._Price * self._ownedSmartToken + self._reserveValue
        self._budget = self._budget + self._ownedvalue - oldownedValue
        print '------'
        print 'smartToken Name:', self._smartToken._Name
        print 'ownedvalue:', self._ownedvalue, 'budget:', self._budget
        
    def getReserveValue(self):
        return self._reserveValue
    def getownedSmartToken(self):
        return self._ownedSmartToken
    
    # add customer's reserve amount
    def addReserve(self, addAmount):
        self._reserveValue = self._reserveValue + addAmount
        self._ownedvalue = self._smartToken._Price * self._ownedSmartToken + self._reserveValue
    
    # returned expected Price
    def getExpectedPrice(self):
        return self._expectedPrice
        
    # change the expected price
    def changeExpectedPrice(self, newExpectedPrice):
        self._expectedPrice = newExpectedPrice
        
    def purchase(self, reserveTokenNumber):
        oldPrice = self._smartToken._Price
        if reserveTokenNumber > self._reserveValue:
            print 'Invalid Operation in Purchase'
            return
        # smartToken.purchasing means being converted
        issuedSmartToken = self._smartToken.purchasing(reserveTokenNumber)
        newPrice = self._smartToken._Price      
        self._ownedSmartToken = self._ownedSmartToken + issuedSmartToken
        self._smartValue = self._ownedSmartToken * newPrice
        self._reserveValue = self._reserveValue - reserveTokenNumber
        # in fact, in this case ownedValue and budget actually does not change at all
        oldownedValue = self._ownedvalue
        self._ownedvalue = self._reserveValue + self._smartValue
        self._budget = self._budget + self._ownedvalue - oldownedValue
        
        
    def destroy(self, smartTokenNumber):
        oldPrice = self._smartToken._Price
        if self._ownedSmartToken < smartTokenNumber:
            print 'Invalid Operation in Destroy'
            return
        self._ownedSmartToken = self._ownedSmartToken - smartTokenNumber
        # smartToken.purchasing means being purchased
        ReceivedToken = self._smartToken.destroying(smartTokenNumber)
        newPrice = self._smartToken._Price
        self._smartValue = self._ownedSmartToken*newPrice
        self._reserveValue = self._reserveValue + ReceivedToken
        # In fact, in this case ownedValue actually does not change at all
        oldownedValue = self._ownedvalue
        self._ownedvalue = self._reserveValue + self._smartValue
        self._budget = self._budget + self._ownedvalue - oldownedValue

# %%
# issue a new smart token
initIssue = 300000000
CRR = 0.2
initTransaction = initIssue * (1-CRR)
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=initIssue)
'''
init properties: 
We have #TimeRound round,
In each time round, #custNum customers come in, 
   with original reserve: #custOriginalReserve
   with original smarttokens: #custOriginalSmartTokens
'''
TimeRound = 1000
custNum = 1000
sigma = 0.1
custOriginalReserve_mu = 100
custOriginalSmartTokens_mu = 100
custOriginalReserve = np.random.normal(custOriginalReserve_mu, 0.5, custNum) # 0.5 is sigma
custOriginalSmartTokens = np.random.normal(custOriginalSmartTokens_mu, 0.5, custNum) # 0.5 is sigma
'''
prevent the init money exhausts the balance, 
here we already set initIssue SmartToken to 300000,
which actually is hard to exhaust,
also, we should consider the situation that the init issued smarttokens is comparably small,
      or the init smarttokens is held in customers in a large amount
'''
if TimeRound * sum(custOriginalSmartTokens) > initTransaction:
    print sum(TimeRound * custOriginalSmartTokens)
    print 'WARNING, too many init smart tokens from customers'
    if TimeRound * sum(custOriginalSmartTokens) > initIssue:
        print 'ERROR!!, too many init smart tokens'
        turndown = 1 + 'klk'

# PriceTracker records the change of the price
PriceTracker = []
# failedTracker records the transaction failure
failedBuy_rateTracker = []
failedSell_rateTracker = []
failed_rateTracker = []

j=0
while j < TimeRound:
    # failed num denotes the number of transactions failed in each time round
    failed_num = 0
    failed_buyNum = 0
    failed_sellNum = 0
    buyNum = 0
    sellNum = 0
    
    i=0
    custlist = []
    CurrentPrice = KennyCoin.getPrice()
    OldPrice = CurrentPrice
    # set the expectation of initPrice (first we fix it), Should it change with time?
    initPrice = CurrentPrice
    ''' 
    First, we initialize the customers who come in at #j TimeRound.
    We assume in each TimeRound, #custNum customers come in, whose number is gaussian distributed with custExpectedPrice
    We assume when price is mu -- initPrice, customers' number is the largest
    Since we get customers #custNum involved, the normal should be sampled by custNum.
    '''
    mu = initPrice
#     np.random.seed(0)
    custExpectedPrice = np.random.normal(mu, sigma, custNum)
    while i < custNum:
        Joe = Customers(smartToken = KennyCoin, ownedSmartTokens = custOriginalSmartTokens[i], reserveValue = custOriginalReserve[i], expectedPrice = custExpectedPrice[i])
        custlist.append(Joe)
        i = i + 1
    for Joe in custlist:
        if Joe.getExpectedPrice() > OldPrice:
            buyNum = buyNum + 1
            if Joe.getExpectedPrice() >= KennyCoin.getPrice():
                # Joe purchases successfully
                custReserve = Joe.getReserveValue()
                randomBuy = random.uniform(0,custReserve)
                Joe.purchase(reserveTokenNumber = randomBuy)
            else:
                # failed in buying
                failed_buyNum = failed_buyNum + 1
        elif Joe.getExpectedPrice() < OldPrice:
            sellNum = sellNum + 1
            if Joe.getExpectedPrice() <= KennyCoin.getPrice():
                # Joe sells successfully
                custSmartToken_Num = Joe.getownedSmartToken()
                randomSell = random.uniform(0,custSmartToken_Num)
                Joe.destroy(smartTokenNumber = randomSell)
            else:
                # failed in selling
                failed_sellNum = failed_sellNum + 1
        else:
            '''
            This case means:
              Joe.getExpectedPrice() == OldPrice,
            Then we need to throw a coin to determine whether to buy or sell,
              half - half possibility
            '''
            seed = random.randint(0, 100)
            if seed < 50:
                buyNum = buyNum + 1
                if Joe.getExpectedPrice() >= KennyCoin.getPrice():
                    # Joe purchases successfully
                    custReserve = Joe.getReserveValue()
                    randomBuy = random.uniform(0,custReserve)
                    Joe.purchase(reserveTokenNumber = randomBuy)
                else:
                    # failed in buying
                    failed_buyNum = failed_buyNum + 1
            else:
                sellNum = sellNum + 1
                if Joe.getExpectedPrice() <= KennyCoin.getPrice():
                    # Joe sells successfully
                    custSmartToken_Num = Joe.getownedSmartToken()
                    randomSell = random.uniform(0,custSmartToken_Num)
                    Joe.destroy(smartTokenNumber = randomSell)
                else:
                    # failed in selling
                    failed_sellNum = failed_sellNum + 1
        CurrentPrice = KennyCoin.getPrice()
        PriceTracker.append((CurrentPrice,j))
    print 'The',j,'round, BuyNum:',buyNum,'SellNum:',sellNum
    failed_num = failed_buyNum + failed_sellNum
    failedBuy_rateTracker.append((float(failed_buyNum) / buyNum , j))
    failedSell_rateTracker.append((float(failed_sellNum) / sellNum , j))
    failed_rateTracker.append((float(failed_num) / (buyNum+sellNum) , j))
    fw.write('After Round '+ str(j) + '\n')
    KennyCoin.saveInfo(fw)
    j = j + 1
# Out:
# The 0 round, BuyNum: 488 SellNum: 512
# The 1 round, BuyNum: 477 SellNum: 523
# The 2 round, BuyNum: 503 SellNum: 497
# The 3 round, BuyNum: 484 SellNum: 516
# The 4 round, BuyNum: 526 SellNum: 474
# The 5 round, BuyNum: 506 SellNum: 494
# The 6 round, BuyNum: 511 SellNum: 489
# The 7 round, BuyNum: 505 SellNum: 495
# The 8 round, BuyNum: 503 SellNum: 497
# The 9 round, BuyNum: 484 SellNum: 516
# The 10 round, BuyNum: 500 SellNum: 500
# The 11 round, BuyNum: 506 SellNum: 494
# The 12 round, BuyNum: 516 SellNum: 484
# The 13 round, BuyNum: 483 SellNum: 517
# The 14 round, BuyNum: 495 SellNum: 505
# The 15 round, BuyNum: 487 SellNum: 513
# The 16 round, BuyNum: 473 SellNum: 527
# The 17 round, BuyNum: 518 SellNum: 482
# The 18 round, BuyNum: 484 SellNum: 516
# The 19 round, BuyNum: 525 SellNum: 475
# The 20 round, BuyNum: 509 SellNum: 491
# The 21 round, BuyNum: 512 SellNum: 488
# The 22 round, BuyNum: 468 SellNum: 532
# The 23 round, BuyNum: 498 SellNum: 502
# The 24 round, BuyNum: 494 SellNum: 506
# The 25 round, BuyNum: 509 SellNum: 491
# The 26 round, BuyNum: 485 SellNum: 515
# The 27 round, BuyNum: 485 SellNum: 515
# The 28 round, BuyNum: 505 SellNum: 495
# The 29 round, BuyNum: 483 SellNum: 517
# The 30 round, BuyNum: 488 SellNum: 512
# The 31 round, BuyNum: 502 SellNum: 498
# The 32 round, BuyNum: 495 SellNum: 505
# The 33 round, BuyNum: 480 SellNum: 520
# The 34 round, BuyNum: 484 SellNum: 516
# The 35 round, BuyNum: 502 SellNum: 498
# The 36 round, BuyNum: 503 SellNum: 497
# The 37 round, BuyNum: 499 SellNum: 501
# The 38 round, BuyNum: 499 SellNum: 501
# The 39 round, BuyNum: 523 SellNum: 477
# The 40 round, BuyNum: 503 SellNum: 497
# The 41 round, BuyNum: 494 SellNum: 506
# The 42 round, BuyNum: 493 SellNum: 507
# The 43 round, BuyNum: 485 SellNum: 515
# The 44 round, BuyNum: 489 SellNum: 511
# The 45 round, BuyNum: 499 SellNum: 501
# The 46 round, BuyNum: 499 SellNum: 501
# The 47 round, BuyNum: 508 SellNum: 492
# The 48 round, BuyNum: 504 SellNum: 496
# The 49 round, BuyNum: 469 SellNum: 531
# The 50 round, BuyNum: 511 SellNum: 489
# The 51 round, BuyNum: 501 SellNum: 499
# The 52 round, BuyNum: 519 SellNum: 481
# The 53 round, BuyNum: 496 SellNum: 504
# The 54 round, BuyNum: 489 SellNum: 511
# The 55 round, BuyNum: 490 SellNum: 510
# The 56 round, BuyNum: 491 SellNum: 509
# The 57 round, BuyNum: 480 SellNum: 520
# The 58 round, BuyNum: 502 SellNum: 498
# The 59 round, BuyNum: 479 SellNum: 521
# The 60 round, BuyNum: 537 SellNum: 463
# The 61 round, BuyNum: 472 SellNum: 528
# The 62 round, BuyNum: 509 SellNum: 491
# The 63 round, BuyNum: 504 SellNum: 496
# The 64 round, BuyNum: 488 SellNum: 512
# The 65 round, BuyNum: 485 SellNum: 515
# The 66 round, BuyNum: 481 SellNum: 519
# The 67 round, BuyNum: 537 SellNum: 463
# The 68 round, BuyNum: 474 SellNum: 526
# The 69 round, BuyNum: 491 SellNum: 509
# The 70 round, BuyNum: 508 SellNum: 492
# The 71 round, BuyNum: 494 SellNum: 506
# The 72 round, BuyNum: 486 SellNum: 514
# The 73 round, BuyNum: 545 SellNum: 455
# The 74 round, BuyNum: 510 SellNum: 490
# The 75 round, BuyNum: 487 SellNum: 513
# The 76 round, BuyNum: 513 SellNum: 487
# The 77 round, BuyNum: 498 SellNum: 502
# The 78 round, BuyNum: 477 SellNum: 523
# The 79 round, BuyNum: 536 SellNum: 464
# The 80 round, BuyNum: 519 SellNum: 481
# The 81 round, BuyNum: 501 SellNum: 499
# The 82 round, BuyNum: 513 SellNum: 487
# The 83 round, BuyNum: 508 SellNum: 492
# The 84 round, BuyNum: 493 SellNum: 507
# The 85 round, BuyNum: 497 SellNum: 503
# The 86 round, BuyNum: 514 SellNum: 486
# The 87 round, BuyNum: 549 SellNum: 451
# The 88 round, BuyNum: 479 SellNum: 521
# The 89 round, BuyNum: 506 SellNum: 494
# The 90 round, BuyNum: 506 SellNum: 494
# The 91 round, BuyNum: 516 SellNum: 484
# The 92 round, BuyNum: 515 SellNum: 485
# The 93 round, BuyNum: 494 SellNum: 506
# The 94 round, BuyNum: 508 SellNum: 492
# The 95 round, BuyNum: 488 SellNum: 512
# The 96 round, BuyNum: 519 SellNum: 481
# The 97 round, BuyNum: 512 SellNum: 488
# The 98 round, BuyNum: 506 SellNum: 494
# The 99 round, BuyNum: 503 SellNum: 497
# The 100 round, BuyNum: 500 SellNum: 500
# The 101 round, BuyNum: 503 SellNum: 497
# The 102 round, BuyNum: 488 SellNum: 512
# The 103 round, BuyNum: 494 SellNum: 506
# The 104 round, BuyNum: 491 SellNum: 509
# The 105 round, BuyNum: 515 SellNum: 485
# The 106 round, BuyNum: 518 SellNum: 482
# The 107 round, BuyNum: 501 SellNum: 499
# The 108 round, BuyNum: 489 SellNum: 511
# The 109 round, BuyNum: 495 SellNum: 505
# The 110 round, BuyNum: 511 SellNum: 489
# The 111 round, BuyNum: 521 SellNum: 479
# The 112 round, BuyNum: 491 SellNum: 509
# The 113 round, BuyNum: 480 SellNum: 520
# The 114 round, BuyNum: 480 SellNum: 520
# The 115 round, BuyNum: 509 SellNum: 491
# The 116 round, BuyNum: 475 SellNum: 525
# The 117 round, BuyNum: 502 SellNum: 498
# The 118 round, BuyNum: 506 SellNum: 494
# The 119 round, BuyNum: 478 SellNum: 522
# The 120 round, BuyNum: 489 SellNum: 511
# The 121 round, BuyNum: 511 SellNum: 489
# The 122 round, BuyNum: 493 SellNum: 507
# The 123 round, BuyNum: 496 SellNum: 504
# The 124 round, BuyNum: 510 SellNum: 490
# The 125 round, BuyNum: 501 SellNum: 499
# The 126 round, BuyNum: 509 SellNum: 491
# The 127 round, BuyNum: 512 SellNum: 488
# The 128 round, BuyNum: 510 SellNum: 490
# The 129 round, BuyNum: 524 SellNum: 476
# The 130 round, BuyNum: 472 SellNum: 528
# The 131 round, BuyNum: 517 SellNum: 483
# The 132 round, BuyNum: 497 SellNum: 503
# The 133 round, BuyNum: 524 SellNum: 476
# The 134 round, BuyNum: 514 SellNum: 486
# The 135 round, BuyNum: 482 SellNum: 518
# The 136 round, BuyNum: 498 SellNum: 502
# The 137 round, BuyNum: 474 SellNum: 526
# The 138 round, BuyNum: 514 SellNum: 486
# The 139 round, BuyNum: 491 SellNum: 509
# The 140 round, BuyNum: 509 SellNum: 491
# The 141 round, BuyNum: 501 SellNum: 499
# The 142 round, BuyNum: 496 SellNum: 504
# The 143 round, BuyNum: 486 SellNum: 514
# The 144 round, BuyNum: 507 SellNum: 493
# The 145 round, BuyNum: 507 SellNum: 493
# The 146 round, BuyNum: 521 SellNum: 479
# The 147 round, BuyNum: 469 SellNum: 531
# The 148 round, BuyNum: 495 SellNum: 505
# The 149 round, BuyNum: 483 SellNum: 517
# The 150 round, BuyNum: 505 SellNum: 495
# The 151 round, BuyNum: 497 SellNum: 503
# The 152 round, BuyNum: 507 SellNum: 493
# The 153 round, BuyNum: 491 SellNum: 509
# The 154 round, BuyNum: 520 SellNum: 480
# The 155 round, BuyNum: 499 SellNum: 501
# The 156 round, BuyNum: 507 SellNum: 493
# The 157 round, BuyNum: 491 SellNum: 509
# The 158 round, BuyNum: 497 SellNum: 503
# The 159 round, BuyNum: 487 SellNum: 513
# The 160 round, BuyNum: 495 SellNum: 505
# The 161 round, BuyNum: 511 SellNum: 489
# The 162 round, BuyNum: 481 SellNum: 519
# The 163 round, BuyNum: 492 SellNum: 508
# The 164 round, BuyNum: 493 SellNum: 507
# The 165 round, BuyNum: 502 SellNum: 498
# The 166 round, BuyNum: 480 SellNum: 520
# The 167 round, BuyNum: 494 SellNum: 506
# The 168 round, BuyNum: 498 SellNum: 502
# The 169 round, BuyNum: 521 SellNum: 479
# The 170 round, BuyNum: 496 SellNum: 504
# The 171 round, BuyNum: 511 SellNum: 489
# The 172 round, BuyNum: 498 SellNum: 502
# The 173 round, BuyNum: 506 SellNum: 494
# The 174 round, BuyNum: 491 SellNum: 509
# The 175 round, BuyNum: 540 SellNum: 460
# The 176 round, BuyNum: 478 SellNum: 522
# The 177 round, BuyNum: 503 SellNum: 497
# The 178 round, BuyNum: 505 SellNum: 495
# The 179 round, BuyNum: 489 SellNum: 511
# The 180 round, BuyNum: 509 SellNum: 491
# The 181 round, BuyNum: 483 SellNum: 517
# The 182 round, BuyNum: 516 SellNum: 484
# The 183 round, BuyNum: 501 SellNum: 499
# The 184 round, BuyNum: 498 SellNum: 502
# The 185 round, BuyNum: 517 SellNum: 483
# The 186 round, BuyNum: 514 SellNum: 486
# The 187 round, BuyNum: 479 SellNum: 521
# The 188 round, BuyNum: 498 SellNum: 502
# The 189 round, BuyNum: 476 SellNum: 524
# The 190 round, BuyNum: 500 SellNum: 500
# The 191 round, BuyNum: 515 SellNum: 485
# The 192 round, BuyNum: 529 SellNum: 471
# The 193 round, BuyNum: 492 SellNum: 508
# The 194 round, BuyNum: 493 SellNum: 507
# The 195 round, BuyNum: 482 SellNum: 518
# The 196 round, BuyNum: 522 SellNum: 478
# The 197 round, BuyNum: 499 SellNum: 501
# The 198 round, BuyNum: 496 SellNum: 504
# The 199 round, BuyNum: 513 SellNum: 487
# The 200 round, BuyNum: 489 SellNum: 511
# The 201 round, BuyNum: 512 SellNum: 488
# The 202 round, BuyNum: 517 SellNum: 483
# The 203 round, BuyNum: 497 SellNum: 503
# The 204 round, BuyNum: 492 SellNum: 508
# The 205 round, BuyNum: 501 SellNum: 499
# The 206 round, BuyNum: 501 SellNum: 499
# The 207 round, BuyNum: 502 SellNum: 498
# The 208 round, BuyNum: 497 SellNum: 503
# The 209 round, BuyNum: 524 SellNum: 476
# The 210 round, BuyNum: 517 SellNum: 483
# The 211 round, BuyNum: 515 SellNum: 485
# The 212 round, BuyNum: 511 SellNum: 489
# The 213 round, BuyNum: 488 SellNum: 512
# The 214 round, BuyNum: 517 SellNum: 483
# The 215 round, BuyNum: 512 SellNum: 488
# The 216 round, BuyNum: 483 SellNum: 517
# The 217 round, BuyNum: 523 SellNum: 477
# The 218 round, BuyNum: 477 SellNum: 523
# The 219 round, BuyNum: 512 SellNum: 488
# The 220 round, BuyNum: 497 SellNum: 503
# The 221 round, BuyNum: 506 SellNum: 494
# The 222 round, BuyNum: 492 SellNum: 508
# The 223 round, BuyNum: 520 SellNum: 480
# The 224 round, BuyNum: 500 SellNum: 500
# The 225 round, BuyNum: 492 SellNum: 508
# The 226 round, BuyNum: 512 SellNum: 488
# The 227 round, BuyNum: 527 SellNum: 473
# The 228 round, BuyNum: 476 SellNum: 524
# The 229 round, BuyNum: 503 SellNum: 497
# The 230 round, BuyNum: 491 SellNum: 509
# The 231 round, BuyNum: 500 SellNum: 500
# The 232 round, BuyNum: 515 SellNum: 485
# The 233 round, BuyNum: 520 SellNum: 480
# The 234 round, BuyNum: 494 SellNum: 506
# The 235 round, BuyNum: 483 SellNum: 517
# The 236 round, BuyNum: 494 SellNum: 506
# The 237 round, BuyNum: 479 SellNum: 521
# The 238 round, BuyNum: 492 SellNum: 508
# The 239 round, BuyNum: 472 SellNum: 528
# The 240 round, BuyNum: 503 SellNum: 497
# The 241 round, BuyNum: 519 SellNum: 481
# The 242 round, BuyNum: 527 SellNum: 473
# The 243 round, BuyNum: 493 SellNum: 507
# The 244 round, BuyNum: 529 SellNum: 471
# The 245 round, BuyNum: 520 SellNum: 480
# The 246 round, BuyNum: 503 SellNum: 497
# The 247 round, BuyNum: 494 SellNum: 506
# The 248 round, BuyNum: 497 SellNum: 503
# The 249 round, BuyNum: 526 SellNum: 474
# The 250 round, BuyNum: 493 SellNum: 507
# The 251 round, BuyNum: 491 SellNum: 509
# The 252 round, BuyNum: 515 SellNum: 485
# The 253 round, BuyNum: 533 SellNum: 467
# The 254 round, BuyNum: 482 SellNum: 518
# The 255 round, BuyNum: 506 SellNum: 494
# The 256 round, BuyNum: 522 SellNum: 478
# The 257 round, BuyNum: 500 SellNum: 500
# The 258 round, BuyNum: 525 SellNum: 475
# The 259 round, BuyNum: 511 SellNum: 489
# The 260 round, BuyNum: 506 SellNum: 494
# The 261 round, BuyNum: 521 SellNum: 479
# The 262 round, BuyNum: 507 SellNum: 493
# The 263 round, BuyNum: 489 SellNum: 511
# The 264 round, BuyNum: 531 SellNum: 469
# The 265 round, BuyNum: 509 SellNum: 491
# The 266 round, BuyNum: 484 SellNum: 516
# The 267 round, BuyNum: 519 SellNum: 481
# The 268 round, BuyNum: 496 SellNum: 504
# The 269 round, BuyNum: 507 SellNum: 493
# The 270 round, BuyNum: 507 SellNum: 493
# The 271 round, BuyNum: 493 SellNum: 507
# The 272 round, BuyNum: 499 SellNum: 501
# The 273 round, BuyNum: 499 SellNum: 501
# The 274 round, BuyNum: 486 SellNum: 514
# The 275 round, BuyNum: 492 SellNum: 508
# The 276 round, BuyNum: 488 SellNum: 512
# The 277 round, BuyNum: 516 SellNum: 484
# The 278 round, BuyNum: 496 SellNum: 504
# The 279 round, BuyNum: 528 SellNum: 472
# The 280 round, BuyNum: 505 SellNum: 495
# The 281 round, BuyNum: 518 SellNum: 482
# The 282 round, BuyNum: 508 SellNum: 492
# The 283 round, BuyNum: 501 SellNum: 499
# The 284 round, BuyNum: 517 SellNum: 483
# The 285 round, BuyNum: 523 SellNum: 477
# The 286 round, BuyNum: 488 SellNum: 512
# The 287 round, BuyNum: 496 SellNum: 504
# The 288 round, BuyNum: 524 SellNum: 476
# The 289 round, BuyNum: 504 SellNum: 496
# The 290 round, BuyNum: 496 SellNum: 504
# The 291 round, BuyNum: 473 SellNum: 527
# The 292 round, BuyNum: 502 SellNum: 498
# The 293 round, BuyNum: 504 SellNum: 496
# The 294 round, BuyNum: 516 SellNum: 484
# The 295 round, BuyNum: 495 SellNum: 505
# The 296 round, BuyNum: 495 SellNum: 505
# The 297 round, BuyNum: 496 SellNum: 504
# The 298 round, BuyNum: 495 SellNum: 505
# The 299 round, BuyNum: 520 SellNum: 480
# The 300 round, BuyNum: 510 SellNum: 490
# The 301 round, BuyNum: 478 SellNum: 522
# The 302 round, BuyNum: 505 SellNum: 495
# The 303 round, BuyNum: 498 SellNum: 502
# The 304 round, BuyNum: 516 SellNum: 484
# The 305 round, BuyNum: 509 SellNum: 491
# The 306 round, BuyNum: 495 SellNum: 505
# The 307 round, BuyNum: 479 SellNum: 521
# The 308 round, BuyNum: 488 SellNum: 512
# The 309 round, BuyNum: 485 SellNum: 515
# The 310 round, BuyNum: 521 SellNum: 479
# The 311 round, BuyNum: 492 SellNum: 508
# The 312 round, BuyNum: 486 SellNum: 514
# The 313 round, BuyNum: 510 SellNum: 490
# The 314 round, BuyNum: 505 SellNum: 495
# The 315 round, BuyNum: 487 SellNum: 513
# The 316 round, BuyNum: 502 SellNum: 498
# The 317 round, BuyNum: 498 SellNum: 502
# The 318 round, BuyNum: 507 SellNum: 493
# The 319 round, BuyNum: 510 SellNum: 490
# The 320 round, BuyNum: 469 SellNum: 531
# The 321 round, BuyNum: 502 SellNum: 498
# The 322 round, BuyNum: 479 SellNum: 521
# The 323 round, BuyNum: 499 SellNum: 501
# The 324 round, BuyNum: 484 SellNum: 516
# The 325 round, BuyNum: 518 SellNum: 482
# The 326 round, BuyNum: 500 SellNum: 500
# The 327 round, BuyNum: 516 SellNum: 484
# The 328 round, BuyNum: 491 SellNum: 509
# The 329 round, BuyNum: 500 SellNum: 500
# The 330 round, BuyNum: 491 SellNum: 509
# The 331 round, BuyNum: 496 SellNum: 504
# The 332 round, BuyNum: 504 SellNum: 496
# The 333 round, BuyNum: 485 SellNum: 515
# The 334 round, BuyNum: 476 SellNum: 524
# The 335 round, BuyNum: 528 SellNum: 472
# The 336 round, BuyNum: 515 SellNum: 485
# The 337 round, BuyNum: 500 SellNum: 500
# The 338 round, BuyNum: 488 SellNum: 512
# The 339 round, BuyNum: 493 SellNum: 507
# The 340 round, BuyNum: 500 SellNum: 500
# The 341 round, BuyNum: 486 SellNum: 514
# The 342 round, BuyNum: 495 SellNum: 505
# The 343 round, BuyNum: 515 SellNum: 485
# The 344 round, BuyNum: 496 SellNum: 504
# The 345 round, BuyNum: 506 SellNum: 494
# The 346 round, BuyNum: 514 SellNum: 486
# The 347 round, BuyNum: 493 SellNum: 507
# The 348 round, BuyNum: 482 SellNum: 518
# The 349 round, BuyNum: 506 SellNum: 494
# The 350 round, BuyNum: 488 SellNum: 512
# The 351 round, BuyNum: 504 SellNum: 496
# The 352 round, BuyNum: 495 SellNum: 505
# The 353 round, BuyNum: 483 SellNum: 517
# The 354 round, BuyNum: 477 SellNum: 523
# The 355 round, BuyNum: 464 SellNum: 536
# The 356 round, BuyNum: 520 SellNum: 480
# The 357 round, BuyNum: 481 SellNum: 519
# The 358 round, BuyNum: 491 SellNum: 509
# The 359 round, BuyNum: 485 SellNum: 515
# The 360 round, BuyNum: 526 SellNum: 474
# The 361 round, BuyNum: 516 SellNum: 484
# The 362 round, BuyNum: 524 SellNum: 476
# The 363 round, BuyNum: 494 SellNum: 506
# The 364 round, BuyNum: 514 SellNum: 486
# The 365 round, BuyNum: 472 SellNum: 528
# The 366 round, BuyNum: 510 SellNum: 490
# The 367 round, BuyNum: 477 SellNum: 523
# The 368 round, BuyNum: 513 SellNum: 487
# The 369 round, BuyNum: 482 SellNum: 518
# The 370 round, BuyNum: 516 SellNum: 484
# The 371 round, BuyNum: 514 SellNum: 486
# The 372 round, BuyNum: 486 SellNum: 514
# The 373 round, BuyNum: 499 SellNum: 501
# The 374 round, BuyNum: 514 SellNum: 486
# The 375 round, BuyNum: 490 SellNum: 510
# The 376 round, BuyNum: 478 SellNum: 522
# The 377 round, BuyNum: 495 SellNum: 505
# The 378 round, BuyNum: 500 SellNum: 500
# The 379 round, BuyNum: 539 SellNum: 461
# The 380 round, BuyNum: 492 SellNum: 508
# The 381 round, BuyNum: 501 SellNum: 499
# The 382 round, BuyNum: 495 SellNum: 505
# The 383 round, BuyNum: 502 SellNum: 498
# The 384 round, BuyNum: 517 SellNum: 483
# The 385 round, BuyNum: 476 SellNum: 524
# The 386 round, BuyNum: 501 SellNum: 499
# The 387 round, BuyNum: 489 SellNum: 511
# The 388 round, BuyNum: 505 SellNum: 495
# The 389 round, BuyNum: 507 SellNum: 493
# The 390 round, BuyNum: 502 SellNum: 498
# The 391 round, BuyNum: 515 SellNum: 485
# The 392 round, BuyNum: 506 SellNum: 494
# The 393 round, BuyNum: 501 SellNum: 499
# The 394 round, BuyNum: 508 SellNum: 492
# The 395 round, BuyNum: 496 SellNum: 504
# The 396 round, BuyNum: 511 SellNum: 489
# The 397 round, BuyNum: 510 SellNum: 490
# The 398 round, BuyNum: 502 SellNum: 498
# The 399 round, BuyNum: 505 SellNum: 495
# The 400 round, BuyNum: 501 SellNum: 499
# The 401 round, BuyNum: 522 SellNum: 478
# The 402 round, BuyNum: 477 SellNum: 523
# The 403 round, BuyNum: 528 SellNum: 472
# The 404 round, BuyNum: 501 SellNum: 499
# The 405 round, BuyNum: 494 SellNum: 506
# The 406 round, BuyNum: 497 SellNum: 503
# The 407 round, BuyNum: 500 SellNum: 500
# The 408 round, BuyNum: 519 SellNum: 481
# The 409 round, BuyNum: 512 SellNum: 488
# The 410 round, BuyNum: 517 SellNum: 483
# The 411 round, BuyNum: 467 SellNum: 533
# The 412 round, BuyNum: 496 SellNum: 504
# The 413 round, BuyNum: 477 SellNum: 523
# The 414 round, BuyNum: 511 SellNum: 489
# The 415 round, BuyNum: 500 SellNum: 500
# The 416 round, BuyNum: 505 SellNum: 495
# The 417 round, BuyNum: 507 SellNum: 493
# The 418 round, BuyNum: 483 SellNum: 517
# The 419 round, BuyNum: 489 SellNum: 511
# The 420 round, BuyNum: 502 SellNum: 498
# The 421 round, BuyNum: 490 SellNum: 510
# The 422 round, BuyNum: 508 SellNum: 492
# The 423 round, BuyNum: 520 SellNum: 480
# The 424 round, BuyNum: 495 SellNum: 505
# The 425 round, BuyNum: 497 SellNum: 503
# The 426 round, BuyNum: 497 SellNum: 503
# The 427 round, BuyNum: 497 SellNum: 503
# The 428 round, BuyNum: 489 SellNum: 511
# The 429 round, BuyNum: 480 SellNum: 520
# The 430 round, BuyNum: 503 SellNum: 497
# The 431 round, BuyNum: 513 SellNum: 487
# The 432 round, BuyNum: 509 SellNum: 491
# The 433 round, BuyNum: 503 SellNum: 497
# The 434 round, BuyNum: 501 SellNum: 499
# The 435 round, BuyNum: 507 SellNum: 493
# The 436 round, BuyNum: 517 SellNum: 483
# The 437 round, BuyNum: 495 SellNum: 505
# The 438 round, BuyNum: 511 SellNum: 489
# The 439 round, BuyNum: 506 SellNum: 494
# The 440 round, BuyNum: 520 SellNum: 480
# The 441 round, BuyNum: 507 SellNum: 493
# The 442 round, BuyNum: 477 SellNum: 523
# The 443 round, BuyNum: 520 SellNum: 480
# The 444 round, BuyNum: 509 SellNum: 491
# The 445 round, BuyNum: 481 SellNum: 519
# The 446 round, BuyNum: 516 SellNum: 484
# The 447 round, BuyNum: 519 SellNum: 481
# The 448 round, BuyNum: 506 SellNum: 494
# The 449 round, BuyNum: 493 SellNum: 507
# The 450 round, BuyNum: 489 SellNum: 511
# The 451 round, BuyNum: 513 SellNum: 487
# The 452 round, BuyNum: 502 SellNum: 498
# The 453 round, BuyNum: 484 SellNum: 516
# The 454 round, BuyNum: 496 SellNum: 504
# The 455 round, BuyNum: 514 SellNum: 486
# The 456 round, BuyNum: 490 SellNum: 510
# The 457 round, BuyNum: 495 SellNum: 505
# The 458 round, BuyNum: 497 SellNum: 503
# The 459 round, BuyNum: 511 SellNum: 489
# The 460 round, BuyNum: 515 SellNum: 485
# The 461 round, BuyNum: 506 SellNum: 494
# The 462 round, BuyNum: 509 SellNum: 491
# The 463 round, BuyNum: 528 SellNum: 472
# The 464 round, BuyNum: 505 SellNum: 495
# The 465 round, BuyNum: 521 SellNum: 479
# The 466 round, BuyNum: 511 SellNum: 489
# The 467 round, BuyNum: 468 SellNum: 532
# The 468 round, BuyNum: 470 SellNum: 530
# The 469 round, BuyNum: 506 SellNum: 494
# The 470 round, BuyNum: 492 SellNum: 508
# The 471 round, BuyNum: 510 SellNum: 490
# The 472 round, BuyNum: 514 SellNum: 486
# The 473 round, BuyNum: 510 SellNum: 490
# The 474 round, BuyNum: 505 SellNum: 495
# The 475 round, BuyNum: 497 SellNum: 503
# The 476 round, BuyNum: 519 SellNum: 481
# The 477 round, BuyNum: 519 SellNum: 481
# The 478 round, BuyNum: 491 SellNum: 509
# The 479 round, BuyNum: 520 SellNum: 480
# The 480 round, BuyNum: 477 SellNum: 523
# The 481 round, BuyNum: 508 SellNum: 492
# The 482 round, BuyNum: 500 SellNum: 500
# The 483 round, BuyNum: 491 SellNum: 509
# The 484 round, BuyNum: 515 SellNum: 485
# The 485 round, BuyNum: 481 SellNum: 519
# The 486 round, BuyNum: 480 SellNum: 520
# The 487 round, BuyNum: 506 SellNum: 494
# The 488 round, BuyNum: 497 SellNum: 503
# The 489 round, BuyNum: 523 SellNum: 477
# The 490 round, BuyNum: 470 SellNum: 530
# The 491 round, BuyNum: 494 SellNum: 506
# The 492 round, BuyNum: 499 SellNum: 501
# The 493 round, BuyNum: 506 SellNum: 494
# The 494 round, BuyNum: 494 SellNum: 506
# The 495 round, BuyNum: 481 SellNum: 519
# The 496 round, BuyNum: 515 SellNum: 485
# The 497 round, BuyNum: 491 SellNum: 509
# The 498 round, BuyNum: 497 SellNum: 503
# The 499 round, BuyNum: 495 SellNum: 505
# The 500 round, BuyNum: 493 SellNum: 507
# The 501 round, BuyNum: 489 SellNum: 511
# The 502 round, BuyNum: 513 SellNum: 487
# The 503 round, BuyNum: 488 SellNum: 512
# The 504 round, BuyNum: 496 SellNum: 504
# The 505 round, BuyNum: 507 SellNum: 493
# The 506 round, BuyNum: 497 SellNum: 503
# The 507 round, BuyNum: 494 SellNum: 506
# The 508 round, BuyNum: 474 SellNum: 526
# The 509 round, BuyNum: 485 SellNum: 515
# The 510 round, BuyNum: 491 SellNum: 509
# The 511 round, BuyNum: 495 SellNum: 505
# The 512 round, BuyNum: 532 SellNum: 468
# The 513 round, BuyNum: 514 SellNum: 486
# The 514 round, BuyNum: 497 SellNum: 503
# The 515 round, BuyNum: 472 SellNum: 528
# The 516 round, BuyNum: 526 SellNum: 474
# The 517 round, BuyNum: 525 SellNum: 475
# The 518 round, BuyNum: 472 SellNum: 528
# The 519 round, BuyNum: 493 SellNum: 507
# The 520 round, BuyNum: 506 SellNum: 494
# The 521 round, BuyNum: 476 SellNum: 524
# The 522 round, BuyNum: 483 SellNum: 517
# The 523 round, BuyNum: 511 SellNum: 489
# The 524 round, BuyNum: 515 SellNum: 485
# The 525 round, BuyNum: 484 SellNum: 516
# The 526 round, BuyNum: 524 SellNum: 476
# The 527 round, BuyNum: 459 SellNum: 541
# The 528 round, BuyNum: 482 SellNum: 518
# The 529 round, BuyNum: 503 SellNum: 497
# The 530 round, BuyNum: 461 SellNum: 539
# The 531 round, BuyNum: 529 SellNum: 471
# The 532 round, BuyNum: 501 SellNum: 499
# The 533 round, BuyNum: 466 SellNum: 534
# The 534 round, BuyNum: 462 SellNum: 538
# The 535 round, BuyNum: 508 SellNum: 492
# The 536 round, BuyNum: 505 SellNum: 495
# The 537 round, BuyNum: 477 SellNum: 523
# The 538 round, BuyNum: 500 SellNum: 500
# The 539 round, BuyNum: 485 SellNum: 515
# The 540 round, BuyNum: 528 SellNum: 472
# The 541 round, BuyNum: 502 SellNum: 498
# The 542 round, BuyNum: 507 SellNum: 493
# The 543 round, BuyNum: 500 SellNum: 500
# The 544 round, BuyNum: 493 SellNum: 507
# The 545 round, BuyNum: 502 SellNum: 498
# The 546 round, BuyNum: 499 SellNum: 501
# The 547 round, BuyNum: 478 SellNum: 522
# The 548 round, BuyNum: 506 SellNum: 494
# The 549 round, BuyNum: 499 SellNum: 501
# The 550 round, BuyNum: 511 SellNum: 489
# The 551 round, BuyNum: 481 SellNum: 519
# The 552 round, BuyNum: 511 SellNum: 489
# The 553 round, BuyNum: 513 SellNum: 487
# The 554 round, BuyNum: 481 SellNum: 519
# The 555 round, BuyNum: 525 SellNum: 475
# The 556 round, BuyNum: 528 SellNum: 472
# The 557 round, BuyNum: 548 SellNum: 452
# The 558 round, BuyNum: 479 SellNum: 521
# The 559 round, BuyNum: 476 SellNum: 524
# The 560 round, BuyNum: 480 SellNum: 520
# The 561 round, BuyNum: 497 SellNum: 503
# The 562 round, BuyNum: 509 SellNum: 491
# The 563 round, BuyNum: 510 SellNum: 490
# The 564 round, BuyNum: 495 SellNum: 505
# The 565 round, BuyNum: 474 SellNum: 526
# The 566 round, BuyNum: 518 SellNum: 482
# The 567 round, BuyNum: 466 SellNum: 534
# The 568 round, BuyNum: 520 SellNum: 480
# The 569 round, BuyNum: 516 SellNum: 484
# The 570 round, BuyNum: 462 SellNum: 538
# The 571 round, BuyNum: 503 SellNum: 497
# The 572 round, BuyNum: 510 SellNum: 490
# The 573 round, BuyNum: 499 SellNum: 501
# The 574 round, BuyNum: 524 SellNum: 476
# The 575 round, BuyNum: 504 SellNum: 496
# The 576 round, BuyNum: 511 SellNum: 489
# The 577 round, BuyNum: 507 SellNum: 493
# The 578 round, BuyNum: 517 SellNum: 483
# The 579 round, BuyNum: 512 SellNum: 488
# The 580 round, BuyNum: 522 SellNum: 478
# The 581 round, BuyNum: 519 SellNum: 481
# The 582 round, BuyNum: 517 SellNum: 483
# The 583 round, BuyNum: 500 SellNum: 500
# The 584 round, BuyNum: 504 SellNum: 496
# The 585 round, BuyNum: 512 SellNum: 488
# The 586 round, BuyNum: 487 SellNum: 513
# The 587 round, BuyNum: 484 SellNum: 516
# The 588 round, BuyNum: 509 SellNum: 491
# The 589 round, BuyNum: 496 SellNum: 504
# The 590 round, BuyNum: 513 SellNum: 487
# The 591 round, BuyNum: 518 SellNum: 482
# The 592 round, BuyNum: 501 SellNum: 499
# The 593 round, BuyNum: 472 SellNum: 528
# The 594 round, BuyNum: 510 SellNum: 490
# The 595 round, BuyNum: 519 SellNum: 481
# The 596 round, BuyNum: 494 SellNum: 506
# The 597 round, BuyNum: 487 SellNum: 513
# The 598 round, BuyNum: 500 SellNum: 500
# The 599 round, BuyNum: 511 SellNum: 489
# The 600 round, BuyNum: 506 SellNum: 494
# The 601 round, BuyNum: 508 SellNum: 492
# The 602 round, BuyNum: 500 SellNum: 500
# The 603 round, BuyNum: 475 SellNum: 525
# The 604 round, BuyNum: 499 SellNum: 501
# The 605 round, BuyNum: 509 SellNum: 491
# The 606 round, BuyNum: 498 SellNum: 502
# The 607 round, BuyNum: 490 SellNum: 510
# The 608 round, BuyNum: 487 SellNum: 513
# The 609 round, BuyNum: 498 SellNum: 502
# The 610 round, BuyNum: 524 SellNum: 476
# The 611 round, BuyNum: 468 SellNum: 532
# The 612 round, BuyNum: 515 SellNum: 485
# The 613 round, BuyNum: 493 SellNum: 507
# The 614 round, BuyNum: 515 SellNum: 485
# The 615 round, BuyNum: 493 SellNum: 507
# The 616 round, BuyNum: 522 SellNum: 478
# The 617 round, BuyNum: 501 SellNum: 499
# The 618 round, BuyNum: 521 SellNum: 479
# The 619 round, BuyNum: 506 SellNum: 494
# The 620 round, BuyNum: 515 SellNum: 485
# The 621 round, BuyNum: 496 SellNum: 504
# The 622 round, BuyNum: 478 SellNum: 522
# The 623 round, BuyNum: 515 SellNum: 485
# The 624 round, BuyNum: 512 SellNum: 488
# The 625 round, BuyNum: 491 SellNum: 509
# The 626 round, BuyNum: 493 SellNum: 507
# The 627 round, BuyNum: 466 SellNum: 534
# The 628 round, BuyNum: 517 SellNum: 483
# The 629 round, BuyNum: 517 SellNum: 483
# The 630 round, BuyNum: 507 SellNum: 493
# The 631 round, BuyNum: 509 SellNum: 491
# The 632 round, BuyNum: 506 SellNum: 494
# The 633 round, BuyNum: 482 SellNum: 518
# The 634 round, BuyNum: 506 SellNum: 494
# The 635 round, BuyNum: 493 SellNum: 507
# The 636 round, BuyNum: 503 SellNum: 497
# The 637 round, BuyNum: 505 SellNum: 495
# The 638 round, BuyNum: 474 SellNum: 526
# The 639 round, BuyNum: 522 SellNum: 478
# The 640 round, BuyNum: 520 SellNum: 480
# The 641 round, BuyNum: 505 SellNum: 495
# The 642 round, BuyNum: 482 SellNum: 518
# The 643 round, BuyNum: 492 SellNum: 508
# The 644 round, BuyNum: 493 SellNum: 507
# The 645 round, BuyNum: 512 SellNum: 488
# The 646 round, BuyNum: 491 SellNum: 509
# The 647 round, BuyNum: 521 SellNum: 479
# The 648 round, BuyNum: 489 SellNum: 511
# The 649 round, BuyNum: 486 SellNum: 514
# The 650 round, BuyNum: 520 SellNum: 480
# The 651 round, BuyNum: 505 SellNum: 495
# The 652 round, BuyNum: 510 SellNum: 490
# The 653 round, BuyNum: 522 SellNum: 478
# The 654 round, BuyNum: 493 SellNum: 507
# The 655 round, BuyNum: 492 SellNum: 508
# The 656 round, BuyNum: 494 SellNum: 506
# The 657 round, BuyNum: 495 SellNum: 505
# The 658 round, BuyNum: 475 SellNum: 525
# The 659 round, BuyNum: 509 SellNum: 491
# The 660 round, BuyNum: 486 SellNum: 514
# The 661 round, BuyNum: 510 SellNum: 490
# The 662 round, BuyNum: 512 SellNum: 488
# The 663 round, BuyNum: 488 SellNum: 512
# The 664 round, BuyNum: 520 SellNum: 480
# The 665 round, BuyNum: 500 SellNum: 500
# The 666 round, BuyNum: 516 SellNum: 484
# The 667 round, BuyNum: 501 SellNum: 499
# The 668 round, BuyNum: 496 SellNum: 504
# The 669 round, BuyNum: 462 SellNum: 538
# The 670 round, BuyNum: 504 SellNum: 496
# The 671 round, BuyNum: 505 SellNum: 495
# The 672 round, BuyNum: 506 SellNum: 494
# The 673 round, BuyNum: 501 SellNum: 499
# The 674 round, BuyNum: 468 SellNum: 532
# The 675 round, BuyNum: 517 SellNum: 483
# The 676 round, BuyNum: 509 SellNum: 491
# The 677 round, BuyNum: 491 SellNum: 509
# The 678 round, BuyNum: 506 SellNum: 494
# The 679 round, BuyNum: 509 SellNum: 491
# The 680 round, BuyNum: 506 SellNum: 494
# The 681 round, BuyNum: 519 SellNum: 481
# The 682 round, BuyNum: 504 SellNum: 496
# The 683 round, BuyNum: 510 SellNum: 490
# The 684 round, BuyNum: 510 SellNum: 490
# The 685 round, BuyNum: 532 SellNum: 468
# The 686 round, BuyNum: 495 SellNum: 505
# The 687 round, BuyNum: 507 SellNum: 493
# The 688 round, BuyNum: 518 SellNum: 482
# The 689 round, BuyNum: 516 SellNum: 484
# The 690 round, BuyNum: 505 SellNum: 495
# The 691 round, BuyNum: 506 SellNum: 494
# The 692 round, BuyNum: 499 SellNum: 501
# The 693 round, BuyNum: 484 SellNum: 516
# The 694 round, BuyNum: 502 SellNum: 498
# The 695 round, BuyNum: 503 SellNum: 497
# The 696 round, BuyNum: 492 SellNum: 508
# The 697 round, BuyNum: 509 SellNum: 491
# The 698 round, BuyNum: 527 SellNum: 473
# The 699 round, BuyNum: 482 SellNum: 518
# The 700 round, BuyNum: 505 SellNum: 495
# The 701 round, BuyNum: 507 SellNum: 493
# The 702 round, BuyNum: 502 SellNum: 498
# The 703 round, BuyNum: 475 SellNum: 525
# The 704 round, BuyNum: 520 SellNum: 480
# The 705 round, BuyNum: 524 SellNum: 476
# The 706 round, BuyNum: 484 SellNum: 516
# The 707 round, BuyNum: 510 SellNum: 490
# The 708 round, BuyNum: 508 SellNum: 492
# The 709 round, BuyNum: 505 SellNum: 495
# The 710 round, BuyNum: 481 SellNum: 519
# The 711 round, BuyNum: 485 SellNum: 515
# The 712 round, BuyNum: 484 SellNum: 516
# The 713 round, BuyNum: 490 SellNum: 510
# The 714 round, BuyNum: 490 SellNum: 510
# The 715 round, BuyNum: 497 SellNum: 503
# The 716 round, BuyNum: 496 SellNum: 504
# The 717 round, BuyNum: 500 SellNum: 500
# The 718 round, BuyNum: 505 SellNum: 495
# The 719 round, BuyNum: 506 SellNum: 494
# The 720 round, BuyNum: 509 SellNum: 491
# The 721 round, BuyNum: 501 SellNum: 499
# The 722 round, BuyNum: 500 SellNum: 500
# The 723 round, BuyNum: 520 SellNum: 480
# The 724 round, BuyNum: 536 SellNum: 464
# The 725 round, BuyNum: 491 SellNum: 509
# The 726 round, BuyNum: 462 SellNum: 538
# The 727 round, BuyNum: 491 SellNum: 509
# The 728 round, BuyNum: 513 SellNum: 487
# The 729 round, BuyNum: 502 SellNum: 498
# The 730 round, BuyNum: 479 SellNum: 521
# The 731 round, BuyNum: 511 SellNum: 489
# The 732 round, BuyNum: 493 SellNum: 507
# The 733 round, BuyNum: 510 SellNum: 490
# The 734 round, BuyNum: 496 SellNum: 504
# The 735 round, BuyNum: 492 SellNum: 508
# The 736 round, BuyNum: 484 SellNum: 516
# The 737 round, BuyNum: 493 SellNum: 507
# The 738 round, BuyNum: 512 SellNum: 488
# The 739 round, BuyNum: 503 SellNum: 497
# The 740 round, BuyNum: 501 SellNum: 499
# The 741 round, BuyNum: 494 SellNum: 506
# The 742 round, BuyNum: 493 SellNum: 507
# The 743 round, BuyNum: 512 SellNum: 488
# The 744 round, BuyNum: 519 SellNum: 481
# The 745 round, BuyNum: 495 SellNum: 505
# The 746 round, BuyNum: 511 SellNum: 489
# The 747 round, BuyNum: 521 SellNum: 479
# The 748 round, BuyNum: 494 SellNum: 506
# The 749 round, BuyNum: 502 SellNum: 498
# The 750 round, BuyNum: 493 SellNum: 507
# The 751 round, BuyNum: 498 SellNum: 502
# The 752 round, BuyNum: 495 SellNum: 505
# The 753 round, BuyNum: 472 SellNum: 528
# The 754 round, BuyNum: 456 SellNum: 544
# The 755 round, BuyNum: 491 SellNum: 509
# The 756 round, BuyNum: 487 SellNum: 513
# The 757 round, BuyNum: 493 SellNum: 507
# The 758 round, BuyNum: 489 SellNum: 511
# The 759 round, BuyNum: 502 SellNum: 498
# The 760 round, BuyNum: 514 SellNum: 486
# The 761 round, BuyNum: 473 SellNum: 527
# The 762 round, BuyNum: 481 SellNum: 519
# The 763 round, BuyNum: 487 SellNum: 513
# The 764 round, BuyNum: 505 SellNum: 495
# The 765 round, BuyNum: 477 SellNum: 523
# The 766 round, BuyNum: 487 SellNum: 513
# The 767 round, BuyNum: 499 SellNum: 501
# The 768 round, BuyNum: 508 SellNum: 492
# The 769 round, BuyNum: 486 SellNum: 514
# The 770 round, BuyNum: 487 SellNum: 513
# The 771 round, BuyNum: 494 SellNum: 506
# The 772 round, BuyNum: 534 SellNum: 466
# The 773 round, BuyNum: 506 SellNum: 494
# The 774 round, BuyNum: 502 SellNum: 498
# The 775 round, BuyNum: 525 SellNum: 475
# The 776 round, BuyNum: 510 SellNum: 490
# The 777 round, BuyNum: 479 SellNum: 521
# The 778 round, BuyNum: 510 SellNum: 490
# The 779 round, BuyNum: 496 SellNum: 504
# The 780 round, BuyNum: 513 SellNum: 487
# The 781 round, BuyNum: 468 SellNum: 532
# The 782 round, BuyNum: 511 SellNum: 489
# The 783 round, BuyNum: 512 SellNum: 488
# The 784 round, BuyNum: 484 SellNum: 516
# The 785 round, BuyNum: 481 SellNum: 519
# The 786 round, BuyNum: 544 SellNum: 456
# The 787 round, BuyNum: 493 SellNum: 507
# The 788 round, BuyNum: 493 SellNum: 507
# The 789 round, BuyNum: 504 SellNum: 496
# The 790 round, BuyNum: 483 SellNum: 517
# The 791 round, BuyNum: 507 SellNum: 493
# The 792 round, BuyNum: 508 SellNum: 492
# The 793 round, BuyNum: 492 SellNum: 508
# The 794 round, BuyNum: 487 SellNum: 513
# The 795 round, BuyNum: 458 SellNum: 542
# The 796 round, BuyNum: 492 SellNum: 508
# The 797 round, BuyNum: 493 SellNum: 507
# The 798 round, BuyNum: 491 SellNum: 509
# The 799 round, BuyNum: 460 SellNum: 540
# The 800 round, BuyNum: 466 SellNum: 534
# The 801 round, BuyNum: 504 SellNum: 496
# The 802 round, BuyNum: 478 SellNum: 522
# The 803 round, BuyNum: 524 SellNum: 476
# The 804 round, BuyNum: 496 SellNum: 504
# The 805 round, BuyNum: 492 SellNum: 508
# The 806 round, BuyNum: 490 SellNum: 510
# The 807 round, BuyNum: 516 SellNum: 484
# The 808 round, BuyNum: 496 SellNum: 504
# The 809 round, BuyNum: 489 SellNum: 511
# The 810 round, BuyNum: 479 SellNum: 521
# The 811 round, BuyNum: 494 SellNum: 506
# The 812 round, BuyNum: 510 SellNum: 490
# The 813 round, BuyNum: 494 SellNum: 506
# The 814 round, BuyNum: 505 SellNum: 495
# The 815 round, BuyNum: 491 SellNum: 509
# The 816 round, BuyNum: 499 SellNum: 501
# The 817 round, BuyNum: 511 SellNum: 489
# The 818 round, BuyNum: 499 SellNum: 501
# The 819 round, BuyNum: 506 SellNum: 494
# The 820 round, BuyNum: 505 SellNum: 495
# The 821 round, BuyNum: 526 SellNum: 474
# The 822 round, BuyNum: 518 SellNum: 482
# The 823 round, BuyNum: 499 SellNum: 501
# The 824 round, BuyNum: 505 SellNum: 495
# The 825 round, BuyNum: 527 SellNum: 473
# The 826 round, BuyNum: 524 SellNum: 476
# The 827 round, BuyNum: 520 SellNum: 480
# The 828 round, BuyNum: 502 SellNum: 498
# The 829 round, BuyNum: 496 SellNum: 504
# The 830 round, BuyNum: 545 SellNum: 455
# The 831 round, BuyNum: 510 SellNum: 490
# The 832 round, BuyNum: 476 SellNum: 524
# The 833 round, BuyNum: 504 SellNum: 496
# The 834 round, BuyNum: 512 SellNum: 488
# The 835 round, BuyNum: 507 SellNum: 493
# The 836 round, BuyNum: 497 SellNum: 503
# The 837 round, BuyNum: 479 SellNum: 521
# The 838 round, BuyNum: 500 SellNum: 500
# The 839 round, BuyNum: 484 SellNum: 516
# The 840 round, BuyNum: 503 SellNum: 497
# The 841 round, BuyNum: 521 SellNum: 479
# The 842 round, BuyNum: 479 SellNum: 521
# The 843 round, BuyNum: 513 SellNum: 487
# The 844 round, BuyNum: 485 SellNum: 515
# The 845 round, BuyNum: 510 SellNum: 490
# The 846 round, BuyNum: 489 SellNum: 511
# The 847 round, BuyNum: 506 SellNum: 494
# The 848 round, BuyNum: 507 SellNum: 493
# The 849 round, BuyNum: 536 SellNum: 464
# The 850 round, BuyNum: 476 SellNum: 524
# The 851 round, BuyNum: 519 SellNum: 481
# The 852 round, BuyNum: 487 SellNum: 513
# The 853 round, BuyNum: 515 SellNum: 485
# The 854 round, BuyNum: 491 SellNum: 509
# The 855 round, BuyNum: 489 SellNum: 511
# The 856 round, BuyNum: 494 SellNum: 506
# The 857 round, BuyNum: 489 SellNum: 511
# The 858 round, BuyNum: 503 SellNum: 497
# The 859 round, BuyNum: 489 SellNum: 511
# The 860 round, BuyNum: 477 SellNum: 523
# The 861 round, BuyNum: 520 SellNum: 480
# The 862 round, BuyNum: 505 SellNum: 495
# The 863 round, BuyNum: 514 SellNum: 486
# The 864 round, BuyNum: 513 SellNum: 487
# The 865 round, BuyNum: 500 SellNum: 500
# The 866 round, BuyNum: 506 SellNum: 494
# The 867 round, BuyNum: 496 SellNum: 504
# The 868 round, BuyNum: 513 SellNum: 487
# The 869 round, BuyNum: 510 SellNum: 490
# The 870 round, BuyNum: 494 SellNum: 506
# The 871 round, BuyNum: 495 SellNum: 505
# The 872 round, BuyNum: 481 SellNum: 519
# The 873 round, BuyNum: 491 SellNum: 509
# The 874 round, BuyNum: 500 SellNum: 500
# The 875 round, BuyNum: 486 SellNum: 514
# The 876 round, BuyNum: 514 SellNum: 486
# The 877 round, BuyNum: 484 SellNum: 516
# The 878 round, BuyNum: 484 SellNum: 516
# The 879 round, BuyNum: 494 SellNum: 506
# The 880 round, BuyNum: 497 SellNum: 503
# The 881 round, BuyNum: 487 SellNum: 513
# The 882 round, BuyNum: 507 SellNum: 493
# The 883 round, BuyNum: 519 SellNum: 481
# The 884 round, BuyNum: 524 SellNum: 476
# The 885 round, BuyNum: 479 SellNum: 521
# The 886 round, BuyNum: 537 SellNum: 463
# The 887 round, BuyNum: 509 SellNum: 491
# The 888 round, BuyNum: 497 SellNum: 503
# The 889 round, BuyNum: 511 SellNum: 489
# The 890 round, BuyNum: 495 SellNum: 505
# The 891 round, BuyNum: 482 SellNum: 518
# The 892 round, BuyNum: 487 SellNum: 513
# The 893 round, BuyNum: 495 SellNum: 505
# The 894 round, BuyNum: 501 SellNum: 499
# The 895 round, BuyNum: 494 SellNum: 506
# The 896 round, BuyNum: 509 SellNum: 491
# The 897 round, BuyNum: 482 SellNum: 518
# The 898 round, BuyNum: 483 SellNum: 517
# The 899 round, BuyNum: 510 SellNum: 490
# The 900 round, BuyNum: 510 SellNum: 490
# The 901 round, BuyNum: 504 SellNum: 496
# The 902 round, BuyNum: 487 SellNum: 513
# The 903 round, BuyNum: 483 SellNum: 517
# The 904 round, BuyNum: 502 SellNum: 498
# The 905 round, BuyNum: 521 SellNum: 479
# The 906 round, BuyNum: 479 SellNum: 521
# The 907 round, BuyNum: 497 SellNum: 503
# The 908 round, BuyNum: 506 SellNum: 494
# The 909 round, BuyNum: 475 SellNum: 525
# The 910 round, BuyNum: 489 SellNum: 511
# The 911 round, BuyNum: 520 SellNum: 480
# The 912 round, BuyNum: 499 SellNum: 501
# The 913 round, BuyNum: 517 SellNum: 483
# The 914 round, BuyNum: 512 SellNum: 488
# The 915 round, BuyNum: 506 SellNum: 494
# The 916 round, BuyNum: 494 SellNum: 506
# The 917 round, BuyNum: 496 SellNum: 504
# The 918 round, BuyNum: 511 SellNum: 489
# The 919 round, BuyNum: 482 SellNum: 518
# The 920 round, BuyNum: 489 SellNum: 511
# The 921 round, BuyNum: 511 SellNum: 489
# The 922 round, BuyNum: 495 SellNum: 505
# The 923 round, BuyNum: 535 SellNum: 465
# The 924 round, BuyNum: 526 SellNum: 474
# The 925 round, BuyNum: 506 SellNum: 494
# The 926 round, BuyNum: 494 SellNum: 506
# The 927 round, BuyNum: 502 SellNum: 498
# The 928 round, BuyNum: 519 SellNum: 481
# The 929 round, BuyNum: 498 SellNum: 502
# The 930 round, BuyNum: 502 SellNum: 498
# The 931 round, BuyNum: 543 SellNum: 457
# The 932 round, BuyNum: 495 SellNum: 505
# The 933 round, BuyNum: 476 SellNum: 524
# The 934 round, BuyNum: 504 SellNum: 496
# The 935 round, BuyNum: 489 SellNum: 511
# The 936 round, BuyNum: 509 SellNum: 491
# The 937 round, BuyNum: 501 SellNum: 499
# The 938 round, BuyNum: 465 SellNum: 535
# The 939 round, BuyNum: 525 SellNum: 475
# The 940 round, BuyNum: 487 SellNum: 513
# The 941 round, BuyNum: 516 SellNum: 484
# The 942 round, BuyNum: 481 SellNum: 519
# The 943 round, BuyNum: 497 SellNum: 503
# The 944 round, BuyNum: 502 SellNum: 498
# The 945 round, BuyNum: 482 SellNum: 518
# The 946 round, BuyNum: 512 SellNum: 488
# The 947 round, BuyNum: 497 SellNum: 503
# The 948 round, BuyNum: 495 SellNum: 505
# The 949 round, BuyNum: 487 SellNum: 513
# The 950 round, BuyNum: 489 SellNum: 511
# The 951 round, BuyNum: 492 SellNum: 508
# The 952 round, BuyNum: 503 SellNum: 497
# The 953 round, BuyNum: 500 SellNum: 500
# The 954 round, BuyNum: 487 SellNum: 513
# The 955 round, BuyNum: 501 SellNum: 499
# The 956 round, BuyNum: 517 SellNum: 483
# The 957 round, BuyNum: 496 SellNum: 504
# The 958 round, BuyNum: 490 SellNum: 510
# The 959 round, BuyNum: 524 SellNum: 476
# The 960 round, BuyNum: 516 SellNum: 484
# The 961 round, BuyNum: 542 SellNum: 458
# The 962 round, BuyNum: 491 SellNum: 509
# The 963 round, BuyNum: 486 SellNum: 514
# The 964 round, BuyNum: 533 SellNum: 467
# The 965 round, BuyNum: 523 SellNum: 477
# The 966 round, BuyNum: 495 SellNum: 505
# The 967 round, BuyNum: 537 SellNum: 463
# The 968 round, BuyNum: 490 SellNum: 510
# The 969 round, BuyNum: 517 SellNum: 483
# The 970 round, BuyNum: 493 SellNum: 507
# The 971 round, BuyNum: 483 SellNum: 517
# The 972 round, BuyNum: 508 SellNum: 492
# The 973 round, BuyNum: 509 SellNum: 491
# The 974 round, BuyNum: 493 SellNum: 507
# The 975 round, BuyNum: 528 SellNum: 472
# The 976 round, BuyNum: 504 SellNum: 496
# The 977 round, BuyNum: 490 SellNum: 510
# The 978 round, BuyNum: 492 SellNum: 508
# The 979 round, BuyNum: 508 SellNum: 492
# The 980 round, BuyNum: 501 SellNum: 499
# The 981 round, BuyNum: 518 SellNum: 482
# The 982 round, BuyNum: 494 SellNum: 506
# The 983 round, BuyNum: 480 SellNum: 520
# The 984 round, BuyNum: 511 SellNum: 489
# The 985 round, BuyNum: 525 SellNum: 475
# The 986 round, BuyNum: 496 SellNum: 504
# The 987 round, BuyNum: 504 SellNum: 496
# The 988 round, BuyNum: 501 SellNum: 499
# The 989 round, BuyNum: 488 SellNum: 512
# The 990 round, BuyNum: 500 SellNum: 500
# The 991 round, BuyNum: 516 SellNum: 484
# The 992 round, BuyNum: 487 SellNum: 513
# The 993 round, BuyNum: 486 SellNum: 514
# The 994 round, BuyNum: 491 SellNum: 509
# The 995 round, BuyNum: 492 SellNum: 508
# The 996 round, BuyNum: 520 SellNum: 480
# The 997 round, BuyNum: 484 SellNum: 516
# The 998 round, BuyNum: 512 SellNum: 488
# The 999 round, BuyNum: 506 SellNum: 494

# %%
j = 0
failedBuyRate = []
failedSellRate = []
failedRate = []
myX = []
while j < TimeRound:
    myX.append(j)
    failedRate.append(failed_rateTracker[j][0])
    failedBuyRate.append(failedBuy_rateTracker[j][0])
    failedSellRate.append(failedSell_rateTracker[j][0])
    j = j + 1
x = np.asarray(myX)
y1 = np.asarray(failedRate)
y2 = np.asarray(failedBuyRate)
y3 = np.asarray(failedSellRate)
plt.plot(x,y1,'o-',color = 'navy',alpha = 0.8)
plt.title('Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Transaction', fontsize = 15)
plt.savefig('Failure/FailureRate-All.png', bbox_inches='tight')
plt.close()
plt.plot(x,y2,'o-',color = 'navy',alpha = 0.8)
plt.title('Buy Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Buy Transaction', fontsize = 15)
plt.savefig('Failure/FailureRate-Buy.png', bbox_inches='tight')
plt.close()
plt.plot(x,y3,'o-',color = 'navy',alpha = 0.8)
plt.title('Sell Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Sell Transaction', fontsize = 15)
plt.savefig('Failure/FailureRate-Sell.png', bbox_inches='tight')
plt.close()

# %%
j = 0
PriceAllRound = []
my_Xall = []
while j < TimeRound:
    myX = []
    Price_eachRound = []
    i = 0
    while i < custNum:
        myX.append(i+1)
        Price_eachRound.append(PriceTracker[i+j*custNum][0])
        i = i + 1
    PriceAllRound.append(Price_eachRound[custNum-1])
    # here to prevent the Price_eachRound plot cost too much time
    if TimeRound <= 50:
        x = np.asarray(myX)
        y = np.asarray(Price_eachRound)
        plt.plot(x,y,'o-',color = 'navy',alpha = 0.8)
        plt.title('Price Change in Round \"'+str(j)+'\"',fontsize = 25)
        plt.xlabel('Customer #',fontsize = 15)
        plt.ylabel('Price of Smart Token', fontsize = 15)
        plt.savefig('Price/PriceRound/Price_inRound'+str(j)+'.png', bbox_inches='tight')
        plt.close()
        print 'Round '+str(j)+' Over...'
    my_Xall.append(j)
    j = j + 1
allX = np.asarray(my_Xall)
ally = np.asarray(PriceAllRound)
plt.plot(allX,ally,'o-',color = 'navy',alpha = 0.8)
plt.title('Price Change For All Round',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Price of Smart Token', fontsize = 15)
plt.savefig('Price/Price_Change.png', bbox_inches='tight')
plt.close()

# %%
KennyCoin.printInfo()
# Out:
# ---------
# NAME: Kenny | RESERVE NAME: ETH CRR: 0.2
# PRICE: 2.07637843008
# SUPPLY: 360120.531037 | RESERVE BALANCE: 149549.300575
# BUDGET: 447746.502874

# %%
# issue a new smart token
initIssue = 300000
CRR = 0.2
initTransaction = initIssue * (1-CRR)
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=initIssue)

# %%
# example of using smartcoin class
BNTCoin = Smartcoin(name='BNT',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=300000)
BNTCoin.printInfo()
BNTCoin.purchasing(300)
BNTCoin.printInfo()
BNTCoin.purchasing(700)
BNTCoin.printInfo()
BNTCoin.destroying(1302)
BNTCoin.printInfo()
BNTCoin.purchasing(100)
BNTCoin.printInfo()
# Out:
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 1.0
# SUPPLY: 300000.0 | RESERVE BALANCE: 60000.0
# BUDGET: 0.0
# *********
# 300.0 ETH be converted into as 299.4 BNT
# Current prize of BNT is 1.00399800399 with 0.3998 % increasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 1.00399800399
# SUPPLY: 300299.401794 | RESERVE BALANCE: 60300.0
# BUDGET: 1500.0
# *********
# 700.0 ETH be converted into as 694.0 BNT
# Current prize of BNT is 1.01331125792 with 0.9276 % increasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 1.01331125792
# SUPPLY: 300993.399232 | RESERVE BALANCE: 61000.0
# BUDGET: 5000.0
# *********
# 1302.0 BNT be converted out as 1307.97 ETH
# Current prize of BNT is 0.995891667702 with 1.7191 % decreasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 0.995891667702
# SUPPLY: 299691.399232 | RESERVE BALANCE: 59692.0334754
# BUDGET: -1539.83262295
# *********
# 100.0 ETH be converted into as 100.35 BNT
# Current prize of BNT is 0.997226150558 with 0.134 % increasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 0.997226150558
# SUPPLY: 299791.74454 | RESERVE BALANCE: 59792.0334754
# BUDGET: -1039.83262295

# %%
# test for customers class
Alice = Customers(smartToken=KennyCoin)
print 'Current Price of KennyCoin: ', round(KennyCoin.getPrice(),4)
Alice.purchase(100)
print 'Current Price of KennyCoin: ', round(KennyCoin.getPrice(),4)
# Out:
# Current Price of KennyCoin:  1.0067
# *********
# 100.0 ETH be converted into as 99.27 Kenny
# Current prize of Kenny is 1.00799203183 with 0.1322 % increasing.
# Current Price of KennyCoin:  1.008
