# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
fw = open('Transaction-Record.txt','w')

# %%
# here, coin number is saved as float (complying with code from github, while contradicts white paper)
class Smartcoin(object):
	def __init__(self, name='kennycoin', reservetokenName='aCoin', initCRR=0.5, initPrice=1, initIssueNum=100):
		self._Name = name
		self._ReservetokenName = reservetokenName
		self._CRR = float(initCRR)
		self._Price = float(initPrice)
		self._Supply = float(initIssueNum)
		self._ReserveBalance = float(initCRR * initIssueNum)
		self._budget = float(0)     

	def printInfo(self):
		print '---------'
		print 'NAME:', self._Name, '| RESERVE NAME:', self._ReservetokenName, 'CRR:', self._CRR
		print 'PRICE:',self._Price
		print 'SUPPLY:', self._Supply, '| RESERVE BALANCE:', self._ReserveBalance
		print 'BUDGET:', self._budget

	def saveInfo(self, fw):
		fw.write('---------\n')
		fw.write('NAME: '+str(self._Name)+' | RESERVE NAME: '+str(self._ReservetokenName) + ' | CRR: '+str(self._CRR)+'\n')
		fw.write('PRICE: '+str(self._Price))
		fw.write('SUPPLY: '+str(self._Supply)+' | RESERVE BALANCE: '+str(self._ReserveBalance)+'\n')
        
	def updatePrice(self, reserveBalance, supply, CRR):
		newPrice = reserveBalance/(supply * CRR)
		return newPrice
    
	def setCRR(self, newCRR = 0.5):
		oldCRR = self._CRR
		self._CRR = newCRR
		print 'CRR', oldCRR, '->', newCRR

	def getPrice(self):
		return self._Price

	def purchasing(self, convertIntoNum=0):
		# ETH be convert into BNT
		issuedtokenNum = self._Supply * (((self._ReserveBalance + convertIntoNum)/self._ReserveBalance)**(self._CRR) - 1)
		self._Supply = self._Supply + issuedtokenNum
		self._ReserveBalance = self._ReserveBalance + convertIntoNum
		oldPrice = self._Price
		self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
		increaseRatio = (self._Price - oldPrice)/oldPrice
		print '&&&&&&&&&&'
		print round(convertIntoNum,2), self._ReservetokenName+" be converted into as", round(issuedtokenNum,2), self._Name
# 		print "Current price of "+self._Name+" is", self._Price, "with", round(increaseRatio*100,4), "% increasing."
		self._budget = self._budget + self._Price*self._Supply - oldPrice*(self._Supply - issuedtokenNum)
		return issuedtokenNum

	def destroying(self, convertOutNum=0):
		# BNT be converted out to ETH
		destroyedtokenNum = convertOutNum      
		reserveReceivedNum = self._ReserveBalance*(1 - ((self._Supply - convertOutNum)/self._Supply)**(1/self._CRR))
		self._Supply = self._Supply - destroyedtokenNum
		self._ReserveBalance = self._ReserveBalance - reserveReceivedNum
		oldPrice = self._Price
		self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
		decreaseRatio = (oldPrice-self._Price)/oldPrice
		print '**********'
		print round(convertOutNum,2), self._Name+" be converted out as", round(reserveReceivedNum,2), self._ReservetokenName
# 		print "Current price of "+self._Name+" is", self._Price, "with", round(decreaseRatio*100,4), "% decreasing."
		self._budget = self._budget + self._Price*self._Supply - oldPrice*(self._Supply + destroyedtokenNum)
		return reserveReceivedNum

# %%
class Customers(object):
    def __init__(self, smartToken, ownedSmartTokens = float(0), reserveValue = float(500),expectedPrice = 0):
        # _smartToken is the token customers want to buy -- SmartToken()
        self._smartToken = smartToken
        # _ownedSmartToken refers to smart token's number customers have
        self._ownedSmartToken = float(ownedSmartTokens)
        # _smartValue is the value of ownedSmartTokens -- currentPrice * owned#
        self._smartValue = smartToken.getPrice() * ownedSmartTokens
        self._reserveValue = float(reserveValue)
        # _ownedvalue = _reserveValue + _smartValue
        self._ownedvalue = float(reserveValue)
        # gain or lose money comparing to the original state
        self._budget = float(0)
        # expectedPrice denotes the how much money customers are willing to finish the transaction 
        self._expectedPrice = expectedPrice
        
    def printinfo(self):
        # since new reserve will be converted into or out the kenny coin, the budget could change
        # when print info, update the budget
        oldownedValue = self._ownedvalue
        self._ownedvalue = self._smartToken._Price * self._ownedSmartToken + self._reserveValue
        self._budget = self._budget + self._ownedvalue - oldownedValue
        print '------'
        print 'smartToken Name:', self._smartToken._Name
        print 'ownedvalue:', self._ownedvalue, 'budget:', self._budget
        
    def getReserveValue(self):
        return self._reserveValue
    def getownedSmartToken(self):
        return self._ownedSmartToken
    
    # add customer's reserve amount
    def addReserve(self, addAmount):
        self._reserveValue = self._reserveValue + addAmount
        self._ownedvalue = self._smartToken._Price * self._ownedSmartToken + self._reserveValue
    
    # returned expected Price
    def getExpectedPrice(self):
        return self._expectedPrice
        
    # change the expected price
    def changeExpectedPrice(self, newExpectedPrice):
        self._expectedPrice = newExpectedPrice
        
    def purchase(self, reserveTokenNumber):
        oldPrice = self._smartToken._Price
        if reserveTokenNumber > self._reserveValue:
            print 'Invalid Operation in Purchase'
            return
        # smartToken.purchasing means being converted
        issuedSmartToken = self._smartToken.purchasing(reserveTokenNumber)
        newPrice = self._smartToken._Price      
        self._ownedSmartToken = self._ownedSmartToken + issuedSmartToken
        self._smartValue = self._ownedSmartToken * newPrice
        self._reserveValue = self._reserveValue - reserveTokenNumber
        # in fact, in this case ownedValue and budget actually does not change at all
        oldownedValue = self._ownedvalue
        self._ownedvalue = self._reserveValue + self._smartValue
        self._budget = self._budget + self._ownedvalue - oldownedValue
        
        
    def destroy(self, smartTokenNumber):
        oldPrice = self._smartToken._Price
        if self._ownedSmartToken < smartTokenNumber:
            print 'Invalid Operation in Destroy'
            return
        self._ownedSmartToken = self._ownedSmartToken - smartTokenNumber
        # smartToken.purchasing means being purchased
        ReceivedToken = self._smartToken.destroying(smartTokenNumber)
        newPrice = self._smartToken._Price
        self._smartValue = self._ownedSmartToken*newPrice
        self._reserveValue = self._reserveValue + ReceivedToken
        # In fact, in this case ownedValue actually does not change at all
        oldownedValue = self._ownedvalue
        self._ownedvalue = self._reserveValue + self._smartValue
        self._budget = self._budget + self._ownedvalue - oldownedValue

# %%
# issue a new smart token
initIssue = 300000
CRR = 0.2
initTransaction = initIssue * (1-CRR)
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=initIssue)

# %%
'''
init properties: 
We have #TimeRound round,
In each time round, #custNum customers come in, 
   with original reserve: #custOriginalReserve
   with original smarttokens: #custOriginalSmartTokens
'''
TimeRound = 100
custNum = 100
custOriginalReserve = 100
custOriginalSmartTokens = 100
if TimeRound * custOriginalSmartTokens > initTransaction:
    print 'WARNING, too many init smart tokens from customers'

# PriceTracker records the change of the price
PriceTracker = []
# failedTracker records the transaction failure
failedBuy_rateTracker = []
failedSell_rateTracker = []
failed_rateTracker = []

alpha = 50 # 50% to buy, 50% to sell
j=0
while j < TimeRound:
    # failed num denotes the number of transactions failed in each time round
    failed_num = 0
    failed_buyNum = 0
    failed_sellNum = 0
    buyNum = 0
    sellNum = 0
    
    i=0
    custlist = []
    CurrentPrice = KennyCoin.getPrice()
    # set the expectation of initPrice (first we fix it), Should it change with time ?
    initPrice = CurrentPrice
    ''' 
    First, we initialize the customers who come in at #j TimeRound.
    We assume in each TimeRound, #custNum customers come in, whose number is gaussian distributed with custExpectedPrice
    We assume when price is mu -- initPrice, customers' number is the largest
    Since we get customers #custNum involved, the normal should be sampled by custNum.
    '''
    mu = initPrice
    sigma = 0.1
    np.random.seed(0)
    custExpectedPrice = np.random.normal(mu, sigma, custNum)
    while i < custNum:
#         # the customer's expected price should not lower than the currentPrice since every one want to achieve the transaction
#         if custExpectedPrice[i] <= CurrentPrice:
#             np.random.seed(0)
#             change_delta = random.uniform(0,0.001)
#             custExpectedPrice[i] = CurrentPrice * (1 + change_delta)
        # create Joe who is the customer who want to hold KennyCoin, with expected Buy and Sell Price custExpectedPrice
        Joe = Customers(smartToken = KennyCoin, ownedSmartTokens = custOriginalSmartTokens, reserveValue = custOriginalReserve, expectedPrice = custExpectedPrice[i])
        custlist.append(Joe)
        i = i + 1
    for Joe in custlist:
        # uses seed to let the purchase or sell happen randomly by a certain ratio
        np.random.seed(0)
        seed = random.randint(1, 100)
        if seed <= alpha:
            buyNum = buyNum + 1
            if Joe.getExpectedPrice() >= KennyCoin.getPrice():
                # Joe is purchasing
                custReserve = Joe.getReserveValue()
                randomBuy = random.uniform(0,custReserve)
                Joe.purchase(reserveTokenNumber = randomBuy)
            else:
                '''
                Customers are smart, and already know the price.
                No one will expect price lower than the standard prize?
                '''
                # if CurrentPrice < Joe.getExpectedPrice():
                failed_buyNum = failed_buyNum + 1
                
        else:
            sellNum = sellNum + 1
            if Joe.getExpectedPrice() <= KennyCoin.getPrice():
                # Joe is selling
                custSmartToken_Num = Joe.getownedSmartToken()
                randomSell = random.uniform(0,custSmartToken_Num)
                Joe.destroy(smartTokenNumber = randomSell)
            else:
                failed_sellNum = failed_sellNum + 1
        CurrentPrice = KennyCoin.getPrice()
        PriceTracker.append((CurrentPrice,j))
    print 'The',j,'round, BuyNum:',buyNum,'SellNum:',sellNum
    failed_num = failed_buyNum + failed_sellNum
    failedBuy_rateTracker.append((float(failed_buyNum) / buyNum , j))
    failedSell_rateTracker.append((float(failed_sellNum) / sellNum , j))
    failed_rateTracker.append((float(failed_num) / (buyNum+sellNum) , j))
    fw.write('After Round '+ str(j) + '\n')
    KennyCoin.saveInfo(fw)
    j = j + 1
fw.close()
# Out:
# &&&&&&&&&&
# 67.42 ETH be converted into as 67.39 Kenny
# &&&&&&&&&&
# 87.93 ETH be converted into as 87.8 Kenny
# &&&&&&&&&&
# 46.7 ETH be converted into as 46.59 Kenny
# &&&&&&&&&&
# 91.68 ETH be converted into as 91.38 Kenny
# &&&&&&&&&&
# 22.26 ETH be converted into as 22.17 Kenny
# **********
# 47.04 Kenny be converted out as 47.22 ETH
# &&&&&&&&&&
# 17.46 ETH be converted into as 17.4 Kenny
# &&&&&&&&&&
# 16.45 ETH be converted into as 16.39 Kenny
# **********
# 48.65 Kenny be converted out as 48.83 ETH
# &&&&&&&&&&
# 53.74 ETH be converted into as 53.54 Kenny
# **********
# 85.97 Kenny be converted out as 86.27 ETH
# &&&&&&&&&&
# 57.02 ETH be converted into as 56.83 Kenny
# &&&&&&&&&&
# 21.76 ETH be converted into as 21.67 Kenny
# &&&&&&&&&&
# 14.76 ETH be converted into as 14.7 Kenny
# &&&&&&&&&&
# 57.28 ETH be converted into as 57.02 Kenny
# &&&&&&&&&&
# 87.21 ETH be converted into as 86.73 Kenny
# **********
# 0.1 Kenny be converted out as 0.1 ETH
# &&&&&&&&&&
# 79.61 ETH be converted into as 79.08 Kenny
# &&&&&&&&&&
# 88.16 ETH be converted into as 87.48 Kenny
# &&&&&&&&&&
# 7.51 ETH be converted into as 7.45 Kenny
# **********
# 39.36 Kenny be converted out as 39.68 ETH
# **********
# 63.73 Kenny be converted out as 64.21 ETH
# &&&&&&&&&&
# 90.57 ETH be converted into as 89.88 Kenny
# **********
# 14.81 Kenny be converted out as 14.93 ETH
# **********
# 15.64 Kenny be converted out as 15.76 ETH
# **********
# 81.1 Kenny be converted out as 81.7 ETH
# **********
# 75.01 Kenny be converted out as 75.48 ETH
# &&&&&&&&&&
# 47.41 ETH be converted into as 47.12 Kenny
# **********
# 86.26 Kenny be converted out as 86.77 ETH
# **********
# 23.44 Kenny be converted out as 23.56 ETH
# **********
# 92.02 Kenny be converted out as 92.42 ETH
# **********
# 89.92 Kenny be converted out as 90.2 ETH
# &&&&&&&&&&
# 67.67 ETH be converted into as 67.47 Kenny
# **********
# 87.29 Kenny be converted out as 87.54 ETH
# &&&&&&&&&&
# 95.44 ETH be converted into as 95.16 Kenny
# &&&&&&&&&&
# 55.03 ETH be converted into as 54.82 Kenny
# &&&&&&&&&&
# 76.83 ETH be converted into as 76.47 Kenny
# **********
# 48.7 Kenny be converted out as 48.94 ETH
# **********
# 50.37 Kenny be converted out as 50.59 ETH
# **********
# 7.67 Kenny be converted out as 7.7 ETH
# **********
# 95.97 Kenny be converted out as 96.28 ETH
# &&&&&&&&&&
# 4.98 ETH be converted into as 4.97 Kenny
# &&&&&&&&&&
# 66.72 ETH be converted into as 66.51 Kenny
# **********
# 97.23 Kenny be converted out as 97.51 ETH
# &&&&&&&&&&
# 30.04 ETH be converted into as 29.97 Kenny
# **********
# 64.01 Kenny be converted out as 64.15 ETH
# &&&&&&&&&&
# 16.51 ETH be converted into as 16.48 Kenny
# &&&&&&&&&&
# 41.27 ETH be converted into as 41.18 Kenny
# &&&&&&&&&&
# 26.28 ETH be converted into as 26.21 Kenny
# **********
# 81.59 Kenny be converted out as 81.78 ETH
# &&&&&&&&&&
# 36.4 ETH be converted into as 36.32 Kenny
# The 0 round, BuyNum: 53 SellNum: 47
# &&&&&&&&&&
# 54.39 ETH be converted into as 54.25 Kenny
# **********
# 49.22 Kenny be converted out as 49.35 ETH
# &&&&&&&&&&
# 10.14 ETH be converted into as 10.12 Kenny
# &&&&&&&&&&
# 45.13 ETH be converted into as 45.01 Kenny
# &&&&&&&&&&
# 97.61 ETH be converted into as 97.25 Kenny
# &&&&&&&&&&
# 40.88 ETH be converted into as 40.69 Kenny
# &&&&&&&&&&
# 77.65 ETH be converted into as 77.23 Kenny
# **********
# 32.17 Kenny be converted out as 32.36 ETH
# &&&&&&&&&&
# 71.96 ETH be converted into as 71.53 Kenny
# &&&&&&&&&&
# 49.43 ETH be converted into as 49.1 Kenny
# **********
# 64.57 Kenny be converted out as 65.01 ETH
# **********
# 45.85 Kenny be converted out as 46.12 ETH
# &&&&&&&&&&
# 94.07 ETH be converted into as 93.48 Kenny
# &&&&&&&&&&
# 11.79 ETH be converted into as 11.71 Kenny
# &&&&&&&&&&
# 3.35 ETH be converted into as 3.33 Kenny
# **********
# 63.3 Kenny be converted out as 63.72 ETH
# **********
# 86.72 Kenny be converted out as 87.21 ETH
# &&&&&&&&&&
# 63.52 ETH be converted into as 63.17 Kenny
# &&&&&&&&&&
# 18.42 ETH be converted into as 18.31 Kenny
# &&&&&&&&&&
# 58.54 ETH be converted into as 58.16 Kenny
# **********
# 70.67 Kenny be converted out as 71.13 ETH
# **********
# 23.27 Kenny be converted out as 23.4 ETH
# **********
# 61.63 Kenny be converted out as 61.95 ETH
# &&&&&&&&&&
# 81.97 ETH be converted into as 81.53 Kenny
# **********
# 28.48 Kenny be converted out as 28.64 ETH
# **********
# 52.82 Kenny be converted out as 53.09 ETH
# &&&&&&&&&&
# 89.72 ETH be converted into as 89.23 Kenny
# **********
# 70.17 Kenny be converted out as 70.57 ETH
# **********
# 74.32 Kenny be converted out as 74.67 ETH
# **********
# 65.04 Kenny be converted out as 65.28 ETH
# &&&&&&&&&&
# 68.01 ETH be converted into as 67.76 Kenny
# &&&&&&&&&&
# 28.88 ETH be converted into as 28.75 Kenny
# **********
# 30.83 Kenny be converted out as 30.97 ETH
# &&&&&&&&&&
# 71.54 ETH be converted into as 71.21 Kenny
# **********
# 85.63 Kenny be converted out as 86.02 ETH
# &&&&&&&&&&
# 91.76 ETH be converted into as 91.34 Kenny
# &&&&&&&&&&
# 41.51 ETH be converted into as 41.29 Kenny
# **********
# 70.38 Kenny be converted out as 70.75 ETH
# **********
# 75.82 Kenny be converted out as 76.15 ETH
# **********
# 38.57 Kenny be converted out as 38.71 ETH
# &&&&&&&&&&
# 49.61 ETH be converted into as 49.43 Kenny
# &&&&&&&&&&
# 98.66 ETH be converted into as 98.21 Kenny
# &&&&&&&&&&
# 34.5 ETH be converted into as 34.31 Kenny
# &&&&&&&&&&
# 59.65 ETH be converted into as 59.28 Kenny
# &&&&&&&&&&
# 19.71 ETH be converted into as 19.58 Kenny
# The 1 round, BuyNum: 53 SellNum: 47
# &&&&&&&&&&
# 66.1 ETH be converted into as 65.62 Kenny
# **********
# 42.84 Kenny be converted out as 43.15 ETH
# &&&&&&&&&&
# 55.17 ETH be converted into as 54.76 Kenny
# &&&&&&&&&&
# 95.48 ETH be converted into as 94.68 Kenny
# &&&&&&&&&&
# 39.42 ETH be converted into as 39.06 Kenny
# &&&&&&&&&&
# 11.18 ETH be converted into as 11.07 Kenny
# &&&&&&&&&&
# 71.34 ETH be converted into as 70.61 Kenny
# &&&&&&&&&&
# 85.19 ETH be converted into as 84.24 Kenny
# **********
# 45.21 Kenny be converted out as 45.73 ETH
# &&&&&&&&&&
# 75.94 ETH be converted into as 75.06 Kenny
# **********
# 71.39 Kenny be converted out as 72.23 ETH
# &&&&&&&&&&
# 68.91 ETH be converted into as 68.11 Kenny
# **********
# 91.95 Kenny be converted out as 93.01 ETH
# **********
# 31.88 Kenny be converted out as 32.23 ETH
# &&&&&&&&&&
# 17.25 ETH be converted into as 17.07 Kenny
# &&&&&&&&&&
# 39.25 ETH be converted into as 38.82 Kenny
# &&&&&&&&&&
# 53.66 ETH be converted into as 53.04 Kenny
# **********
# 6.83 Kenny be converted out as 6.91 ETH
# &&&&&&&&&&
# 70.5 ETH be converted into as 69.64 Kenny
# **********
# 93.88 Kenny be converted out as 95.02 ETH
# **********
# 17.14 Kenny be converted out as 17.34 ETH
# &&&&&&&&&&
# 82.17 ETH be converted into as 81.21 Kenny
# **********
# 20.6 Kenny be converted out as 20.85 ETH
# **********
# 49.66 Kenny be converted out as 50.25 ETH
# &&&&&&&&&&
# 41.76 ETH be converted into as 41.28 Kenny
# **********
# 67.31 Kenny be converted out as 68.09 ETH
# **********
# 77.21 Kenny be converted out as 78.03 ETH
# &&&&&&&&&&
# 56.67 ETH be converted into as 56.08 Kenny
# **********
# 73.87 Kenny be converted out as 74.64 ETH
# **********
# 92.59 Kenny be converted out as 93.44 ETH
# **********
# 7.4 Kenny be converted out as 7.46 ETH
# **********
# 26.67 Kenny be converted out as 26.89 ETH
# **********
# 52.22 Kenny be converted out as 52.63 ETH
# **********
# 49.0 Kenny be converted out as 49.35 ETH
# &&&&&&&&&&
# 68.67 ETH be converted into as 68.17 Kenny
# &&&&&&&&&&
# 5.89 ETH be converted into as 5.85 Kenny
# **********
# 1.56 Kenny be converted out as 1.58 ETH
# **********
# 2.13 Kenny be converted out as 2.15 ETH
# &&&&&&&&&&
# 73.53 ETH be converted into as 72.93 Kenny
# **********
# 10.78 Kenny be converted out as 10.88 ETH
# **********
# 10.79 Kenny be converted out as 10.88 ETH
# &&&&&&&&&&
# 19.69 ETH be converted into as 19.53 Kenny
# &&&&&&&&&&
# 38.25 ETH be converted into as 37.91 Kenny
# &&&&&&&&&&
# 28.06 ETH be converted into as 27.8 Kenny
# &&&&&&&&&&
# 4.46 ETH be converted into as 4.42 Kenny
# **********
# 5.05 Kenny be converted out as 5.1 ETH
# &&&&&&&&&&
# 65.15 ETH be converted into as 64.51 Kenny
# &&&&&&&&&&
# 45.36 ETH be converted into as 44.87 Kenny
# &&&&&&&&&&
# 14.9 ETH be converted into as 14.73 Kenny
# The 2 round, BuyNum: 49 SellNum: 51
# &&&&&&&&&&
# 22.87 ETH be converted into as 22.61 Kenny
# &&&&&&&&&&
# 23.04 ETH be converted into as 22.77 Kenny
# **********
# 13.81 Kenny be converted out as 13.97 ETH
# **********
# 77.4 Kenny be converted out as 78.26 ETH
# **********
# 58.19 Kenny be converted out as 58.78 ETH
# &&&&&&&&&&
# 77.82 ETH be converted into as 77.02 Kenny
# &&&&&&&&&&
# 29.72 ETH be converted into as 29.4 Kenny
# &&&&&&&&&&
# 94.31 ETH be converted into as 93.2 Kenny
# &&&&&&&&&&
# 28.58 ETH be converted into as 28.22 Kenny
# &&&&&&&&&&
# 25.25 ETH be converted into as 24.92 Kenny
# **********
# 72.75 Kenny be converted out as 73.68 ETH
# &&&&&&&&&&
# 66.29 ETH be converted into as 65.46 Kenny
# **********
# 30.81 Kenny be converted out as 31.21 ETH
# &&&&&&&&&&
# 74.21 ETH be converted into as 73.24 Kenny
# **********
# 69.81 Kenny be converted out as 70.73 ETH
# &&&&&&&&&&
# 21.21 ETH be converted into as 20.94 Kenny
# &&&&&&&&&&
# 50.44 ETH be converted into as 49.77 Kenny
# &&&&&&&&&&
# 22.17 ETH be converted into as 21.87 Kenny
# **********
# 18.72 Kenny be converted out as 18.98 ETH
# **********
# 36.13 Kenny be converted out as 36.62 ETH
# **********
# 4.38 Kenny be converted out as 4.44 ETH
# &&&&&&&&&&
# 28.1 ETH be converted into as 27.72 Kenny
# **********
# 23.54 Kenny be converted out as 23.86 ETH
# &&&&&&&&&&
# 86.33 ETH be converted into as 85.15 Kenny
# **********
# 21.42 Kenny be converted out as 21.73 ETH
# **********
# 64.33 Kenny be converted out as 65.21 ETH
# &&&&&&&&&&
# 67.11 ETH be converted into as 66.2 Kenny
# &&&&&&&&&&
# 55.67 ETH be converted into as 54.87 Kenny
# **********
# 60.94 Kenny be converted out as 61.82 ETH
# **********
# 10.53 Kenny be converted out as 10.68 ETH
# **********
# 42.87 Kenny be converted out as 43.46 ETH
# &&&&&&&&&&
# 32.79 ETH be converted into as 32.35 Kenny
# **********
# 57.2 Kenny be converted out as 57.97 ETH
# &&&&&&&&&&
# 2.47 ETH be converted into as 2.44 Kenny
# **********
# 69.77 Kenny be converted out as 70.65 ETH
# **********
# 89.42 Kenny be converted out as 90.45 ETH
# &&&&&&&&&&
# 50.53 ETH be converted into as 49.97 Kenny
# **********
# 0.55 Kenny be converted out as 0.55 ETH
# &&&&&&&&&&
# 53.75 ETH be converted into as 53.11 Kenny
# &&&&&&&&&&
# 71.12 ETH be converted into as 70.22 Kenny
# &&&&&&&&&&
# 10.29 ETH be converted into as 10.15 Kenny
# &&&&&&&&&&
# 50.27 ETH be converted into as 49.59 Kenny
# **********
# 17.94 Kenny be converted out as 18.19 ETH
# &&&&&&&&&&
# 22.48 ETH be converted into as 22.17 Kenny
# &&&&&&&&&&
# 97.72 ETH be converted into as 96.3 Kenny
# &&&&&&&&&&
# 72.18 ETH be converted into as 71.06 Kenny
# The 3 round, BuyNum: 52 SellNum: 48
# &&&&&&&&&&
# 33.75 ETH be converted into as 33.2 Kenny
# &&&&&&&&&&
# 32.24 ETH be converted into as 31.7 Kenny
# &&&&&&&&&&
# 19.43 ETH be converted into as 19.09 Kenny
# &&&&&&&&&&
# 75.66 ETH be converted into as 74.32 Kenny
# **********
# 94.79 Kenny be converted out as 96.49 ETH
# &&&&&&&&&&
# 78.81 ETH be converted into as 77.43 Kenny
# &&&&&&&&&&
# 32.54 ETH be converted into as 31.95 Kenny
# &&&&&&&&&&
# 6.86 ETH be converted into as 6.73 Kenny
# &&&&&&&&&&
# 42.54 ETH be converted into as 41.74 Kenny
# &&&&&&&&&&
# 84.7 ETH be converted into as 83.05 Kenny
# &&&&&&&&&&
# 86.83 ETH be converted into as 85.04 Kenny
# &&&&&&&&&&
# 68.43 ETH be converted into as 66.96 Kenny
# &&&&&&&&&&
# 16.09 ETH be converted into as 15.73 Kenny
# &&&&&&&&&&
# 14.47 ETH be converted into as 14.15 Kenny
# **********
# 41.46 Kenny be converted out as 42.4 ETH
# &&&&&&&&&&
# 4.98 ETH be converted into as 4.87 Kenny
# &&&&&&&&&&
# 70.93 ETH be converted into as 69.34 Kenny
# &&&&&&&&&&
# 95.9 ETH be converted into as 93.65 Kenny
# **********
# 27.44 Kenny be converted out as 28.12 ETH
# **********
# 20.5 Kenny be converted out as 21.0 ETH
# **********
# 34.65 Kenny be converted out as 35.47 ETH
# &&&&&&&&&&
# 88.19 ETH be converted into as 86.12 Kenny
# **********
# 41.92 Kenny be converted out as 42.95 ETH
# &&&&&&&&&&
# 31.0 ETH be converted into as 30.26 Kenny
# **********
# 36.71 Kenny be converted out as 37.61 ETH
# **********
# 13.17 Kenny be converted out as 13.49 ETH
# **********
# 56.46 Kenny be converted out as 57.79 ETH
# **********
# 89.64 Kenny be converted out as 91.66 ETH
# &&&&&&&&&&
# 82.72 ETH be converted into as 80.91 Kenny
# **********
# 75.67 Kenny be converted out as 77.37 ETH
# **********
# 6.53 Kenny be converted out as 6.67 ETH
# **********
# 81.28 Kenny be converted out as 83.01 ETH
# **********
# 81.72 Kenny be converted out as 83.37 ETH
# &&&&&&&&&&
# 95.14 ETH be converted into as 93.25 Kenny
# &&&&&&&&&&
# 29.72 ETH be converted into as 29.11 Kenny
# &&&&&&&&&&
# 29.51 ETH be converted into as 28.89 Kenny
# **********
# 45.01 Kenny be converted out as 45.97 ETH
# &&&&&&&&&&
# 23.17 ETH be converted into as 22.69 Kenny
# &&&&&&&&&&
# 51.94 ETH be converted into as 50.83 Kenny
# **********
# 69.99 Kenny be converted out as 71.5 ETH
# **********
# 39.16 Kenny be converted out as 39.98 ETH
# **********
# 10.96 Kenny be converted out as 11.19 ETH
# &&&&&&&&&&
# 62.14 ETH be converted into as 60.87 Kenny
# &&&&&&&&&&
# 61.68 ETH be converted into as 60.37 Kenny
# &&&&&&&&&&
# 98.74 ETH be converted into as 96.54 Kenny
# **********
# 58.05 Kenny be converted out as 59.39 ETH
# &&&&&&&&&&
# 15.68 ETH be converted into as 15.34 Kenny
# &&&&&&&&&&
# 2.57 ETH be converted into as 2.52 Kenny
# The 4 round, BuyNum: 57 SellNum: 43
# &&&&&&&&&&
# 71.73 ETH be converted into as 70.09 Kenny
# &&&&&&&&&&
# 71.07 ETH be converted into as 69.38 Kenny
# &&&&&&&&&&
# 10.88 ETH be converted into as 10.62 Kenny
# &&&&&&&&&&
# 48.21 ETH be converted into as 47.02 Kenny
# **********
# 63.9 Kenny be converted out as 65.5 ETH
# &&&&&&&&&&
# 91.97 ETH be converted into as 89.7 Kenny
# &&&&&&&&&&
# 5.77 ETH be converted into as 5.62 Kenny
# &&&&&&&&&&
# 92.22 ETH be converted into as 89.83 Kenny
# &&&&&&&&&&
# 65.49 ETH be converted into as 63.73 Kenny
# &&&&&&&&&&
# 65.83 ETH be converted into as 64.01 Kenny
# &&&&&&&&&&
# 64.41 ETH be converted into as 62.58 Kenny
# **********
# 63.42 Kenny be converted out as 65.28 ETH
# **********
# 93.24 Kenny be converted out as 95.88 ETH
# **********
# 47.98 Kenny be converted out as 49.29 ETH
# &&&&&&&&&&
# 28.44 ETH be converted into as 27.69 Kenny
# &&&&&&&&&&
# 32.62 ETH be converted into as 31.75 Kenny
# &&&&&&&&&&
# 28.9 ETH be converted into as 28.12 Kenny
# **********
# 10.19 Kenny be converted out as 10.48 ETH
# **********
# 6.94 Kenny be converted out as 7.14 ETH
# **********
# 31.88 Kenny be converted out as 32.77 ETH
# &&&&&&&&&&
# 79.71 ETH be converted into as 77.53 Kenny
# &&&&&&&&&&
# 55.55 ETH be converted into as 53.99 Kenny
# **********
# 50.17 Kenny be converted out as 51.62 ETH
# **********
# 2.58 Kenny be converted out as 2.66 ETH
# &&&&&&&&&&
# 10.11 ETH be converted into as 9.83 Kenny
# **********
# 31.78 Kenny be converted out as 32.68 ETH
# **********
# 50.36 Kenny be converted out as 51.77 ETH
# &&&&&&&&&&
# 25.37 ETH be converted into as 24.69 Kenny
# **********
# 82.59 Kenny be converted out as 84.85 ETH
# **********
# 54.46 Kenny be converted out as 55.9 ETH
# **********
# 47.89 Kenny be converted out as 49.13 ETH
# **********
# 76.22 Kenny be converted out as 78.12 ETH
# **********
# 80.56 Kenny be converted out as 82.49 ETH
# **********
# 72.75 Kenny be converted out as 74.41 ETH
# **********
# 0.93 Kenny be converted out as 0.95 ETH
# **********
# 54.36 Kenny be converted out as 55.56 ETH
# &&&&&&&&&&
# 20.68 ETH be converted into as 20.24 Kenny
# &&&&&&&&&&
# 48.85 ETH be converted into as 47.79 Kenny
# **********
# 64.72 Kenny be converted out as 66.15 ETH
# **********
# 57.59 Kenny be converted out as 58.82 ETH
# **********
# 6.95 Kenny be converted out as 7.09 ETH
# **********
# 9.63 Kenny be converted out as 9.83 ETH
# &&&&&&&&&&
# 16.24 ETH be converted into as 15.91 Kenny
# &&&&&&&&&&
# 74.64 ETH be converted into as 73.08 Kenny
# **********
# 83.4 Kenny be converted out as 85.17 ETH
# &&&&&&&&&&
# 26.53 ETH be converted into as 25.99 Kenny
# &&&&&&&&&&
# 20.82 ETH be converted into as 20.38 Kenny
# &&&&&&&&&&
# 39.17 ETH be converted into as 38.34 Kenny
# **********
# 91.76 Kenny be converted out as 93.71 ETH
# &&&&&&&&&&
# 67.49 ETH be converted into as 66.1 Kenny
# &&&&&&&&&&
# 70.45 ETH be converted into as 68.93 Kenny
# &&&&&&&&&&
# 41.15 ETH be converted into as 40.24 Kenny
# The 5 round, BuyNum: 48 SellNum: 52
# &&&&&&&&&&
# 26.97 ETH be converted into as 26.36 Kenny
# &&&&&&&&&&
# 90.82 ETH be converted into as 88.7 Kenny
# &&&&&&&&&&
# 50.52 ETH be converted into as 49.3 Kenny
# &&&&&&&&&&
# 94.24 ETH be converted into as 91.87 Kenny
# **********
# 23.98 Kenny be converted out as 24.61 ETH
# &&&&&&&&&&
# 99.02 ETH be converted into as 96.44 Kenny
# &&&&&&&&&&
# 60.97 ETH be converted into as 59.32 Kenny
# &&&&&&&&&&
# 85.16 ETH be converted into as 82.78 Kenny
# &&&&&&&&&&
# 61.39 ETH be converted into as 59.61 Kenny
# &&&&&&&&&&
# 47.62 ETH be converted into as 46.21 Kenny
# **********
# 96.58 Kenny be converted out as 99.49 ETH
# **********
# 95.69 Kenny be converted out as 98.45 ETH
# &&&&&&&&&&
# 7.04 ETH be converted into as 6.85 Kenny
# **********
# 39.25 Kenny be converted out as 40.34 ETH
# **********
# 52.59 Kenny be converted out as 54.03 ETH
# **********
# 87.68 Kenny be converted out as 89.99 ETH
# &&&&&&&&&&
# 93.98 ETH be converted into as 91.55 Kenny
# &&&&&&&&&&
# 38.82 ETH be converted into as 37.78 Kenny
# **********
# 58.59 Kenny be converted out as 60.18 ETH
# **********
# 97.84 Kenny be converted out as 100.4 ETH
# **********
# 11.76 Kenny be converted out as 12.06 ETH
# **********
# 86.06 Kenny be converted out as 88.19 ETH
# &&&&&&&&&&
# 33.28 ETH be converted into as 32.49 Kenny
# **********
# 72.55 Kenny be converted out as 74.3 ETH
# &&&&&&&&&&
# 78.21 ETH be converted into as 76.37 Kenny
# &&&&&&&&&&
# 77.23 ETH be converted into as 75.34 Kenny
# &&&&&&&&&&
# 4.73 ETH be converted into as 4.61 Kenny
# **********
# 69.85 Kenny be converted out as 71.61 ETH
# **********
# 82.58 Kenny be converted out as 84.58 ETH
# **********
# 82.0 Kenny be converted out as 83.9 ETH
# **********
# 79.05 Kenny be converted out as 80.79 ETH
# **********
# 6.7 Kenny be converted out as 6.84 ETH
# **********
# 61.57 Kenny be converted out as 62.86 ETH
# &&&&&&&&&&
# 16.85 ETH be converted into as 16.5 Kenny
# **********
# 14.36 Kenny be converted out as 14.66 ETH
# &&&&&&&&&&
# 66.66 ETH be converted into as 65.28 Kenny
# &&&&&&&&&&
# 97.85 ETH be converted into as 95.74 Kenny
# &&&&&&&&&&
# 62.1 ETH be converted into as 60.69 Kenny
# &&&&&&&&&&
# 49.79 ETH be converted into as 48.63 Kenny
# &&&&&&&&&&
# 12.21 ETH be converted into as 11.92 Kenny
# **********
# 0.43 Kenny be converted out as 0.44 ETH
# **********
# 8.15 Kenny be converted out as 8.35 ETH
# **********
# 29.05 Kenny be converted out as 29.75 ETH
# &&&&&&&&&&
# 51.59 ETH be converted into as 50.37 Kenny
# &&&&&&&&&&
# 0.0 ETH be converted into as 0.0 Kenny
# **********
# 87.2 Kenny be converted out as 89.29 ETH
# &&&&&&&&&&
# 33.4 ETH be converted into as 32.63 Kenny
# &&&&&&&&&&
# 23.61 ETH be converted into as 23.05 Kenny
# **********
# 60.49 Kenny be converted out as 61.92 ETH
# &&&&&&&&&&
# 40.56 ETH be converted into as 39.63 Kenny
# &&&&&&&&&&
# 87.84 ETH be converted into as 85.74 Kenny
# &&&&&&&&&&
# 41.92 ETH be converted into as 40.89 Kenny
# The 6 round, BuyNum: 52 SellNum: 48
# &&&&&&&&&&
# 17.46 ETH be converted into as 17.02 Kenny
# &&&&&&&&&&
# 5.03 ETH be converted into as 4.9 Kenny
# &&&&&&&&&&
# 97.99 ETH be converted into as 95.46 Kenny
# &&&&&&&&&&
# 64.27 ETH be converted into as 62.55 Kenny
# **********
# 83.27 Kenny be converted out as 85.56 ETH
# &&&&&&&&&&
# 15.64 ETH be converted into as 15.23 Kenny
# **********
# 57.25 Kenny be converted out as 58.78 ETH
# &&&&&&&&&&
# 16.3 ETH be converted into as 15.88 Kenny
# &&&&&&&&&&
# 25.95 ETH be converted into as 25.27 Kenny
# &&&&&&&&&&
# 32.84 ETH be converted into as 31.98 Kenny
# &&&&&&&&&&
# 85.68 ETH be converted into as 83.36 Kenny
# &&&&&&&&&&
# 83.83 ETH be converted into as 81.46 Kenny
# &&&&&&&&&&
# 30.12 ETH be converted into as 29.25 Kenny
# **********
# 7.61 Kenny be converted out as 7.84 ETH
# &&&&&&&&&&
# 19.5 ETH be converted into as 18.93 Kenny
# &&&&&&&&&&
# 10.52 ETH be converted into as 10.21 Kenny
# **********
# 8.74 Kenny be converted out as 9.01 ETH
# &&&&&&&&&&
# 85.91 ETH be converted into as 83.35 Kenny
# **********
# 23.88 Kenny be converted out as 24.62 ETH
# &&&&&&&&&&
# 31.59 ETH be converted into as 30.64 Kenny
# &&&&&&&&&&
# 9.66 ETH be converted into as 9.37 Kenny
# **********
# 28.35 Kenny be converted out as 29.24 ETH
# **********
# 23.1 Kenny be converted out as 23.81 ETH
# **********
# 44.32 Kenny be converted out as 45.67 ETH
# &&&&&&&&&&
# 99.75 ETH be converted into as 96.77 Kenny
# **********
# 60.17 Kenny be converted out as 62.04 ETH
# &&&&&&&&&&
# 79.92 ETH be converted into as 77.5 Kenny
# **********
# 38.68 Kenny be converted out as 39.89 ETH
# **********
# 52.91 Kenny be converted out as 54.55 ETH
# &&&&&&&&&&
# 59.9 ETH be converted into as 58.1 Kenny
# **********
# 65.63 Kenny be converted out as 67.66 ETH
# &&&&&&&&&&
# 12.95 ETH be converted into as 12.56 Kenny
# **********
# 31.89 Kenny be converted out as 32.86 ETH
# **********
# 46.49 Kenny be converted out as 47.88 ETH
# **********
# 30.45 Kenny be converted out as 31.34 ETH
# &&&&&&&&&&
# 26.53 ETH be converted into as 25.78 Kenny
# &&&&&&&&&&
# 58.94 ETH be converted into as 57.24 Kenny
# &&&&&&&&&&
# 24.1 ETH be converted into as 23.39 Kenny
# &&&&&&&&&&
# 27.88 ETH be converted into as 27.05 Kenny
# **********
# 93.41 Kenny be converted out as 96.23 ETH
# **********
# 84.41 Kenny be converted out as 86.86 ETH
# &&&&&&&&&&
# 31.57 ETH be converted into as 30.69 Kenny
# **********
# 32.84 Kenny be converted out as 33.78 ETH
# **********
# 41.92 Kenny be converted out as 43.1 ETH
# **********
# 28.7 Kenny be converted out as 29.5 ETH
# **********
# 94.3 Kenny be converted out as 96.83 ETH
# &&&&&&&&&&
# 50.11 ETH be converted into as 48.82 Kenny
# &&&&&&&&&&
# 62.19 ETH be converted into as 60.54 Kenny
# &&&&&&&&&&
# 79.61 ETH be converted into as 77.43 Kenny
# The 7 round, BuyNum: 52 SellNum: 48
# &&&&&&&&&&
# 30.71 ETH be converted into as 29.85 Kenny
# &&&&&&&&&&
# 40.51 ETH be converted into as 39.35 Kenny
# **********
# 30.49 Kenny be converted out as 31.38 ETH
# &&&&&&&&&&
# 99.47 ETH be converted into as 96.58 Kenny
# **********
# 56.12 Kenny be converted out as 57.82 ETH
# &&&&&&&&&&
# 58.74 ETH be converted into as 57.02 Kenny
# &&&&&&&&&&
# 92.73 ETH be converted into as 89.92 Kenny
# **********
# 32.67 Kenny be converted out as 33.7 ETH
# &&&&&&&&&&
# 77.69 ETH be converted into as 75.29 Kenny
# &&&&&&&&&&
# 11.13 ETH be converted into as 10.78 Kenny
# **********
# 39.94 Kenny be converted out as 41.23 ETH
# &&&&&&&&&&
# 61.55 ETH be converted into as 59.62 Kenny
# &&&&&&&&&&
# 95.41 ETH be converted into as 92.33 Kenny
# **********
# 75.85 Kenny be converted out as 78.4 ETH
# **********
# 22.66 Kenny be converted out as 23.4 ETH
# &&&&&&&&&&
# 28.61 ETH be converted into as 27.69 Kenny
# **********
# 61.7 Kenny be converted out as 63.72 ETH
# &&&&&&&&&&
# 74.5 ETH be converted into as 72.14 Kenny
# **********
# 57.86 Kenny be converted out as 59.77 ETH
# **********
# 36.96 Kenny be converted out as 38.15 ETH
# &&&&&&&&&&
# 48.12 ETH be converted into as 46.62 Kenny
# **********
# 71.33 Kenny be converted out as 73.62 ETH
# **********
# 53.79 Kenny be converted out as 55.47 ETH
# &&&&&&&&&&
# 40.79 ETH be converted into as 39.55 Kenny
# **********
# 5.5 Kenny be converted out as 5.67 ETH
# **********
# 98.39 Kenny be converted out as 101.41 ETH
# **********
# 59.82 Kenny be converted out as 61.6 ETH
# &&&&&&&&&&
# 67.7 ETH be converted into as 65.75 Kenny
# &&&&&&&&&&
# 25.99 ETH be converted into as 25.23 Kenny
# &&&&&&&&&&
# 7.79 ETH be converted into as 7.56 Kenny
# **********
# 89.13 Kenny be converted out as 91.8 ETH
# &&&&&&&&&&
# 60.09 ETH be converted into as 58.36 Kenny
# **********
# 52.69 Kenny be converted out as 54.26 ETH
# &&&&&&&&&&
# 74.87 ETH be converted into as 72.7 Kenny
# **********
# 36.36 Kenny be converted out as 37.46 ETH
# **********
# 47.06 Kenny be converted out as 48.45 ETH
# &&&&&&&&&&
# 40.37 ETH be converted into as 39.21 Kenny
# **********
# 83.47 Kenny be converted out as 85.91 ETH
# &&&&&&&&&&
# 24.32 ETH be converted into as 23.64 Kenny
# &&&&&&&&&&
# 94.33 ETH be converted into as 91.62 Kenny
# &&&&&&&&&&
# 93.92 ETH be converted into as 91.11 Kenny
# &&&&&&&&&&
# 85.8 ETH be converted into as 83.13 Kenny
# &&&&&&&&&&
# 52.86 ETH be converted into as 51.18 Kenny
# &&&&&&&&&&
# 48.14 ETH be converted into as 46.58 Kenny
# &&&&&&&&&&
# 94.24 ETH be converted into as 91.09 Kenny
# The 8 round, BuyNum: 53 SellNum: 47
# &&&&&&&&&&
# 39.16 ETH be converted into as 37.82 Kenny
# **********
# 8.91 Kenny be converted out as 9.22 ETH
# **********
# 78.48 Kenny be converted out as 81.23 ETH
# &&&&&&&&&&
# 0.37 ETH be converted into as 0.35 Kenny
# &&&&&&&&&&
# 66.76 ETH be converted into as 64.51 Kenny
# &&&&&&&&&&
# 42.27 ETH be converted into as 40.81 Kenny
# &&&&&&&&&&
# 88.53 ETH be converted into as 85.41 Kenny
# **********
# 48.13 Kenny be converted out as 49.9 ETH
# **********
# 88.34 Kenny be converted out as 91.5 ETH
# &&&&&&&&&&
# 24.5 ETH be converted into as 23.66 Kenny
# **********
# 80.6 Kenny be converted out as 83.42 ETH
# &&&&&&&&&&
# 58.01 ETH be converted into as 56.06 Kenny
# &&&&&&&&&&
# 43.34 ETH be converted into as 41.85 Kenny
# **********
# 7.81 Kenny be converted out as 8.08 ETH
# **********
# 97.8 Kenny be converted out as 101.23 ETH
# &&&&&&&&&&
# 34.37 ETH be converted into as 33.22 Kenny
# **********
# 73.08 Kenny be converted out as 75.59 ETH
# **********
# 97.4 Kenny be converted out as 100.63 ETH
# &&&&&&&&&&
# 64.27 ETH be converted into as 62.22 Kenny
# **********
# 70.52 Kenny be converted out as 72.84 ETH
# **********
# 76.54 Kenny be converted out as 78.98 ETH
# &&&&&&&&&&
# 22.38 ETH be converted into as 21.7 Kenny
# **********
# 46.04 Kenny be converted out as 47.49 ETH
# **********
# 47.37 Kenny be converted out as 48.82 ETH
# **********
# 62.52 Kenny be converted out as 64.39 ETH
# &&&&&&&&&&
# 86.38 ETH be converted into as 83.86 Kenny
# **********
# 35.66 Kenny be converted out as 36.75 ETH
# &&&&&&&&&&
# 49.08 ETH be converted into as 47.63 Kenny
# &&&&&&&&&&
# 81.86 ETH be converted into as 79.37 Kenny
# &&&&&&&&&&
# 63.7 ETH be converted into as 61.7 Kenny
# &&&&&&&&&&
# 72.36 ETH be converted into as 70.04 Kenny
# &&&&&&&&&&
# 18.84 ETH be converted into as 18.23 Kenny
# **********
# 4.04 Kenny be converted out as 4.18 ETH
# **********
# 71.87 Kenny be converted out as 74.27 ETH
# **********
# 25.56 Kenny be converted out as 26.39 ETH
# **********
# 47.27 Kenny be converted out as 48.8 ETH
# &&&&&&&&&&
# 80.66 ETH be converted into as 78.13 Kenny
# &&&&&&&&&&
# 77.51 ETH be converted into as 75.0 Kenny
# **********
# 18.67 Kenny be converted out as 19.3 ETH
# **********
# 69.12 Kenny be converted out as 71.42 ETH
# **********
# 39.62 Kenny be converted out as 40.91 ETH
# &&&&&&&&&&
# 88.06 ETH be converted into as 85.26 Kenny
# &&&&&&&&&&
# 60.11 ETH be converted into as 58.14 Kenny
# &&&&&&&&&&
# 42.51 ETH be converted into as 41.09 Kenny
# The 9 round, BuyNum: 44 SellNum: 56
# &&&&&&&&&&
# 2.66 ETH be converted into as 2.57 Kenny
# **********
# 95.84 Kenny be converted out as 99.11 ETH
# &&&&&&&&&&
# 2.2 ETH be converted into as 2.13 Kenny
# &&&&&&&&&&
# 70.51 ETH be converted into as 68.19 Kenny
# &&&&&&&&&&
# 81.62 ETH be converted into as 78.86 Kenny
# &&&&&&&&&&
# 98.97 ETH be converted into as 95.51 Kenny
# &&&&&&&&&&
# 54.68 ETH be converted into as 52.72 Kenny
# &&&&&&&&&&
# 99.07 ETH be converted into as 95.43 Kenny
# &&&&&&&&&&
# 63.06 ETH be converted into as 60.68 Kenny
# **********
# 31.46 Kenny be converted out as 32.71 ETH
# **********
# 0.14 Kenny be converted out as 0.14 ETH
# &&&&&&&&&&
# 5.62 ETH be converted into as 5.4 Kenny
# **********
# 17.26 Kenny be converted out as 17.94 ETH
# &&&&&&&&&&
# 77.35 ETH be converted into as 74.4 Kenny
# &&&&&&&&&&
# 99.45 ETH be converted into as 95.55 Kenny
# &&&&&&&&&&
# 87.51 ETH be converted into as 83.98 Kenny
# **********
# 25.22 Kenny be converted out as 26.29 ETH
# **********
# 79.1 Kenny be converted out as 82.4 ETH
# &&&&&&&&&&
# 63.7 ETH be converted into as 61.15 Kenny
# **********
# 8.26 Kenny be converted out as 8.61 ETH
# **********
# 43.13 Kenny be converted out as 44.92 ETH
# &&&&&&&&&&
# 38.75 ETH be converted into as 37.21 Kenny
# **********
# 62.59 Kenny be converted out as 65.18 ETH
# **********
# 59.02 Kenny be converted out as 61.41 ETH
# **********
# 18.53 Kenny be converted out as 19.27 ETH
# **********
# 95.83 Kenny be converted out as 99.59 ETH
# **********
# 18.8 Kenny be converted out as 19.52 ETH
# **********
# 70.7 Kenny be converted out as 73.38 ETH
# **********
# 43.06 Kenny be converted out as 44.65 ETH
# &&&&&&&&&&
# 53.29 ETH be converted into as 51.38 Kenny
# &&&&&&&&&&
# 67.27 ETH be converted into as 64.82 Kenny
# &&&&&&&&&&
# 56.78 ETH be converted into as 54.66 Kenny
# &&&&&&&&&&
# 57.89 ETH be converted into as 55.69 Kenny
# &&&&&&&&&&
# 41.96 ETH be converted into as 40.34 Kenny
# **********
# 79.01 Kenny be converted out as 82.16 ETH
# &&&&&&&&&&
# 65.85 ETH be converted into as 63.33 Kenny
# **********
# 72.46 Kenny be converted out as 75.33 ETH
# **********
# 51.22 Kenny be converted out as 53.21 ETH
# &&&&&&&&&&
# 69.71 ETH be converted into as 67.09 Kenny
# &&&&&&&&&&
# 63.63 ETH be converted into as 61.19 Kenny
# &&&&&&&&&&
# 50.66 ETH be converted into as 48.69 Kenny
# &&&&&&&&&&
# 79.04 ETH be converted into as 75.89 Kenny
# **********
# 62.37 Kenny be converted out as 64.97 ETH
# **********
# 40.57 Kenny be converted out as 42.23 ETH
# &&&&&&&&&&
# 96.5 ETH be converted into as 92.68 Kenny
# **********
# 56.03 Kenny be converted out as 58.36 ETH
# &&&&&&&&&&
# 64.02 ETH be converted into as 61.47 Kenny
# &&&&&&&&&&
# 21.93 ETH be converted into as 21.05 Kenny
# &&&&&&&&&&
# 81.79 ETH be converted into as 78.43 Kenny
# The 10 round, BuyNum: 53 SellNum: 47
# &&&&&&&&&&
# 80.2 ETH be converted into as 76.84 Kenny
# **********
# 96.6 Kenny be converted out as 100.82 ETH
# &&&&&&&&&&
# 0.22 ETH be converted into as 0.21 Kenny
# &&&&&&&&&&
# 3.71 ETH be converted into as 3.56 Kenny
# &&&&&&&&&&
# 30.36 ETH be converted into as 29.1 Kenny
# **********
# 38.48 Kenny be converted out as 40.14 ETH
# **********
# 52.4 Kenny be converted out as 54.64 ETH
# **********
# 33.2 Kenny be converted out as 34.6 ETH
# &&&&&&&&&&
# 22.08 ETH be converted into as 21.19 Kenny
# &&&&&&&&&&
# 27.13 ETH be converted into as 26.03 Kenny
# **********
# 73.79 Kenny be converted out as 76.89 ETH
# &&&&&&&&&&
# 17.09 ETH be converted into as 16.4 Kenny
# &&&&&&&&&&
# 28.72 ETH be converted into as 27.57 Kenny
# **********
# 74.91 Kenny be converted out as 78.02 ETH
# **********
# 19.7 Kenny be converted out as 20.5 ETH
# **********
# 33.96 Kenny be converted out as 35.34 ETH
# &&&&&&&&&&
# 24.2 ETH be converted into as 23.26 Kenny
# **********
# 24.54 Kenny be converted out as 25.53 ETH
# **********
# 67.68 Kenny be converted out as 70.37 ETH
# &&&&&&&&&&
# 37.99 ETH be converted into as 36.54 Kenny
# **********
# 80.78 Kenny be converted out as 83.95 ETH
# **********
# 23.04 Kenny be converted out as 23.93 ETH
# &&&&&&&&&&
# 59.27 ETH be converted into as 57.06 Kenny
# **********
# 31.57 Kenny be converted out as 32.8 ETH
# **********
# 29.44 Kenny be converted out as 30.58 ETH
# **********
# 38.68 Kenny be converted out as 40.15 ETH
# &&&&&&&&&&
# 1.22 ETH be converted into as 1.18 Kenny
# &&&&&&&&&&
# 98.91 ETH be converted into as 95.25 Kenny
# &&&&&&&&&&
# 58.5 ETH be converted into as 56.28 Kenny
# &&&&&&&&&&
# 73.66 ETH be converted into as 70.8 Kenny
# **********
# 68.21 Kenny be converted out as 70.97 ETH
# **********
# 97.9 Kenny be converted out as 101.75 ETH
# **********
# 78.56 Kenny be converted out as 81.54 ETH
# **********
# 71.75 Kenny be converted out as 74.41 ETH
# **********
# 45.66 Kenny be converted out as 47.31 ETH
# &&&&&&&&&&
# 39.5 ETH be converted into as 38.12 Kenny
# **********
# 31.03 Kenny be converted out as 32.15 ETH
# &&&&&&&&&&
# 90.99 ETH be converted into as 87.78 Kenny
# **********
# 82.44 Kenny be converted out as 85.46 ETH
# &&&&&&&&&&
# 11.93 ETH be converted into as 11.51 Kenny
# &&&&&&&&&&
# 38.37 ETH be converted into as 37.02 Kenny
# &&&&&&&&&&
# 76.07 ETH be converted into as 73.34 Kenny
# &&&&&&&&&&
# 55.87 ETH be converted into as 53.82 Kenny
# **********
# 95.38 Kenny be converted out as 98.98 ETH
# &&&&&&&&&&
# 62.92 ETH be converted into as 60.65 Kenny
# **********
# 11.7 Kenny be converted out as 12.15 ETH
# **********
# 6.16 Kenny be converted out as 6.39 ETH
# &&&&&&&&&&
# 79.03 ETH be converted into as 76.12 Kenny
# &&&&&&&&&&
# 60.45 ETH be converted into as 58.17 Kenny
# **********
# 1.4 Kenny be converted out as 1.46 ETH
# &&&&&&&&&&
# 82.52 ETH be converted into as 79.34 Kenny
# &&&&&&&&&&
# 77.46 ETH be converted into as 74.4 Kenny
# &&&&&&&&&&
# 34.93 ETH be converted into as 33.52 Kenny
# **********
# 79.27 Kenny be converted out as 82.57 ETH
# &&&&&&&&&&
# 86.6 ETH be converted into as 83.14 Kenny
# &&&&&&&&&&
# 64.46 ETH be converted into as 61.82 Kenny
# &&&&&&&&&&
# 45.67 ETH be converted into as 43.77 Kenny
# &&&&&&&&&&
# 59.35 ETH be converted into as 56.84 Kenny
# &&&&&&&&&&
# 30.41 ETH be converted into as 29.11 Kenny
# The 11 round, BuyNum: 50 SellNum: 50
# &&&&&&&&&&
# 41.35 ETH be converted into as 39.57 Kenny
# &&&&&&&&&&
# 49.7 ETH be converted into as 47.53 Kenny
# &&&&&&&&&&
# 35.89 ETH be converted into as 34.31 Kenny
# &&&&&&&&&&
# 99.99 ETH be converted into as 95.49 Kenny
# &&&&&&&&&&
# 82.71 ETH be converted into as 78.89 Kenny
# &&&&&&&&&&
# 81.24 ETH be converted into as 77.41 Kenny
# &&&&&&&&&&
# 18.75 ETH be converted into as 17.86 Kenny
# &&&&&&&&&&
# 56.27 ETH be converted into as 53.56 Kenny
# &&&&&&&&&&
# 42.34 ETH be converted into as 40.28 Kenny
# **********
# 96.63 Kenny be converted out as 101.55 ETH
# &&&&&&&&&&
# 4.04 ETH be converted into as 3.85 Kenny
# &&&&&&&&&&
# 18.6 ETH be converted into as 17.71 Kenny
# &&&&&&&&&&
# 51.68 ETH be converted into as 49.18 Kenny
# **********
# 88.26 Kenny be converted out as 92.73 ETH
# **********
# 62.05 Kenny be converted out as 65.13 ETH
# &&&&&&&&&&
# 96.35 ETH be converted into as 91.79 Kenny
# **********
# 54.29 Kenny be converted out as 57.01 ETH
# **********
# 44.0 Kenny be converted out as 46.17 ETH
# **********
# 36.46 Kenny be converted out as 38.24 ETH
# **********
# 89.08 Kenny be converted out as 93.34 ETH
# **********
# 50.69 Kenny be converted out as 53.07 ETH
# &&&&&&&&&&
# 1.8 ETH be converted into as 1.72 Kenny
# **********
# 73.83 Kenny be converted out as 77.23 ETH
# &&&&&&&&&&
# 22.38 ETH be converted into as 21.4 Kenny
# **********
# 39.03 Kenny be converted out as 40.81 ETH
# **********
# 37.72 Kenny be converted out as 39.42 ETH
# **********
# 93.92 Kenny be converted out as 98.07 ETH
# &&&&&&&&&&
# 67.99 ETH be converted into as 65.12 Kenny
# **********
# 23.32 Kenny be converted out as 24.35 ETH
# **********
# 54.65 Kenny be converted out as 57.04 ETH
# **********
# 33.41 Kenny be converted out as 34.85 ETH
# &&&&&&&&&&
# 47.66 ETH be converted into as 45.69 Kenny
# **********
# 82.98 Kenny be converted out as 86.54 ETH
# &&&&&&&&&&
# 52.49 ETH be converted into as 50.34 Kenny
# **********
# 10.44 Kenny be converted out as 10.89 ETH
# &&&&&&&&&&
# 28.18 ETH be converted into as 27.02 Kenny
# &&&&&&&&&&
# 85.64 ETH be converted into as 82.04 Kenny
# &&&&&&&&&&
# 76.51 ETH be converted into as 73.22 Kenny
# &&&&&&&&&&
# 34.47 ETH be converted into as 32.97 Kenny
# &&&&&&&&&&
# 69.55 ETH be converted into as 66.47 Kenny
# &&&&&&&&&&
# 10.83 ETH be converted into as 10.35 Kenny
# The 12 round, BuyNum: 53 SellNum: 47
# &&&&&&&&&&
# 40.09 ETH be converted into as 38.28 Kenny
# &&&&&&&&&&
# 80.02 ETH be converted into as 76.35 Kenny
# &&&&&&&&&&
# 73.04 ETH be converted into as 69.63 Kenny
# **********
# 18.68 Kenny be converted out as 19.61 ETH
# &&&&&&&&&&
# 89.91 ETH be converted into as 85.64 Kenny
# &&&&&&&&&&
# 75.87 ETH be converted into as 72.19 Kenny
# &&&&&&&&&&
# 73.33 ETH be converted into as 69.71 Kenny
# &&&&&&&&&&
# 18.44 ETH be converted into as 17.52 Kenny
# &&&&&&&&&&
# 44.73 ETH be converted into as 42.48 Kenny
# **********
# 48.48 Kenny be converted out as 51.04 ETH
# &&&&&&&&&&
# 28.19 ETH be converted into as 26.78 Kenny
# **********
# 5.88 Kenny be converted out as 6.19 ETH
# &&&&&&&&&&
# 24.19 ETH be converted into as 22.97 Kenny
# &&&&&&&&&&
# 10.32 ETH be converted into as 9.8 Kenny
# **********
# 87.73 Kenny be converted out as 92.35 ETH
# **********
# 39.47 Kenny be converted out as 41.51 ETH
# **********
# 54.78 Kenny be converted out as 57.58 ETH
# **********
# 83.87 Kenny be converted out as 88.08 ETH
# **********
# 12.34 Kenny be converted out as 12.95 ETH
# **********
# 34.39 Kenny be converted out as 36.08 ETH
# &&&&&&&&&&
# 52.57 ETH be converted into as 50.1 Kenny
# **********
# 7.98 Kenny be converted out as 8.38 ETH
# **********
# 34.08 Kenny be converted out as 35.76 ETH
# **********
# 53.43 Kenny be converted out as 56.04 ETH
# **********
# 27.26 Kenny be converted out as 28.57 ETH
# **********
# 79.77 Kenny be converted out as 83.55 ETH
# &&&&&&&&&&
# 80.27 ETH be converted into as 76.64 Kenny
# &&&&&&&&&&
# 61.06 ETH be converted into as 58.24 Kenny
# **********
# 0.4 Kenny be converted out as 0.42 ETH
# **********
# 5.39 Kenny be converted out as 5.65 ETH
# **********
# 64.79 Kenny be converted out as 67.91 ETH
# **********
# 56.42 Kenny be converted out as 59.09 ETH
# **********
# 34.54 Kenny be converted out as 36.15 ETH
# **********
# 70.6 Kenny be converted out as 73.85 ETH
# **********
# 49.82 Kenny be converted out as 52.07 ETH
# **********
# 95.35 Kenny be converted out as 99.56 ETH
# &&&&&&&&&&
# 18.87 ETH be converted into as 18.08 Kenny
# &&&&&&&&&&
# 9.85 ETH be converted into as 9.43 Kenny
# &&&&&&&&&&
# 32.38 ETH be converted into as 31.02 Kenny
# &&&&&&&&&&
# 30.3 ETH be converted into as 29.01 Kenny
# **********
# 63.54 Kenny be converted out as 66.36 ETH
# &&&&&&&&&&
# 54.38 ETH be converted into as 52.08 Kenny
# **********
# 0.24 Kenny be converted out as 0.25 ETH
# &&&&&&&&&&
# 34.65 ETH be converted into as 33.16 Kenny
# **********
# 87.09 Kenny be converted out as 90.96 ETH
# &&&&&&&&&&
# 95.92 ETH be converted into as 91.84 Kenny
# &&&&&&&&&&
# 37.84 ETH be converted into as 36.2 Kenny
# &&&&&&&&&&
# 20.16 ETH be converted into as 19.28 Kenny
# &&&&&&&&&&
# 24.82 ETH be converted into as 23.73 Kenny
# **********
# 40.97 Kenny be converted out as 42.85 ETH
# **********
# 36.66 Kenny be converted out as 38.32 ETH
# **********
# 65.72 Kenny be converted out as 68.65 ETH
# &&&&&&&&&&
# 17.77 ETH be converted into as 17.01 Kenny
# &&&&&&&&&&
# 32.86 ETH be converted into as 31.46 Kenny
# &&&&&&&&&&
# 40.77 ETH be converted into as 39.01 Kenny
# &&&&&&&&&&
# 58.3 ETH be converted into as 55.75 Kenny
# &&&&&&&&&&
# 20.58 ETH be converted into as 19.67 Kenny
# &&&&&&&&&&
# 63.56 ETH be converted into as 60.71 Kenny
# The 13 round, BuyNum: 48 SellNum: 52
# &&&&&&&&&&
# 37.46 ETH be converted into as 35.76 Kenny
# &&&&&&&&&&
# 21.57 ETH be converted into as 20.58 Kenny
# &&&&&&&&&&
# 65.05 ETH be converted into as 62.04 Kenny
# &&&&&&&&&&
# 18.25 ETH be converted into as 17.4 Kenny
# **********
# 73.87 Kenny be converted out as 77.47 ETH
# **********
# 91.06 Kenny be converted out as 95.38 ETH
# &&&&&&&&&&
# 94.69 ETH be converted into as 90.4 Kenny
# &&&&&&&&&&
# 71.93 ETH be converted into as 68.6 Kenny
# &&&&&&&&&&
# 40.28 ETH be converted into as 38.39 Kenny
# &&&&&&&&&&
# 28.6 ETH be converted into as 27.24 Kenny
# **********
# 26.93 Kenny be converted out as 28.27 ETH
# &&&&&&&&&&
# 17.03 ETH be converted into as 16.22 Kenny
# &&&&&&&&&&
# 31.1 ETH be converted into as 29.62 Kenny
# &&&&&&&&&&
# 40.77 ETH be converted into as 38.81 Kenny
# **********
# 73.02 Kenny be converted out as 76.69 ETH
# &&&&&&&&&&
# 61.78 ETH be converted into as 58.83 Kenny
# **********
# 1.88 Kenny be converted out as 1.98 ETH
# **********
# 65.78 Kenny be converted out as 69.07 ETH
# **********
# 16.11 Kenny be converted out as 16.9 ETH
# &&&&&&&&&&
# 1.17 ETH be converted into as 1.12 Kenny
# &&&&&&&&&&
# 38.43 ETH be converted into as 36.61 Kenny
# **********
# 74.68 Kenny be converted out as 78.37 ETH
# **********
# 94.47 Kenny be converted out as 99.03 ETH
# **********
# 30.39 Kenny be converted out as 31.83 ETH
# &&&&&&&&&&
# 48.35 ETH be converted into as 46.16 Kenny
# **********
# 72.3 Kenny be converted out as 75.72 ETH
# **********
# 27.16 Kenny be converted out as 28.43 ETH
# **********
# 86.05 Kenny be converted out as 90.0 ETH
# **********
# 55.92 Kenny be converted out as 58.43 ETH
# **********
# 30.95 Kenny be converted out as 32.32 ETH
# &&&&&&&&&&
# 87.17 ETH be converted into as 83.45 Kenny
# &&&&&&&&&&
# 35.53 ETH be converted into as 33.99 Kenny
# **********
# 80.43 Kenny be converted out as 84.06 ETH
# **********
# 96.56 Kenny be converted out as 100.8 ETH
# **********
# 35.5 Kenny be converted out as 37.03 ETH
# **********
# 83.92 Kenny be converted out as 87.46 ETH
# &&&&&&&&&&
# 37.26 ETH be converted into as 35.77 Kenny
# **********
# 11.86 Kenny be converted out as 12.36 ETH
# &&&&&&&&&&
# 83.01 ETH be converted into as 79.62 Kenny
# **********
# 63.16 Kenny be converted out as 65.85 ETH
# &&&&&&&&&&
# 24.41 ETH be converted into as 23.42 Kenny
# **********
# 97.06 Kenny be converted out as 101.12 ETH
# **********
# 23.76 Kenny be converted out as 24.73 ETH
# **********
# 8.44 Kenny be converted out as 8.78 ETH
# &&&&&&&&&&
# 16.56 ETH be converted into as 15.91 Kenny
# **********
# 73.81 Kenny be converted out as 76.79 ETH
# &&&&&&&&&&
# 64.44 ETH be converted into as 61.95 Kenny
# &&&&&&&&&&
# 66.5 ETH be converted into as 63.87 Kenny
# **********
# 12.53 Kenny be converted out as 13.05 ETH
# &&&&&&&&&&
# 3.59 ETH be converted into as 3.45 Kenny
# &&&&&&&&&&
# 5.62 ETH be converted into as 5.39 Kenny
# &&&&&&&&&&
# 21.66 ETH be converted into as 20.8 Kenny
# &&&&&&&&&&
# 68.09 ETH be converted into as 65.32 Kenny
# &&&&&&&&&&
# 78.99 ETH be converted into as 75.71 Kenny
# &&&&&&&&&&
# 1.21 ETH be converted into as 1.15 Kenny
# &&&&&&&&&&
# 57.49 ETH be converted into as 55.06 Kenny
# &&&&&&&&&&
# 80.1 ETH be converted into as 76.65 Kenny
# The 14 round, BuyNum: 50 SellNum: 50
# &&&&&&&&&&
# 23.17 ETH be converted into as 22.16 Kenny
# &&&&&&&&&&
# 89.56 ETH be converted into as 85.58 Kenny
# &&&&&&&&&&
# 36.38 ETH be converted into as 34.74 Kenny
# &&&&&&&&&&
# 4.6 ETH be converted into as 4.39 Kenny
# &&&&&&&&&&
# 28.55 ETH be converted into as 27.24 Kenny
# &&&&&&&&&&
# 91.98 ETH be converted into as 87.71 Kenny
# &&&&&&&&&&
# 76.31 ETH be converted into as 72.7 Kenny
# &&&&&&&&&&
# 84.41 ETH be converted into as 80.33 Kenny
# **********
# 81.9 Kenny be converted out as 86.07 ETH
# **********
# 54.57 Kenny be converted out as 57.29 ETH
# &&&&&&&&&&
# 87.68 ETH be converted into as 83.5 Kenny
# **********
# 77.6 Kenny be converted out as 81.49 ETH
# **********
# 16.13 Kenny be converted out as 16.93 ETH
# &&&&&&&&&&
# 54.28 ETH be converted into as 51.71 Kenny
# &&&&&&&&&&
# 83.21 ETH be converted into as 79.21 Kenny
# **********
# 24.18 Kenny be converted out as 25.41 ETH
# **********
# 22.44 Kenny be converted out as 23.58 ETH
# **********
# 0.7 Kenny be converted out as 0.73 ETH
# &&&&&&&&&&
# 34.58 ETH be converted into as 32.91 Kenny
# &&&&&&&&&&
# 25.92 ETH be converted into as 24.66 Kenny
# **********
# 62.58 Kenny be converted out as 65.77 ETH
# &&&&&&&&&&
# 10.81 ETH be converted into as 10.29 Kenny
# **********
# 54.72 Kenny be converted out as 57.47 ETH
# &&&&&&&&&&
# 52.89 ETH be converted into as 50.36 Kenny
# **********
# 72.17 Kenny be converted out as 75.78 ETH
# &&&&&&&&&&
# 18.57 ETH be converted into as 17.69 Kenny
# **********
# 85.7 Kenny be converted out as 89.92 ETH
# **********
# 9.94 Kenny be converted out as 10.43 ETH
# **********
# 32.27 Kenny be converted out as 33.83 ETH
# **********
# 58.69 Kenny be converted out as 61.48 ETH
# **********
# 37.04 Kenny be converted out as 38.78 ETH
# **********
# 4.26 Kenny be converted out as 4.45 ETH
# &&&&&&&&&&
# 3.14 ETH be converted into as 3.0 Kenny
# &&&&&&&&&&
# 56.77 ETH be converted into as 54.22 Kenny
# **********
# 7.4 Kenny be converted out as 7.75 ETH
# &&&&&&&&&&
# 37.36 ETH be converted into as 35.66 Kenny
# **********
# 54.6 Kenny be converted out as 57.19 ETH
# **********
# 68.12 Kenny be converted out as 71.29 ETH
# **********
# 58.95 Kenny be converted out as 61.64 ETH
# &&&&&&&&&&
# 73.39 ETH be converted into as 70.18 Kenny
# &&&&&&&&&&
# 23.91 ETH be converted into as 22.85 Kenny
# &&&&&&&&&&
# 72.82 ETH be converted into as 69.55 Kenny
# &&&&&&&&&&
# 41.73 ETH be converted into as 39.83 Kenny
# The 15 round, BuyNum: 49 SellNum: 51
# &&&&&&&&&&
# 95.44 ETH be converted into as 91.01 Kenny
# &&&&&&&&&&
# 77.38 ETH be converted into as 73.71 Kenny
# &&&&&&&&&&
# 99.21 ETH be converted into as 94.4 Kenny
# &&&&&&&&&&
# 29.72 ETH be converted into as 28.26 Kenny
# **********
# 60.17 Kenny be converted out as 63.27 ETH
# **********
# 56.54 Kenny be converted out as 59.42 ETH
# &&&&&&&&&&
# 40.01 ETH be converted into as 38.08 Kenny
# &&&&&&&&&&
# 93.3 ETH be converted into as 88.73 Kenny
# &&&&&&&&&&
# 65.71 ETH be converted into as 62.43 Kenny
# &&&&&&&&&&
# 53.52 ETH be converted into as 50.81 Kenny
# &&&&&&&&&&
# 84.82 ETH be converted into as 80.45 Kenny
# **********
# 35.43 Kenny be converted out as 37.37 ETH
# **********
# 71.0 Kenny be converted out as 74.83 ETH
# **********
# 77.31 Kenny be converted out as 81.39 ETH
# &&&&&&&&&&
# 76.78 ETH be converted into as 72.92 Kenny
# **********
# 27.38 Kenny be converted out as 28.84 ETH
# &&&&&&&&&&
# 45.73 ETH be converted into as 43.42 Kenny
# &&&&&&&&&&
# 32.5 ETH be converted into as 30.84 Kenny
# &&&&&&&&&&
# 66.62 ETH be converted into as 63.18 Kenny
# **********
# 89.84 Kenny be converted out as 94.72 ETH
# **********
# 33.23 Kenny be converted out as 35.0 ETH
# **********
# 54.26 Kenny be converted out as 57.13 ETH
# &&&&&&&&&&
# 53.27 ETH be converted into as 50.6 Kenny
# &&&&&&&&&&
# 7.38 ETH be converted into as 7.01 Kenny
# **********
# 85.84 Kenny be converted out as 90.35 ETH
# **********
# 39.63 Kenny be converted out as 41.68 ETH
# **********
# 80.42 Kenny be converted out as 84.51 ETH
# &&&&&&&&&&
# 29.19 ETH be converted into as 27.78 Kenny
# **********
# 94.03 Kenny be converted out as 98.74 ETH
# **********
# 27.4 Kenny be converted out as 28.75 ETH
# **********
# 47.14 Kenny be converted out as 49.44 ETH
# &&&&&&&&&&
# 98.23 ETH be converted into as 93.64 Kenny
# **********
# 5.94 Kenny be converted out as 6.23 ETH
# **********
# 44.12 Kenny be converted out as 46.3 ETH
# **********
# 90.22 Kenny be converted out as 94.58 ETH
# **********
# 40.58 Kenny be converted out as 42.5 ETH
# &&&&&&&&&&
# 83.07 ETH be converted into as 79.28 Kenny
# **********
# 15.46 Kenny be converted out as 16.2 ETH
# **********
# 37.91 Kenny be converted out as 39.72 ETH
# **********
# 64.77 Kenny be converted out as 67.82 ETH
# &&&&&&&&&&
# 49.19 ETH be converted into as 46.99 Kenny
# &&&&&&&&&&
# 77.65 ETH be converted into as 74.11 Kenny
# &&&&&&&&&&
# 10.18 ETH be converted into as 9.71 Kenny
# &&&&&&&&&&
# 51.38 ETH be converted into as 48.99 Kenny
# &&&&&&&&&&
# 2.82 ETH be converted into as 2.69 Kenny
# **********
# 28.4 Kenny be converted out as 29.79 ETH
# &&&&&&&&&&
# 97.84 ETH be converted into as 93.23 Kenny
# **********
# 12.35 Kenny be converted out as 12.97 ETH
# &&&&&&&&&&
# 41.29 ETH be converted into as 39.32 Kenny
# &&&&&&&&&&
# 95.22 ETH be converted into as 90.59 Kenny
# &&&&&&&&&&
# 64.34 ETH be converted into as 61.16 Kenny
# &&&&&&&&&&
# 52.85 ETH be converted into as 50.19 Kenny
# **********
# 84.12 Kenny be converted out as 88.55 ETH
# &&&&&&&&&&
# 75.75 ETH be converted into as 71.96 Kenny
# &&&&&&&&&&
# 27.95 ETH be converted into as 26.54 Kenny
# &&&&&&&&&&
# 97.88 ETH be converted into as 92.86 Kenny
# &&&&&&&&&&
# 5.5 ETH be converted into as 5.21 Kenny
# **********
# 51.11 Kenny be converted out as 53.89 ETH
# &&&&&&&&&&
# 3.27 ETH be converted into as 3.1 Kenny
# The 16 round, BuyNum: 54 SellNum: 46
# &&&&&&&&&&
# 45.87 ETH be converted into as 43.5 Kenny
# &&&&&&&&&&
# 47.77 ETH be converted into as 45.28 Kenny
# &&&&&&&&&&
# 71.57 ETH be converted into as 67.78 Kenny
# &&&&&&&&&&
# 60.33 ETH be converted into as 57.09 Kenny
# &&&&&&&&&&
# 61.27 ETH be converted into as 57.93 Kenny
# **********
# 93.23 Kenny be converted out as 98.57 ETH
# **********
# 33.14 Kenny be converted out as 35.01 ETH
# &&&&&&&&&&
# 56.71 ETH be converted into as 53.68 Kenny
# &&&&&&&&&&
# 12.15 ETH be converted into as 11.5 Kenny
# **********
# 21.59 Kenny be converted out as 22.82 ETH
# **********
# 28.42 Kenny be converted out as 30.03 ETH
# &&&&&&&&&&
# 65.33 ETH be converted into as 61.82 Kenny
# **********
# 54.7 Kenny be converted out as 57.81 ETH
# &&&&&&&&&&
# 30.39 ETH be converted into as 28.76 Kenny
# &&&&&&&&&&
# 18.87 ETH be converted into as 17.85 Kenny
# &&&&&&&&&&
# 72.46 ETH be converted into as 68.51 Kenny
# &&&&&&&&&&
# 27.43 ETH be converted into as 25.92 Kenny
# **********
# 82.16 Kenny be converted out as 86.91 ETH
# &&&&&&&&&&
# 80.56 ETH be converted into as 76.15 Kenny
# &&&&&&&&&&
# 71.4 ETH be converted into as 67.43 Kenny
# &&&&&&&&&&
# 82.71 ETH be converted into as 78.04 Kenny
# **********
# 34.31 Kenny be converted out as 36.37 ETH
# **********
# 99.47 Kenny be converted out as 105.36 ETH
# **********
# 76.99 Kenny be converted out as 81.45 ETH
# &&&&&&&&&&
# 68.04 ETH be converted into as 64.31 Kenny
# **********
# 4.4 Kenny be converted out as 4.65 ETH
# **********
# 30.74 Kenny be converted out as 32.53 ETH
# **********
# 37.01 Kenny be converted out as 39.14 ETH
# &&&&&&&&&&
# 83.04 ETH be converted into as 78.5 Kenny
# **********
# 67.56 Kenny be converted out as 71.48 ETH
# **********
# 14.97 Kenny be converted out as 15.83 ETH
# &&&&&&&&&&
# 98.77 ETH be converted into as 93.36 Kenny
# **********
# 2.39 Kenny be converted out as 2.53 ETH
# &&&&&&&&&&
# 45.03 ETH be converted into as 42.53 Kenny
# &&&&&&&&&&
# 81.99 ETH be converted into as 77.37 Kenny
# **********
# 71.06 Kenny be converted out as 75.31 ETH
# **********
# 12.29 Kenny be converted out as 13.02 ETH
# **********
# 49.5 Kenny be converted out as 52.4 ETH
# **********
# 86.49 Kenny be converted out as 91.49 ETH
# &&&&&&&&&&
# 44.65 ETH be converted into as 42.22 Kenny
# **********
# 75.16 Kenny be converted out as 79.46 ETH
# **********
# 43.06 Kenny be converted out as 45.49 ETH
# &&&&&&&&&&
# 58.56 ETH be converted into as 55.43 Kenny
# &&&&&&&&&&
# ...
# &&&&&&&&&&
# 79.5 ETH be converted into as 68.88 Kenny
# **********
# 50.58 Kenny be converted out as 58.39 ETH
# &&&&&&&&&&
# 21.48 ETH be converted into as 18.62 Kenny
# **********
# 68.23 Kenny be converted out as 78.72 ETH
# **********
# 54.75 Kenny be converted out as 63.11 ETH
# **********
# 85.45 Kenny be converted out as 98.42 ETH
# **********
# 77.12 Kenny be converted out as 88.74 ETH
# **********
# 70.94 Kenny be converted out as 81.54 ETH
# &&&&&&&&&&
# 78.68 ETH be converted into as 68.45 Kenny
# &&&&&&&&&&
# 75.44 ETH be converted into as 65.57 Kenny
# &&&&&&&&&&
# 11.56 ETH be converted into as 10.05 Kenny
# &&&&&&&&&&
# 6.12 ETH be converted into as 5.31 Kenny
# **********
# 87.94 Kenny be converted out as 101.18 ETH
# **********
# 89.59 Kenny be converted out as 102.96 ETH
# **********
# 72.86 Kenny be converted out as 83.64 ETH
# **********
# 33.28 Kenny be converted out as 38.18 ETH
# &&&&&&&&&&
# 93.49 ETH be converted into as 81.47 Kenny
# &&&&&&&&&&
# 37.5 ETH be converted into as 32.65 Kenny
# **********
# 89.69 Kenny be converted out as 102.96 ETH
# &&&&&&&&&&
# 17.16 ETH be converted into as 14.96 Kenny
# **********
# 14.52 Kenny be converted out as 16.66 ETH
# &&&&&&&&&&
# 76.21 ETH be converted into as 66.4 Kenny
# &&&&&&&&&&
# 59.97 ETH be converted into as 52.21 Kenny
# &&&&&&&&&&
# 13.45 ETH be converted into as 11.71 Kenny
# The 93 round, BuyNum: 36 SellNum: 64
# &&&&&&&&&&
# 56.76 ETH be converted into as 49.38 Kenny
# &&&&&&&&&&
# 19.15 ETH be converted into as 16.65 Kenny
# &&&&&&&&&&
# 58.85 ETH be converted into as 51.14 Kenny
# **********
# 72.92 Kenny be converted out as 83.89 ETH
# &&&&&&&&&&
# 75.43 ETH be converted into as 65.57 Kenny
# &&&&&&&&&&
# 16.95 ETH be converted into as 14.72 Kenny
# &&&&&&&&&&
# 89.22 ETH be converted into as 77.47 Kenny
# **********
# 35.37 Kenny be converted out as 40.74 ETH
# **********
# 34.95 Kenny be converted out as 40.24 ETH
# &&&&&&&&&&
# 97.47 ETH be converted into as 84.62 Kenny
# &&&&&&&&&&
# 76.3 ETH be converted into as 66.18 Kenny
# **********
# 22.39 Kenny be converted out as 25.82 ETH
# &&&&&&&&&&
# 87.43 ETH be converted into as 75.78 Kenny
# &&&&&&&&&&
# 97.67 ETH be converted into as 84.57 Kenny
# **********
# 48.63 Kenny be converted out as 56.17 ETH
# &&&&&&&&&&
# 56.78 ETH be converted into as 49.15 Kenny
# &&&&&&&&&&
# 12.22 ETH be converted into as 10.57 Kenny
# &&&&&&&&&&
# 28.5 ETH be converted into as 24.66 Kenny
# **********
# 83.61 Kenny be converted out as 96.6 ETH
# &&&&&&&&&&
# 45.5 ETH be converted into as 39.39 Kenny
# **********
# 91.17 Kenny be converted out as 105.28 ETH
# **********
# 71.46 Kenny be converted out as 82.43 ETH
# &&&&&&&&&&
# 80.53 ETH be converted into as 69.81 Kenny
# &&&&&&&&&&
# 84.7 ETH be converted into as 73.36 Kenny
# &&&&&&&&&&
# 13.12 ETH be converted into as 11.36 Kenny
# **********
# 40.21 Kenny be converted out as 46.45 ETH
# **********
# 74.9 Kenny be converted out as 86.44 ETH
# **********
# 83.0 Kenny be converted out as 95.7 ETH
# **********
# 9.29 Kenny be converted out as 10.7 ETH
# **********
# 89.55 Kenny be converted out as 103.12 ETH
# &&&&&&&&&&
# 9.32 ETH be converted into as 8.1 Kenny
# **********
# 38.97 Kenny be converted out as 44.84 ETH
# &&&&&&&&&&
# 42.77 ETH be converted into as 37.17 Kenny
# &&&&&&&&&&
# 82.05 ETH be converted into as 71.26 Kenny
# &&&&&&&&&&
# 54.17 ETH be converted into as 47.01 Kenny
# **********
# 16.06 Kenny be converted out as 18.51 ETH
# &&&&&&&&&&
# 11.35 ETH be converted into as 9.85 Kenny
# **********
# 46.37 Kenny be converted out as 53.43 ETH
# **********
# 88.48 Kenny be converted out as 101.87 ETH
# **********
# 89.0 Kenny be converted out as 102.34 ETH
# &&&&&&&&&&
# 68.54 ETH be converted into as 59.61 Kenny
# **********
# 62.35 Kenny be converted out as 71.68 ETH
# &&&&&&&&&&
# 47.19 ETH be converted into as 41.05 Kenny
# **********
# 79.24 Kenny be converted out as 91.07 ETH
# &&&&&&&&&&
# 91.36 ETH be converted into as 79.49 Kenny
# The 94 round, BuyNum: 50 SellNum: 50
# &&&&&&&&&&
# 8.7 ETH be converted into as 7.57 Kenny
# &&&&&&&&&&
# 55.52 ETH be converted into as 48.27 Kenny
# **********
# 99.55 Kenny be converted out as 114.48 ETH
# **********
# 4.26 Kenny be converted out as 4.89 ETH
# &&&&&&&&&&
# 7.79 ETH be converted into as 6.78 Kenny
# **********
# 97.5 Kenny be converted out as 111.98 ETH
# &&&&&&&&&&
# 96.82 ETH be converted into as 84.31 Kenny
# **********
# 11.93 Kenny be converted out as 13.71 ETH
# **********
# 1.45 Kenny be converted out as 1.66 ETH
# &&&&&&&&&&
# 88.1 ETH be converted into as 76.65 Kenny
# &&&&&&&&&&
# 31.72 ETH be converted into as 27.57 Kenny
# **********
# 42.53 Kenny be converted out as 48.92 ETH
# &&&&&&&&&&
# 63.37 ETH be converted into as 55.1 Kenny
# &&&&&&&&&&
# 68.14 ETH be converted into as 59.2 Kenny
# &&&&&&&&&&
# 13.55 ETH be converted into as 11.76 Kenny
# &&&&&&&&&&
# 37.43 ETH be converted into as 32.5 Kenny
# **********
# 64.46 Kenny be converted out as 74.24 ETH
# **********
# 20.78 Kenny be converted out as 23.92 ETH
# &&&&&&&&&&
# 43.73 ETH be converted into as 37.99 Kenny
# **********
# 21.93 Kenny be converted out as 25.25 ETH
# **********
# 22.7 Kenny be converted out as 26.12 ETH
# **********
# 81.54 Kenny be converted out as 93.79 ETH
# &&&&&&&&&&
# 3.87 ETH be converted into as 3.37 Kenny
# **********
# 90.33 Kenny be converted out as 103.78 ETH
# &&&&&&&&&&
# 53.56 ETH be converted into as 46.63 Kenny
# **********
# 65.61 Kenny be converted out as 75.36 ETH
# **********
# 40.43 Kenny be converted out as 46.4 ETH
# &&&&&&&&&&
# 55.81 ETH be converted into as 48.63 Kenny
# **********
# 26.11 Kenny be converted out as 29.97 ETH
# **********
# 79.75 Kenny be converted out as 91.48 ETH
# **********
# 24.06 Kenny be converted out as 27.58 ETH
# **********
# 69.51 Kenny be converted out as 79.64 ETH
# &&&&&&&&&&
# 68.87 ETH be converted into as 60.12 Kenny
# &&&&&&&&&&
# 50.8 ETH be converted into as 44.31 Kenny
# &&&&&&&&&&
# 86.26 ETH be converted into as 75.19 Kenny
# &&&&&&&&&&
# 15.32 ETH be converted into as 13.34 Kenny
# &&&&&&&&&&
# 88.68 ETH be converted into as 77.21 Kenny
# **********
# 46.64 Kenny be converted out as 53.58 ETH
# **********
# 81.46 Kenny be converted out as 93.51 ETH
# &&&&&&&&&&
# 97.97 ETH be converted into as 85.35 Kenny
# &&&&&&&&&&
# 6.29 ETH be converted into as 5.48 Kenny
# **********
# 1.4 Kenny be converted out as 1.61 ETH
# &&&&&&&&&&
# 39.3 ETH be converted into as 34.2 Kenny
# &&&&&&&&&&
# 87.09 ETH be converted into as 75.76 Kenny
# **********
# 57.47 Kenny be converted out as 66.08 ETH
# &&&&&&&&&&
# 46.09 ETH be converted into as 40.09 Kenny
# &&&&&&&&&&
# 14.94 ETH be converted into as 12.99 Kenny
# &&&&&&&&&&
# 82.87 ETH be converted into as 72.02 Kenny
# &&&&&&&&&&
# 4.88 ETH be converted into as 4.24 Kenny
# &&&&&&&&&&
# 20.6 ETH be converted into as 17.89 Kenny
# &&&&&&&&&&
# 64.67 ETH be converted into as 56.14 Kenny
# The 95 round, BuyNum: 53 SellNum: 47
# **********
# 9.24 Kenny be converted out as 10.64 ETH
# **********
# 44.64 Kenny be converted out as 51.43 ETH
# &&&&&&&&&&
# 14.42 ETH be converted into as 12.52 Kenny
# &&&&&&&&&&
# 44.18 ETH be converted into as 38.35 Kenny
# &&&&&&&&&&
# 93.13 ETH be converted into as 80.78 Kenny
# &&&&&&&&&&
# 47.79 ETH be converted into as 41.42 Kenny
# **********
# 5.51 Kenny be converted out as 6.36 ETH
# &&&&&&&&&&
# 41.12 ETH be converted into as 35.62 Kenny
# **********
# 47.58 Kenny be converted out as 54.92 ETH
# &&&&&&&&&&
# 31.44 ETH be converted into as 27.25 Kenny
# **********
# 88.51 Kenny be converted out as 102.11 ETH
# &&&&&&&&&&
# 59.19 ETH be converted into as 51.32 Kenny
# &&&&&&&&&&
# 64.9 ETH be converted into as 56.23 Kenny
# **********
# 18.46 Kenny be converted out as 21.31 ETH
# **********
# 85.74 Kenny be converted out as 98.92 ETH
# **********
# 21.93 Kenny be converted out as 25.28 ETH
# **********
# 23.6 Kenny be converted out as 27.2 ETH
# &&&&&&&&&&
# 3.46 ETH be converted into as 3.0 Kenny
# &&&&&&&&&&
# 35.84 ETH be converted into as 31.1 Kenny
# &&&&&&&&&&
# 89.58 ETH be converted into as 77.67 Kenny
# **********
# 75.26 Kenny be converted out as 86.81 ETH
# **********
# 44.05 Kenny be converted out as 50.77 ETH
# **********
# 62.79 Kenny be converted out as 72.32 ETH
# &&&&&&&&&&
# 14.08 ETH be converted into as 12.23 Kenny
# **********
# 76.52 Kenny be converted out as 88.06 ETH
# &&&&&&&&&&
# 76.48 ETH be converted into as 66.45 Kenny
# &&&&&&&&&&
# 10.53 ETH be converted into as 9.14 Kenny
# **********
# 7.29 Kenny be converted out as 8.39 ETH
# **********
# 25.61 Kenny be converted out as 29.49 ETH
# &&&&&&&&&&
# 20.05 ETH be converted into as 17.42 Kenny
# **********
# 61.66 Kenny be converted out as 70.95 ETH
# &&&&&&&&&&
# 7.74 ETH be converted into as 6.73 Kenny
# &&&&&&&&&&
# 72.85 ETH be converted into as 63.3 Kenny
# &&&&&&&&&&
# 98.34 ETH be converted into as 85.36 Kenny
# &&&&&&&&&&
# 18.8 ETH be converted into as 16.31 Kenny
# **********
# 27.07 Kenny be converted out as 31.2 ETH
# **********
# 96.14 Kenny be converted out as 110.73 ETH
# &&&&&&&&&&
# 20.48 ETH be converted into as 17.79 Kenny
# &&&&&&&&&&
# 62.45 ETH be converted into as 54.22 Kenny
# &&&&&&&&&&
# 86.54 ETH be converted into as 75.08 Kenny
# The 96 round, BuyNum: 49 SellNum: 51
# &&&&&&&&&&
# 61.9 ETH be converted into as 53.66 Kenny
# &&&&&&&&&&
# 94.78 ETH be converted into as 82.08 Kenny
# **********
# 16.0 Kenny be converted out as 18.48 ETH
# &&&&&&&&&&
# 87.05 ETH be converted into as 75.33 Kenny
# **********
# 29.86 Kenny be converted out as 34.52 ETH
# &&&&&&&&&&
# 67.07 ETH be converted into as 58.01 Kenny
# &&&&&&&&&&
# 57.44 ETH be converted into as 49.65 Kenny
# &&&&&&&&&&
# 96.81 ETH be converted into as 83.61 Kenny
# **********
# 75.3 Kenny be converted out as 87.2 ETH
# &&&&&&&&&&
# 91.62 ETH be converted into as 79.12 Kenny
# **********
# 46.43 Kenny be converted out as 53.77 ETH
# &&&&&&&&&&
# 40.62 ETH be converted into as 35.07 Kenny
# **********
# 58.51 Kenny be converted out as 67.75 ETH
# &&&&&&&&&&
# 60.4 ETH be converted into as 52.16 Kenny
# &&&&&&&&&&
# 9.96 ETH be converted into as 8.6 Kenny
# **********
# 87.63 Kenny be converted out as 101.46 ETH
# &&&&&&&&&&
# 95.31 ETH be converted into as 82.33 Kenny
# &&&&&&&&&&
# 5.75 ETH be converted into as 4.96 Kenny
# &&&&&&&&&&
# 73.94 ETH be converted into as 63.8 Kenny
# **********
# 97.87 Kenny be converted out as 113.4 ETH
# **********
# 47.08 Kenny be converted out as 54.49 ETH
# **********
# 59.61 Kenny be converted out as 68.96 ETH
# &&&&&&&&&&
# 49.6 ETH be converted into as 42.89 Kenny
# **********
# 90.67 Kenny be converted out as 104.84 ETH
# **********
# 6.52 Kenny be converted out as 7.53 ETH
# **********
# 34.59 Kenny be converted out as 39.97 ETH
# **********
# 84.45 Kenny be converted out as 97.49 ETH
# &&&&&&&&&&
# 43.03 ETH be converted into as 37.29 Kenny
# &&&&&&&&&&
# 22.42 ETH be converted into as 19.42 Kenny
# &&&&&&&&&&
# 48.74 ETH be converted into as 42.2 Kenny
# **********
# 55.39 Kenny be converted out as 63.97 ETH
# **********
# 29.75 Kenny be converted out as 34.34 ETH
# **********
# 44.78 Kenny be converted out as 51.66 ETH
# &&&&&&&&&&
# 66.24 ETH be converted into as 57.41 Kenny
# **********
# 88.03 Kenny be converted out as 101.55 ETH
# &&&&&&&&&&
# 15.57 ETH be converted into as 13.51 Kenny
# **********
# 14.48 Kenny be converted out as 16.69 ETH
# **********
# 2.74 Kenny be converted out as 3.15 ETH
# &&&&&&&&&&
# 38.88 ETH be converted into as 33.72 Kenny
# &&&&&&&&&&
# 7.3 ETH be converted into as 6.33 Kenny
# **********
# 60.75 Kenny be converted out as 70.05 ETH
# &&&&&&&&&&
# 67.87 ETH be converted into as 58.87 Kenny
# **********
# 10.61 Kenny be converted out as 12.24 ETH
# &&&&&&&&&&
# 80.43 ETH be converted into as 69.71 Kenny
# &&&&&&&&&&
# 65.02 ETH be converted into as 56.31 Kenny
# &&&&&&&&&&
# 89.98 ETH be converted into as 77.86 Kenny
# &&&&&&&&&&
# 1.5 ETH be converted into as 1.3 Kenny
# The 97 round, BuyNum: 52 SellNum: 48
# &&&&&&&&&&
# 29.91 ETH be converted into as 25.86 Kenny
# &&&&&&&&&&
# 30.17 ETH be converted into as 26.08 Kenny
# &&&&&&&&&&
# 10.3 ETH be converted into as 8.9 Kenny
# **********
# 71.28 Kenny be converted out as 82.45 ETH
# **********
# 4.18 Kenny be converted out as 4.83 ETH
# &&&&&&&&&&
# 75.34 ETH be converted into as 65.14 Kenny
# &&&&&&&&&&
# 9.77 ETH be converted into as 8.44 Kenny
# &&&&&&&&&&
# 32.81 ETH be converted into as 28.35 Kenny
# &&&&&&&&&&
# 19.0 ETH be converted into as 16.41 Kenny
# **********
# 14.56 Kenny be converted out as 16.86 ETH
# &&&&&&&&&&
# 90.55 ETH be converted into as 78.18 Kenny
# **********
# 0.42 Kenny be converted out as 0.49 ETH
# &&&&&&&&&&
# 25.63 ETH be converted into as 22.12 Kenny
# **********
# 34.52 Kenny be converted out as 40.0 ETH
# &&&&&&&&&&
# 83.18 ETH be converted into as 71.76 Kenny
# **********
# 2.28 Kenny be converted out as 2.64 ETH
# **********
# 67.29 Kenny be converted out as 77.99 ETH
# **********
# 41.02 Kenny be converted out as 47.51 ETH
# **********
# 86.37 Kenny be converted out as 99.96 ETH
# &&&&&&&&&&
# 55.18 ETH be converted into as 47.69 Kenny
# **********
# 73.42 Kenny be converted out as 84.94 ETH
# **********
# 10.73 Kenny be converted out as 12.4 ETH
# &&&&&&&&&&
# 16.96 ETH be converted into as 14.67 Kenny
# **********
# 21.66 Kenny be converted out as 25.05 ETH
# **********
# 80.74 Kenny be converted out as 93.29 ETH
# &&&&&&&&&&
# 16.29 ETH be converted into as 14.1 Kenny
# &&&&&&&&&&
# 26.32 ETH be converted into as 22.78 Kenny
# &&&&&&&&&&
# 54.03 ETH be converted into as 46.75 Kenny
# &&&&&&&&&&
# 23.79 ETH be converted into as 20.58 Kenny
# **********
# 40.4 Kenny be converted out as 46.71 ETH
# **********
# 6.47 Kenny be converted out as 7.48 ETH
# **********
# 22.46 Kenny be converted out as 25.96 ETH
# &&&&&&&&&&
# 5.36 ETH be converted into as 4.64 Kenny
# **********
# 45.06 Kenny be converted out as 52.05 ETH
# &&&&&&&&&&
# 16.68 ETH be converted into as 14.45 Kenny
# **********
# 26.79 Kenny be converted out as 30.94 ETH
# &&&&&&&&&&
# 25.45 ETH be converted into as 22.04 Kenny
# &&&&&&&&&&
# 45.62 ETH be converted into as 39.49 Kenny
# &&&&&&&&&&
# 10.1 ETH be converted into as 8.74 Kenny
# &&&&&&&&&&
# 5.91 ETH be converted into as 5.11 Kenny
# &&&&&&&&&&
# 22.88 ETH be converted into as 19.8 Kenny
# The 98 round, BuyNum: 50 SellNum: 50
# &&&&&&&&&&
# 90.98 ETH be converted into as 78.66 Kenny
# &&&&&&&&&&
# 50.1 ETH be converted into as 43.28 Kenny
# &&&&&&&&&&
# 17.57 ETH be converted into as 15.17 Kenny
# **********
# 67.05 Kenny be converted out as 77.61 ETH
# **********
# 18.64 Kenny be converted out as 21.56 ETH
# &&&&&&&&&&
# 23.57 ETH be converted into as 20.37 Kenny
# &&&&&&&&&&
# 11.59 ETH be converted into as 10.01 Kenny
# &&&&&&&&&&
# 94.72 ETH be converted into as 81.81 Kenny
# &&&&&&&&&&
# 6.92 ETH be converted into as 5.97 Kenny
# &&&&&&&&&&
# 79.29 ETH be converted into as 68.41 Kenny
# **********
# 83.34 Kenny be converted out as 96.58 ETH
# &&&&&&&&&&
# 78.58 ETH be converted into as 67.81 Kenny
# &&&&&&&&&&
# 36.37 ETH be converted into as 31.37 Kenny
# &&&&&&&&&&
# 55.14 ETH be converted into as 47.53 Kenny
# **********
# 86.27 Kenny be converted out as 100.06 ETH
# &&&&&&&&&&
# 1.19 ETH be converted into as 1.03 Kenny
# **********
# 41.0 Kenny be converted out as 47.52 ETH
# &&&&&&&&&&
# 79.14 ETH be converted into as 68.27 Kenny
# **********
# 86.35 Kenny be converted out as 100.08 ETH
# **********
# 0.34 Kenny be converted out as 0.4 ETH
# **********
# 84.31 Kenny be converted out as 97.61 ETH
# &&&&&&&&&&
# 96.68 ETH be converted into as 83.51 Kenny
# **********
# 39.46 Kenny be converted out as 45.7 ETH
# **********
# 78.94 Kenny be converted out as 91.34 ETH
# **********
# 69.78 Kenny be converted out as 80.67 ETH
# **********
# 36.0 Kenny be converted out as 41.59 ETH
# &&&&&&&&&&
# 0.12 ETH be converted into as 0.11 Kenny
# &&&&&&&&&&
# 17.18 ETH be converted into as 14.87 Kenny
# **********
# 11.7 Kenny be converted out as 13.51 ETH
# **********
# 93.41 Kenny be converted out as 107.83 ETH
# &&&&&&&&&&
# 22.97 ETH be converted into as 19.91 Kenny
# **********
# 84.67 Kenny be converted out as 97.65 ETH
# &&&&&&&&&&
# 15.69 ETH be converted into as 13.61 Kenny
# &&&&&&&&&&
# 94.5 ETH be converted into as 81.92 Kenny
# &&&&&&&&&&
# 67.37 ETH be converted into as 58.35 Kenny
# **********
# 93.94 Kenny be converted out as 108.43 ETH
# **********
# 51.39 Kenny be converted out as 59.27 ETH
# **********
# 2.99 Kenny be converted out as 3.45 ETH
# &&&&&&&&&&
# 31.5 ETH be converted into as 27.32 Kenny
# &&&&&&&&&&
# 84.13 ETH be converted into as 72.92 Kenny
# **********
# 75.33 Kenny be converted out as 86.91 ETH
# &&&&&&&&&&
# 33.56 ETH be converted into as 29.1 Kenny
# **********
# 27.64 Kenny be converted out as 31.87 ETH
# **********
# 56.92 Kenny be converted out as 65.61 ETH
# &&&&&&&&&&
# 91.24 ETH be converted into as 79.14 Kenny
# &&&&&&&&&&
# 51.02 ETH be converted into as 44.22 Kenny
# &&&&&&&&&&
# 26.03 ETH be converted into as 22.55 Kenny
# &&&&&&&&&&
# 46.17 ETH be converted into as 39.98 Kenny
# The 99 round, BuyNum: 51 SellNum: 49

# %%
KennyCoin.printInfo()
# Out:
# ---------
# NAME: Kenny | RESERVE NAME: ETH CRR: 0.2
# PRICE: 2.07637843008
# SUPPLY: 360120.531037 | RESERVE BALANCE: 149549.300575
# BUDGET: 447746.502874

# %%
print failedBuy_rateTracker[6] ,failedSell_rateTracker[6], failed_rateTracker[6]
# Out:
# (0.38461538461538464, 6) (0.5, 6) (0.44, 6)

# %%
j = 0
failedBuyRate = []
failedSellRate = []
failedRate = []
myX = []
while j < TimeRound:
    myX.append(j)
    failedRate.append(failed_rateTracker[j][0])
    failedBuyRate.append(failedBuy_rateTracker[j][0])
    failedSellRate.append(failedSell_rateTracker[j][0])
    j = j + 1
x = np.asarray(myX)
y1 = np.asarray(failedRate)
y2 = np.asarray(failedBuyRate)
y3 = np.asarray(failedSellRate)
plt.plot(x,y1,'o-',color = 'navy',alpha = 0.8)
plt.title('Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Transaction', fontsize = 15)
plt.savefig('Failure/FailureRate-All.png', bbox_inches='tight')
plt.close()
plt.plot(x,y2,'o-',color = 'navy',alpha = 0.8)
plt.title('Buy Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Buy Transaction', fontsize = 15)
plt.savefig('Failure/FailureRate-Buy.png', bbox_inches='tight')
plt.close()
plt.plot(x,y3,'o-',color = 'navy',alpha = 0.8)
plt.title('Sell Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Sell Transaction', fontsize = 15)
plt.savefig('Failure/FailureRate-Sell.png', bbox_inches='tight')
plt.close()

# %%
print PriceTracker[101]
# Out:
# (3.7057318690059224, 1)

# %%
j = 0
PriceAllRound = []
my_Xall = []
while j < TimeRound:
    myX = []
    Price_eachRound = []
    i = 0
    while i < custNum:
        myX.append(i+1)
        Price_eachRound.append(PriceTracker[i+j*custNum][0])
        i = i + 1
    PriceAllRound.append(Price_eachRound[99])
    x = np.asarray(myX)
    y = np.asarray(Price_eachRound)
    plt.plot(x,y,'o',color = 'navy',alpha = 0.8)
    plt.title('Price Change in Round \"'+str(j)+'\"',fontsize = 25)
    plt.xlabel('Customer #',fontsize = 15)
    plt.ylabel('Price of Smart Token', fontsize = 15)
    plt.savefig('Price/PriceRound/Price_inRound'+str(j)+'.png', bbox_inches='tight')
    plt.close()
    my_Xall.append(j)
    print 'Round '+str(j)+' Over...'
    j = j + 1
allX = np.asarray(my_Xall)
ally = np.asarray(PriceAllRound)
plt.plot(allX,ally,'o',color = 'navy',alpha = 0.8)
plt.title('Price Change For All Round',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Price of Smart Token', fontsize = 15)
plt.savefig('Price/Price_Change.png', bbox_inches='tight')
plt.close()
# Out:
# Round 0 Over...
# Round 1 Over...
# Round 2 Over...
# Round 3 Over...
# Round 4 Over...
# Round 5 Over...
# Round 6 Over...
# Round 7 Over...
# Round 8 Over...
# Round 9 Over...
# Round 10 Over...
# Round 11 Over...
# Round 12 Over...
# Round 13 Over...
# Round 14 Over...
# Round 15 Over...
# Round 16 Over...
# Round 17 Over...
# Round 18 Over...
# Round 19 Over...
# Round 20 Over...
# Round 21 Over...
# Round 22 Over...
# Round 23 Over...
# Round 24 Over...
# Round 25 Over...
# Round 26 Over...
# Round 27 Over...
# Round 28 Over...
# Round 29 Over...
# Round 30 Over...
# Round 31 Over...
# Round 32 Over...
# Round 33 Over...
# Round 34 Over...
# Round 35 Over...
# Round 36 Over...
# Round 37 Over...
# Round 38 Over...
# Round 39 Over...
# Round 40 Over...
# Round 41 Over...
# Round 42 Over...
# Round 43 Over...
# Round 44 Over...
# Round 45 Over...
# Round 46 Over...
# Round 47 Over...
# Round 48 Over...
# Round 49 Over...
# Round 50 Over...
# Round 51 Over...
# Round 52 Over...
# Round 53 Over...
# Round 54 Over...
# Round 55 Over...
# Round 56 Over...
# Round 57 Over...
# Round 58 Over...
# Round 59 Over...
# Round 60 Over...
# Round 61 Over...
# Round 62 Over...
# Round 63 Over...
# Round 64 Over...
# Round 65 Over...
# Round 66 Over...
# Round 67 Over...
# Round 68 Over...
# Round 69 Over...
# Round 70 Over...
# Round 71 Over...
# Round 72 Over...
# Round 73 Over...
# Round 74 Over...
# Round 75 Over...
# Round 76 Over...
# Round 77 Over...
# Round 78 Over...
# Round 79 Over...
# Round 80 Over...
# Round 81 Over...
# Round 82 Over...
# Round 83 Over...
# Round 84 Over...
# Round 85 Over...
# Round 86 Over...
# Round 87 Over...
# Round 88 Over...
# Round 89 Over...
# Round 90 Over...
# Round 91 Over...
# Round 92 Over...
# Round 93 Over...
# Round 94 Over...
# Round 95 Over...
# Round 96 Over...
# Round 97 Over...
# Round 98 Over...
# Round 99 Over...

# %%
# example of using smartcoin class
BNTCoin = Smartcoin(name='BNT',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=300000)
BNTCoin.printInfo()
BNTCoin.purchasing(300)
BNTCoin.printInfo()
BNTCoin.purchasing(700)
BNTCoin.printInfo()
BNTCoin.destroying(1302)
BNTCoin.printInfo()
BNTCoin.purchasing(100)
BNTCoin.printInfo()
# Out:
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 1.0
# SUPPLY: 300000.0 | RESERVE BALANCE: 60000.0
# BUDGET: 0.0
# *********
# 300.0 ETH be converted into as 299.4 BNT
# Current prize of BNT is 1.00399800399 with 0.3998 % increasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 1.00399800399
# SUPPLY: 300299.401794 | RESERVE BALANCE: 60300.0
# BUDGET: 1500.0
# *********
# 700.0 ETH be converted into as 694.0 BNT
# Current prize of BNT is 1.01331125792 with 0.9276 % increasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 1.01331125792
# SUPPLY: 300993.399232 | RESERVE BALANCE: 61000.0
# BUDGET: 5000.0
# *********
# 1302.0 BNT be converted out as 1307.97 ETH
# Current prize of BNT is 0.995891667702 with 1.7191 % decreasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 0.995891667702
# SUPPLY: 299691.399232 | RESERVE BALANCE: 59692.0334754
# BUDGET: -1539.83262295
# *********
# 100.0 ETH be converted into as 100.35 BNT
# Current prize of BNT is 0.997226150558 with 0.134 % increasing.
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 0.997226150558
# SUPPLY: 299791.74454 | RESERVE BALANCE: 59792.0334754
# BUDGET: -1039.83262295

# %%
# test for customers class
Alice = Customers(smartToken=KennyCoin)
print 'Current Price of KennyCoin: ', round(KennyCoin.getPrice(),4)
Alice.purchase(100)
print 'Current Price of KennyCoin: ', round(KennyCoin.getPrice(),4)
# Out:
# Current Price of KennyCoin:  1.0067
# *********
# 100.0 ETH be converted into as 99.27 Kenny
# Current prize of Kenny is 1.00799203183 with 0.1322 % increasing.
# Current Price of KennyCoin:  1.008
