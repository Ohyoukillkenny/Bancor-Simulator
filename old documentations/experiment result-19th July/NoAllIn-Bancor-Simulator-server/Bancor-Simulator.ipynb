# %%
import random
import numpy as np
import sys
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
# Out:
# /Users/konglingkun/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
class Smartcoin(object):
    '''
    _Name: Name of Smart token
    _ReservetokenName: Name of Reserve Token
    _CRR: CRR
    _Price: the current Price of smart token
    _Supply: the number of issued smart tokens
    _ReserveBalance: the balance of the reserve pool
    '''
    def __init__(self, name='kennycoin', reservetokenName='aCoin', initCRR=0.5, initPrice=1.0, initIssueNum=100):
        self._Name = name
        self._ReservetokenName = reservetokenName
        self._CRR = initCRR
        self._Price = initPrice
        self._Supply = float(initIssueNum)
        self._ReserveBalance = float(initCRR*initIssueNum)

        # _initPrice is used to set the init Price of Market
        self._initPrice = initPrice

    def printInfo(self):
        print '---------'
        print 'NAME:', self._Name, '| RESERVE NAME:', self._ReservetokenName, 'CRR:', self._CRR
        print 'PRICE:',self._Price
        print 'SUPPLY:', self._Supply, '| RESERVE BALANCE:', self._ReserveBalance

    def saveInfo(self, fw):
        fw.write('---------\n')
        fw.write('NAME: '+str(self._Name)+' | RESERVE NAME: '+str(self._ReservetokenName) + ' | CRR: '+str(self._CRR)+'\n')
        fw.write('PRICE: '+str(self._Price))
        fw.write('SUPPLY: '+str(self._Supply)+' | RESERVE BALANCE: '+str(self._ReserveBalance)+'\n')
        
    def getInitPrice(self):
        return self._initPrice

    def updatePrice(self, reserveBalance, supply, CRR):
        newPrice = reserveBalance / (supply * CRR)
        return newPrice
    
    def setCRR(self, newCRR = 0.5):
        oldCRR = self._CRR
        self._CRR = newCRR
        print 'CRR', oldCRR, '->', newCRR

    def getPrice(self):
        return self._Price

    def purchasing(self, convertIntoNum=0):
        # E.g., ETH be convert into BNT, convertInto Num
        issuedtokenNum = round( self._Supply * (((self._ReserveBalance + convertIntoNum)/self._ReserveBalance)**(self._CRR) - 1) )
        self._Supply = self._Supply + issuedtokenNum
        self._ReserveBalance = self._ReserveBalance + convertIntoNum
        # Update the price after purchasing, e.g. ETH is converted into BNT (cust uses eth to buy bnt)
        oldPrice = self._Price
        self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
        increaseRatio = (self._Price - oldPrice)/oldPrice
        return int(issuedtokenNum)

    def destroying(self, convertOutNum=0):
        # E.g., BNT be converted out to ETH, convertOutNum is BNT's num
        destroyedtokenNum = convertOutNum
        reserveReceivedNum = round(self._ReserveBalance*(1 - ((self._Supply - convertOutNum) / self._Supply) ** (1/self._CRR)))
        self._Supply = self._Supply - destroyedtokenNum
        self._ReserveBalance = self._ReserveBalance - reserveReceivedNum
        # Update the price after destroying, e.g. BNT is converted into ETH (cust sells bnt to get eth)
        oldPrice = self._Price
        self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
        decreaseRatio = (oldPrice-self._Price)/oldPrice
        return int(reserveReceivedNum)

# def smarttoken_main():
#     ''' 
#     This part is consistent with the example offered by white paper, 
#         which shows our codes realize the idea of Bancor according to its white paper.
#     '''
#     BNTCoin = Smartcoin(name='BNT',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=300000)
#     BNTCoin.printInfo()
#     print BNTCoin.destroying(300)
#     print BNTCoin.purchasing(300)
#     print BNTCoin.purchasing(700)
#     BNTCoin.printInfo()
#     print BNTCoin.destroying(1302)
#     BNTCoin.printInfo()
#     print BNTCoin.purchasing(100)
#     BNTCoin.printInfo()

# if __name__ == '__main__':
#     smarttoken_main()

# %%
class Customer(object):
    '''
    _smartToken: class of the token customers want to buy or sell -- SmartToken()
    _market: instance of the market customers buy or sell 
    _tokenBalance: number of smart tokens a customer has
    _reserveBalance: number of reserve tokens a customer has
    _valuation: how much money customers are willing to finish the transaction
    _originalCash: original money cust has
    _cash: net profit or loss to date
    _timeslot: the time slot when customers want to make transactions, 
               and in every timeslot, we should set customers' time slot like: XXX.SetTimeSlot(time)
    '''
    def __init__(self, smartToken, market ,tokenBalance = 0, reserveBalance = 0, valuation = 0.0):
        self._smartToken = smartToken
        self._market = market
        self._tokenBalance = tokenBalance
        self._reserveBalance = reserveBalance
        self._originalCash = float(self._reserveBalance + self._tokenBalance * self._smartToken.getPrice())
        self._cash = 0.0
        self._valuation = valuation
        self._timeslot = None

        self._BUY = 1
        self._SELL = -1
        self._ERROR = -2
        self._TransactionFailed = -1

    def printInfo(self):
        currentCash = float(self._smartToken.getPrice() * self._tokenBalance + self._reserveBalance)
        self._cash = currentCash - self._originalCash
        print '------'
        print 'smartToken Name:', self._smartToken._Name, '| valuation:', self._valuation
        print 'reserveBalance:', self._reserveBalance, '| tokenBalance:', self._tokenBalance

    # def SetTimeSlot(self, timeslot):
    #     self._timeslot = timeslot

    def getReserveBalance(self):
        return self._reserveBalance

    def changeReserveBalance(self, changeValue):
        self._reserveBalance = self._reserveBalance + changeValue

    def getTokenBalance(self):
        return self._tokenBalance

    def changeTokenBalance(self, changeValue):
        self._tokenBalance = self._tokenBalance + changeValue

    def getCash(self):
        currentCash = float(self._smartToken.getPrice() * self._tokenBalance + self._reserveBalance)
        self._cash = currentCash - self._originalCash
        return self._cash

    def getValuation(self):
        return self._valuation

    # change the valuation, if customer has a new valuation, he will generate a new transaction request, 
    # and market will give responce for this request
    def changeValuation(self, newValuation):
        self._valuation = newValuation
        '''
        Cancel the previous order in market's orderlist.
        If the previous order succeeds in the market, this function call will cancel nothing.
        '''
        self._market.cancelOrder(self)
        '''
        What getCurrentPrice() returns in Bancor market should be different with the real time price of Smart Token. 
        This is because since every time slot many customers come into the market simultaneously, 
            what they see is the final price at the end of previous time slot.
        '''
        if self._valuation > self._market.getCurrentPrice() and self._reserveBalance > 0:
            # XXX issues a buy order 
            self._market.buy(self, self._reserveBalance)
        elif self._valuation < self._market.getCurrentPrice() and self._tokenBalance > 0:
            # XXX issue a sell order
            self._market.sell(self, self._tokenBalance)
        else:
            # nothing to do
            pass

# def cust_main():
    
#     KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1.0, initIssueNum=300000)
    
#     # test for Bancor Market
#     market1 = BancorMarket(smartToken = KennyCoin)
#     Alice = Customer(smartToken=KennyCoin, market=market1, tokenBalance=200, reserveBalance=100)
#     market1.sychronize(0)
#     Alice.printInfo()
#     Alice.changeValuation(1.5)
#     Alice.printInfo()
#     KennyCoin.printInfo()
#     Alice.changeValuation(0.9)
#     Alice.printInfo()
#     KennyCoin.printInfo()
#     print market1.getCanceledTransactionNum() , 'being canceled.'

#     # test for Classic Market
#     market2 = ClassicMarket(smartToken = KennyCoin)
#     Alice = Customer(smartToken=KennyCoin, market=market2, tokenBalance=200, reserveBalance=100)
#     Bob = Customer(smartToken=KennyCoin, market=market2, tokenBalance=305, reserveBalance=333)
#     market2.sychronize(0)
#     Alice.changeValuation(1.5)
#     Alice.printInfo()
#     Bob.changeValuation(1.6)
#     Bob.changeValuation(0.7)
#     Alice.printInfo()
#     Bob.printInfo()
#     Alice.changeValuation(1.4)
#     print market2.getCanceledTransactionNum(), 'being canceled.'
#     print market2.getTotallyFailedTransactionNum(), 'Totally failed.'

# if __name__ == '__main__':
#     cust_main()

# %%
class BancorMarket(object):
    def __init__(self, smartToken):
        self._smartToken = smartToken
        # Order format: [cust, transactionValue, buy_or_sell]
        self._OrderList = []
        self._CurrentPrice = smartToken.getInitPrice()
        self._timeList = []
        self._time = 0

        self._BUY = 1
        self._SELL = -1
        self._ERROR = -2

        # parameters for plotting: txNum and canceledTxNum are reset to 0 in the beginning of every time slot:
        self._transactionNum = 0
        self._canceledTransactionNum = 0

    '''
    To tell market new time slot is coming, 
        and the currentPrice market offers to customers should be different from the previous one.
    '''
    def sychronize(self, timeSlot):
        self._time = timeSlot
        self._transactionNum = 0
        self._canceledTransactionNum = 0

    # what getCurrentPrice() returns in Bancor market should be different with the real time price of Smart Token. 
    # This is because since every time slot many customers come into the market simultaneously, 
    # what they see is the final price at the end of previous time slot
    def getCurrentPrice(self):
        if self._time in self._timeList:
            return self._CurrentPrice
        else:
            self._timeList.append(self._time)
            self._CurrentPrice = self._smartToken.getPrice()
            return self._CurrentPrice

    def cancelOrder(self, cust):
        # Order format: [cust, transactionValue, buy_or_sell]
        for s in range(len(self._OrderList)):
            if self._OrderList[s][0] is cust:
                self._canceledTransactionNum = self._canceledTransactionNum + 1
                self._OrderList.pop(s)
                break
    '''
    Becuase in Bancor Market, after every transaction, the price of smart token will be changed.
    Update the orderlist by recursion after every time transaction being made is too time-comsuming.
    Here, we just scan the orderlist once if the price being changed. 
        E.g., every time the price of token changes, we will sequence through the orderlist to see whether some orders can be satisfied.
    And this method offers almost same accuracy with recursion function.
    '''
    def updateOrderList(self):
        s = 0
        while s < len(self._OrderList):
            if ((self._OrderList[s][2] == self._BUY) and (self._OrderList[s][0].getValuation()>=self._smartToken.getPrice()) ):
                receivedSmartTokens = self._smartToken.purchasing(self._OrderList[s][1])
                self._OrderList[s][0].changeReserveBalance(-self._OrderList[s][1])
                self._OrderList[s][0].changeTokenBalance(receivedSmartTokens)
                self._OrderList.pop(s)
                s = s - 1
            elif ((self._OrderList[s][2] == self._SELL) and (self._OrderList[s][0].getValuation()<=self._smartToken.getPrice()) ):
                receivedReserveTokens = self._smartToken.destroying(self._OrderList[s][1])
                self._OrderList[s][0].changeReserveBalance(receivedReserveTokens)
                self._OrderList[s][0].changeTokenBalance(-self._OrderList[s][1])
                self._OrderList.pop(s)
                s = s - 1
            else:
                # nothing to do
                pass
            s = s + 1
    '''
    use #Transaction_Value reserveTokens to buy smartTokens -> smartToken price increase
    call smartTokens.purchasing() function
    '''
    def buy(self, cust, Transaction_Value):
        self._transactionNum = self._transactionNum + 1
        if Transaction_Value < 0:
            print '** ERROR, cannot buy with negative number of reserveToken'
        if not isinstance(Transaction_Value,int):
            print '** ERROR, should use integer number of reserveTokens to buy', Transaction_Value
        if cust.getValuation() >= self._smartToken.getPrice():
            receivedSmartTokens = self._smartToken.purchasing(Transaction_Value)
            cust.changeReserveBalance(-Transaction_Value)
            cust.changeTokenBalance(receivedSmartTokens)
            '''
            Since the price of smart token is changed, maybe some transaction requests in orderlist is now acceptable, 
                we need to update the OrderList Now.
            '''
            self.updateOrderList()
        else:
            # add buy order into orderlist
            self._OrderList.append([cust, Transaction_Value, self._BUY])
            
        
    '''
    sell #Transaction_Value smartTokens to get reserveTokens -> smartToken price decrease
    call smartTokens.destroying() function
    '''
    def sell(self, cust, Transaction_Value):
        self._transactionNum = self._transactionNum + 1
        if Transaction_Value < 0:
            print '** ERROR, cannot sell negative number of smartToken'
        if not isinstance(Transaction_Value,int):
            print '** ERROR, should use integer number of smartTokens to sell', Transaction_Value
        if cust.getValuation() <= self._smartToken.getPrice():
            receivedReserveTokens = self._smartToken.destroying(Transaction_Value)
            cust.changeReserveBalance(receivedReserveTokens)
            cust.changeTokenBalance(-Transaction_Value)
            '''
            Since the price of smart token is changed, maybe some transaction requests in orderlist is now acceptable, 
                we need to update the OrderList Now.
            '''
            self.updateOrderList()
        else:
            # add sell order into orderlist
            self._OrderList.append([cust, Transaction_Value, self._SELL])

    # functions for plotting
    def getTransactionNum(self):
        return self._transactionNum
        
    def getCanceledTransactionNum(self):
        return self._canceledTransactionNum



'''
Custmers give their orders to Classic Market. Market will process these orders.
Once customers' orders come into market, market will update the order list.
And if customers want to change their valuation, their old orders will be canceled, 
  which means the order is failed (or partially failed -- 
  e.g. Customer XXX generates a sell order of 100 tokens, he successfully sells 50, but still 50 remaining in orderlist)
In Classic Market, the price of smart token will not change, but the customers' valuations will change.
'''
class ClassicMarket(object):
    def __init__(self, smartToken):
        self._smartToken = smartToken
        # Order format: [cust, transactionValue, buy_or_sell]
        self._OrderList = []
        self._CurrentPrice = smartToken.getInitPrice()

        self._BUY = 1
        self._SELL = -1
        self._ERROR = -2

        # parameters for plotting:
        self._transactionNum = 0
        self._canceledTransactionNum = 0
        self._totallyFailedTransactionNum = 0
        self._ChangedOrderList = []


    '''
    Reset plotting parameters.
    '''
    def sychronize(self, timeSlot = 0):
        self._transactionNum = 0
        self._canceledTransactionNum = 0
        self._totallyFailedTransactionNum = 0

    def getCurrentPrice(self):
        return self._CurrentPrice

    def cancelOrder(self, cust):
        # Order format: [cust, transactionValue, buy_or_sell]
        for s in range(len(self._OrderList)):
            if self._OrderList[s][0] is cust:
                self._canceledTransactionNum = self._canceledTransactionNum + 1
                if cust not in self._ChangedOrderList:
                    self._totallyFailedTransactionNum = self._totallyFailedTransactionNum + 1
                else:
                    # Since the order will be canceled, the customer should be removed from ChangedOrderList.
                    self._ChangedOrderList.pop(self._ChangedOrderList.index(cust))
                self._OrderList.pop(s)
                break

    def updateOrderList(self, newOrder):
        cust = newOrder[0]
        custValuation = cust.getValuation()
        transactionValue =  newOrder[1]
        buy_or_sell = newOrder[2]

        # If the orderlist is empty, just add the new order into list
        if len(self._OrderList) == 0:
            self._OrderList.append(newOrder)
            return
        '''
        Buyer comes into the market, scan the market seller, find sellers who offers the valuation smaller than his valuation:
            If none of the sellers offers smaller valuation, push new order into list, return
            If there do exist some sellers, save [seller's valuation, seller, seller's index in orderList] into a seller list, 
            and sorted by sellers' valuations from small to large. 
            Then, buyer will try to make transaction with the seller in list one by one:
            Loop:
                if the buyer's demand can be satisfied by seller:
                    update the buyer's info in customer class,
                    update the seller's info in customer class, 
                    update the seller's info in order list. 
                    return
                if the buyer's demand can not be fully satisfied by seller:
                    update the buyer's info in customer class,
                    decrease buyer's demand
                    update the seller's info in customer class,
                    pop the seller out of order list
                    update other sellers in seller list's index info since one seller is poped out of orderlist 
            if buyer's demand still > 0:
                push buyer's remaining demand into order list
            else:
                just return, since the buyer's demand is satisfied by transaction

        Same thing goes with seller. But for seller, the buyer list should be sorted from high valuation to low valuation
        '''
        sellerList = []
        buyerList = []
        if buy_or_sell == self._BUY:
            for s in range(len(self._OrderList)):
                if self._OrderList[s][2] == self._SELL and custValuation >= self._OrderList[s][0].getValuation():
                    sellerValuation = self._OrderList[s][0].getValuation()
                    seller = self._OrderList[s][0]
                    # sellerList format: [valuation, seller, index of seller in orderList]
                    sellerList.append([sellerValuation,seller,s])

            if len(sellerList) == 0:
                self._OrderList.append(newOrder)
                return
            else:
                sorted(sellerList, key=lambda sellerOrders: sellerOrders[0]) # sorted from low to high

            for t in range(len(sellerList)):
                sellerValuation = sellerList[t][0]
                seller = sellerList[t][1]
                indexInOrderList = sellerList[t][2]
                sellerMaxCouldSatisfy = int(self._OrderList[indexInOrderList][1] * sellerValuation)
                if transactionValue < sellerMaxCouldSatisfy:
                    cust.changeReserveBalance(-transactionValue)
                    cust.changeTokenBalance(int(transactionValue/sellerValuation))
                    seller.changeReserveBalance(transactionValue)
                    seller.changeTokenBalance(-int(transactionValue/sellerValuation))
                    self._OrderList[indexInOrderList][1] -= int(transactionValue/sellerValuation)
                    if seller not in self._ChangedOrderList:
                        # to count whether cust's order is totally failed
                        self._ChangedOrderList.append(seller)
                    break # cust's order is satisfied
                else: 
                # seller cannot satisfy buyer's need, transactionValue >= sellerMaxCouldSatisfy
                    cust.changeReserveBalance(-sellerMaxCouldSatisfy)
                    cust.changeTokenBalance(self._OrderList[indexInOrderList][1])
                    transactionValue -= sellerMaxCouldSatisfy
                    seller.changeReserveBalance(sellerMaxCouldSatisfy)
                    seller.changeTokenBalance(-self._OrderList[indexInOrderList][1])
                    self._OrderList.pop(indexInOrderList)
                    for item in sellerList:
                        if item[2] > indexInOrderList:
                            # update index info, since one seller is poped out from orderList
                            item[2] -= 1

            if transactionValue < 0:
                print '** Error, buyer buys too much in market class'
            elif transactionValue == 0:
                return
            else:
                # transactionValue > 0
                newOrder[1] = transactionValue
                self._OrderList.append(newOrder)
        else:
            # buy_or_sell == self._SELL
            for s in range(len(self._OrderList)):
                if self._OrderList[s][2] == self._BUY and custValuation <= self._OrderList[s][0].getValuation():
                    buyerValuation = self._OrderList[s][0].getValuation()
                    buyer = self._OrderList[s][0]
                    # buyerList format: [valuation, buyer, index of buyer in orderList]
                    buyerList.append([buyerValuation,buyer,s])

            if len(buyerList) == 0:
                self._OrderList.append(newOrder)
                return
            else:
                # sorted from high to low
                sorted(sellerList, key=lambda sellerOrders: sellerOrders[0], reverse=True) 

            for t in range(len(buyerList)):
                buyerValuation = buyerList[t][0]
                buyer = buyerList[t][1]
                indexInOrderList = buyerList[t][2]
                buyerMaxCouldBuy = int(self._OrderList[indexInOrderList][1] / buyerValuation)
                if transactionValue < buyerMaxCouldBuy:
                    cust.changeReserveBalance(int(transactionValue * buyerValuation))
                    cust.changeTokenBalance(-transactionValue)
                    buyer.changeReserveBalance(-int(transactionValue * buyerValuation))
                    buyer.changeTokenBalance(transactionValue)
                    self._OrderList[indexInOrderList][1] -= int(transactionValue * buyerValuation)
                    if buyer not in self._ChangedOrderList:
                        # to count whether cust's order is totally failed
                        self._ChangedOrderList.append(buyer)
                    break # cust's order is satisfied
                else:
                    # buyer cannot satisfy the seller's need, transactionValue >= buyerMaxCouldBuy
                    cust.changeReserveBalance(self._OrderList[indexInOrderList][1])
                    cust.changeTokenBalance(-buyerMaxCouldBuy)
                    transactionValue -= buyerMaxCouldBuy
                    buyer.changeReserveBalance(-self._OrderList[indexInOrderList][1])
                    buyer.changeTokenBalance(buyerMaxCouldBuy)
                    self._OrderList.pop(indexInOrderList)
                    for item in buyerList:
                        if item[2] > indexInOrderList:
                            # update index info, since one buyer is poped out from orderList
                            item[2] -= 1 

            if transactionValue < 0:
                print '** Error, Seller sells too much in market class'
            elif transactionValue == 0:
                return
            else:
                # transactionValue > 0
                newOrder[1] = transactionValue
                self._OrderList.append(newOrder)

    '''
    use #Transaction_Value reserveTokens to buy smartTokens -> smartToken price increase
    call smartTokens.purchasing() function
    '''
    def buy(self, cust, Transaction_Value):
        self.updateOrderList([cust, Transaction_Value, self._BUY])
        self._transactionNum = self._transactionNum + 1
        
    '''
    sell #Transaction_Value smartTokens to get reserveTokens -> smartToken price decrease
    call smartTokens.destroying() function
    '''
    def sell(self, cust, Transaction_Value):
        self.updateOrderList([cust, Transaction_Value, self._SELL])
        self._transactionNum = self._transactionNum + 1

    # functions for plotting
    def getTransactionNum(self):
        return self._transactionNum
        
    def getCanceledTransactionNum(self):
        return self._canceledTransactionNum

    def getTotallyFailedTransactionNum(self):
        return self._totallyFailedTransactionNum

# %%
# Main function call for Bancor Market Simulating
# the Bancor Market has to be sychronized in every different time slot
def sychronizeMarket(market, timeSlot):
    market.sychronize(timeSlot)

# issue a new smart token
initIssue = 3000000
CRR = 0.2
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=initIssue)

# create two different markets
MyBancorMarket = BancorMarket(smartToken = KennyCoin)

TimeSlotNum = 1000
bouncingInterval = 200
bouncingRange = 10.0
custNum = 2000
sigma = 0.1

# the seeds of pseudo-random numbers
mySeeds = [0,1,2,3,4]

for mySeed in mySeeds:
    np.random.seed(mySeed)
    myfw = open('Result/Bancor/T-'+str(TimeSlotNum)+'BI-'+str(bouncingInterval)+
        'BG-'+str(bouncingRange)+'CN-'+str(custNum)+'Sig-'+str(sigma)+'Seed-'+str(mySeed)+'.txt', 'w')

    '''
    First of all, we initialize the customer's tokenBalance and reserveBalance 
    by Gaussian distributed random number (mu = 200, sigma = 0.1)
    '''
    custInitReserveBalance_mu = 200
    custInitTokenBalance_mu = 200
    custInitReserveBalance_list = np.random.normal(custInitReserveBalance_mu, 0.1, custNum) # 0.5 is sigma
    custInitTokenBalance_list = np.random.normal(custInitTokenBalance_mu, 0.1, custNum) # 0.5 is sigma

    if sum(custInitTokenBalance_list) > (initIssue * (1 - CRR)):
        print 'ERROR, too many init smart tokens holding by customers.'
        sys.exit(0)

    custList = []
    # here we name single customer as Joe. And every customer is initialized with 
    # random value of token balance as well as reserve balance.
    for i in range(custNum):
        Joe = Customer(smartToken = KennyCoin, market = MyBancorMarket, 
                        tokenBalance = int(custInitTokenBalance_list[i]), 
                        reserveBalance = int(custInitReserveBalance_list[i]))
        custList.append(Joe)

    # cashTracker records custmers' cash
    # cashTracker = []
    # priceTracker records the change of the smart token's price in Bancor market
    priceTracker = []
    # transaction tracker records the transations' number in each time slot
    txTracker = []
    # canceled transaction tracker records the canceled transactions' number in each time slot
    canceledTxTracker = []

    for j in range(TimeSlotNum):
        # Sychronize the market
        sychronizeMarket(MyBancorMarket, j)

        # we assume that in every time slot, all customers change their valuation
        currentMarketPrice = MyBancorMarket.getCurrentPrice()
        if (j > 0) and (j % bouncingInterval == 0):
            ''' 
            We assume the valuation_mu is generated by random, which denotes the mean valuation
            of customers when the good or bad news comes into market on a certain time slot,
            which is divided by bouncing interval.
            '''
            valuation_mu = random.uniform(currentMarketPrice/bouncingRange, currentMarketPrice*bouncingRange)
        else:
            valuation_mu = currentMarketPrice

        custValuation_list = np.random.normal(valuation_mu, sigma, custNum)
        for i in range(custNum):
            if custValuation_list[i] < 0:
                # Customer does not want to sell their token in free. 
                # Here we give them a small valuation when valuation < 0
                custList[i].changeValuation(0.001*currentMarketPrice)
            else:
                custList[i].changeValuation(custValuation_list[i])

        priceTracker.append(KennyCoin.getPrice())
        txTracker.append(MyBancorMarket.getTransactionNum())
        canceledTxTracker.append(MyBancorMarket.getCanceledTransactionNum())

        # show some information in terminal
        print ('In time slot:'+str(j)+' | '+str(MyBancorMarket.getTransactionNum())+
            ' happens. And '+str(MyBancorMarket.getCanceledTransactionNum())+' transactions are canceled.')
        myfw.write(str(j)+'\t'+str(MyBancorMarket.getTransactionNum())+'\t'+
                    str(MyBancorMarket.getCanceledTransactionNum())+'\n')
    myfw.close()

    '''Plotting'''

    # Figure about price changing
    pricePlot = []
    myX_P = []
    for j in range(TimeSlotNum):
        pricePlot.append(priceTracker[j])
        myX_P.append(j)
        j = j + 1
    x_P = np.asarray(myX_P)
    y_P = np.asarray(pricePlot)
    plt.plot(x_P, y_P, 'o-',color = 'navy', alpha = 0.8)
    plt.title('Price Change For Bancor Market',fontsize = 25)
    plt.xlabel('Time Slot #',fontsize = 15)
    plt.ylabel('Price of Smart Token', fontsize = 15)
    plt.savefig('Figures/Bancor/Price-Seed-'+str(mySeed)+'.png', bbox_inches='tight')
    plt.close()

    # Figure about transactions
    txPlot = []
    myX_T = []
    for j in range(TimeSlotNum):
        txPlot.append(txTracker[j])
        myX_T.append(j)
        j = j + 1
    x_T = np.asarray(myX_T)
    y_T = np.asarray(txPlot)
    plt.plot(x_T, y_T, 'o-',color = 'navy', alpha = 0.8)
    plt.title('Transaction Num For Bancor Market',fontsize = 25)
    plt.xlabel('Time Slot #',fontsize = 15)
    plt.ylabel('Transaction #', fontsize = 15)
    plt.savefig('Figures/Bancor/Transactions-Seed-'+str(mySeed)+'.png', bbox_inches='tight')
    plt.close()

    # Figure about canceled transactions
    canceledTxPlot = []
    myX_C = []
    for j in range(TimeSlotNum):
        canceledTxPlot.append(canceledTxTracker[j])
        myX_C.append(j)
        j = j + 1
    x_C = np.asarray(myX_C)
    y_C = np.asarray(canceledTxPlot)
    plt.plot(x_C, y_C, 'o-',color = 'navy', alpha = 0.8)
    plt.title('Canceled Transaction Num For Bancor Market',fontsize = 25)
    plt.xlabel('Time Slot #',fontsize = 15)
    plt.ylabel('Canceled Transaction #', fontsize = 15)
    plt.savefig('Figures/Bancor/CanceledTx-Seed-'+str(mySeed)+'.png', bbox_inches='tight')
    plt.close()

    fw_trax = open('Result/Bancor/Tx_T-'+str(TimeSlotNum)+'BI-'+str(bouncingInterval)+
        'BG-'+str(bouncingRange)+'CN-'+str(custNum)+'Sig-'+str(sigma)+'Seed-'+str(mySeed)+'.txt', 'w')
    fw_trax.write('All_Tx:'+'\t'+str(sum(txTracker))+'\tCanceled:'+'\t'+str(sum(canceledTxTracker)))
    fw_trax.close()

# %%
# Main function call for Classic Market simulating
# the Classic Market has to be sychronized in every different time slot
def sychronizeMarket(market, timeSlot):
    market.sychronize(timeSlot)

# issue a new smart token
initIssue = 3000000
CRR = 0.2
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=initIssue)

# create two different markets
MyClassicMarket = ClassicMarket(smartToken = KennyCoin)

TimeSlotNum = 1000
bouncingInterval = 200
bouncingRange = 10.0
custNum = 2000
sigma = 0.1

# the seeds of pseudo-random numbers
mySeeds = [0,1,2,3,4]

for mySeed in mySeeds:
    np.random.seed(mySeed)
    myfw = open('Result/Classic/T-'+str(TimeSlotNum)+'BI-'+str(bouncingInterval)+
        'BG-'+str(bouncingRange)+'CN-'+str(custNum)+'Sig-'+str(sigma)+'Seed-'+str(mySeed)+'.txt', 'w')

    '''
    First of all, we initialize the customer's tokenBalance and reserveBalance 
    by Gaussian distributed random number (mu = 200, sigma = 0.1)
    '''
    custInitReserveBalance_mu = 200
    custInitTokenBalance_mu = 200
    custInitReserveBalance_list = np.random.normal(custInitReserveBalance_mu, 0.1, custNum) # 0.5 is sigma
    custInitTokenBalance_list = np.random.normal(custInitTokenBalance_mu, 0.1, custNum) # 0.5 is sigma

    if sum(custInitTokenBalance_list) > (initIssue * (1 - CRR)):
        print 'ERROR, too many init smart tokens holding by customers.'
        sys.exit(0)

    custList = []
    # here we name single customer as Joe. And every customer is initialized with 
    # random value of token balance as well as reserve balance.
    for i in range(custNum):
        Joe = Customer(smartToken = KennyCoin, market = MyClassicMarket, 
                        tokenBalance = int(custInitTokenBalance_list[i]), 
                        reserveBalance = int(custInitReserveBalance_list[i]))
        custList.append(Joe)

    # cashTracker records custmers' cash
    # cashTracker = []
    # transaction tracker records the transations' number in each time slot
    txTracker = []
    # canceled transaction tracker records the canceled transactions' number in each time slot
    canceledTxTracker = []
    # failed transaction tracker records the totally failed transactions' number in each time slot
    failedTxTracker = []

    for j in range(TimeSlotNum):

        # Sychronize the market
        sychronizeMarket(MyClassicMarket, j)

        # we assume that in every time slot, all customers change their valuation
        currentMarketPrice = MyClassicMarket.getCurrentPrice()
        if (j > 0) and (j % bouncingInterval == 0):
            ''' 
            We assume the valuation_mu is generated by random, which denotes the mean valuation
            of customers when the good or bad news comes into market on a certain time slot,
            which is divided by bouncing interval.
            '''
            valuation_mu = random.uniform(currentMarketPrice/bouncingRange, currentMarketPrice*bouncingRange)
        else:
            valuation_mu = currentMarketPrice

        custValuation_list = np.random.normal(valuation_mu, sigma, custNum)
        for i in range(custNum):
            if custValuation_list[i] < 0:
                # Customer does not want to sell their token in free. 
                # Here we give them a small valuation when valuation < 0
                custList[i].changeValuation(0.001*currentMarketPrice)
            else:
                custList[i].changeValuation(custValuation_list[i])

        txTracker.append(MyClassicMarket.getTransactionNum())
        canceledTxTracker.append(MyClassicMarket.getCanceledTransactionNum())
        failedTxTracker.append(MyClassicMarket.getTotallyFailedTransactionNum())

        # show some information in terminal
        print ('In time slot:'+str(j)+' | '+str(MyClassicMarket.getTransactionNum())+
            ' happens. And '+str(MyClassicMarket.getCanceledTransactionNum())+' transactions are canceled. | And '+
            str(MyClassicMarket.getTotallyFailedTransactionNum())+' totally failed.')
        myfw.write(str(j)+'\t'+str(MyClassicMarket.getTransactionNum())+'\t'+
                    str(MyClassicMarket.getCanceledTransactionNum())+'\t'+
                    str(MyClassicMarket.getTotallyFailedTransactionNum())+'\n')
    myfw.close()
    
    '''Plotting'''

    # Figure about transactions
    txPlot = []
    myX_T = []
    for j in range(TimeSlotNum):
        txPlot.append(txTracker[j])
        myX_T.append(j)
        j = j + 1
    x_T = np.asarray(myX_T)
    y_T = np.asarray(txPlot)
    plt.plot(x_T, y_T, 'o-',color = 'navy', alpha = 0.8)
    plt.title('Transaction Num For Classic Market',fontsize = 25)
    plt.xlabel('Time Slot #',fontsize = 15)
    plt.ylabel('Transaction #', fontsize = 15)
    plt.savefig('Figures/Classic/Transactions-Seed-'+str(mySeed)+'.png', bbox_inches='tight')
    plt.close()

    # Figure about canceled transactions
    canceledTxPlot = []
    myX_C = []
    for j in range(TimeSlotNum):
        canceledTxPlot.append(canceledTxTracker[j])
        myX_C.append(j)
        j = j + 1
    x_C = np.asarray(myX_C)
    y_C = np.asarray(canceledTxPlot)
    plt.plot(x_C, y_C, 'o-',color = 'navy', alpha = 0.8)
    plt.title('Canceled Transaction Num For Classic Market',fontsize = 25)
    plt.xlabel('Time Slot #',fontsize = 15)
    plt.ylabel('Canceled Transaction #', fontsize = 15)
    plt.savefig('Figures/Classic/CanceledTx-Seed-'+str(mySeed)+'.png', bbox_inches='tight')
    plt.close()

    # Figure about failed transactions
    failedTxPlot = []
    myX_F = []
    for j in range(TimeSlotNum):
        failedTxPlot.append(failedTxTracker[j])
        myX_F.append(j)
        j = j + 1
    x_F = np.asarray(myX_F)
    y_F = np.asarray(failedTxPlot)
    plt.plot(x_F, y_F, 'o-',color = 'navy', alpha = 0.8)
    plt.title('Failed Transaction Num For Classic Market',fontsize = 25)
    plt.xlabel('Time Slot #',fontsize = 15)
    plt.ylabel('Failed Transaction #', fontsize = 15)
    plt.savefig('Figures/Classic/FailedTx-Seed-'+str(mySeed)+'.png', bbox_inches='tight')
    plt.close()

    fw_trax = open('Result/Classic/Tx_T-'+str(TimeSlotNum)+'BI-'+str(bouncingInterval)+
        'BG-'+str(bouncingRange)+'CN-'+str(custNum)+'Sig-'+str(sigma)+'Seed-'+str(mySeed)+'.txt', 'w')
    fw_trax.write('All_Tx:'+'\t'+str(sum(txTracker))+'\tCanceled:'+'\t'+str(sum(canceledTxTracker))
        +'\tTotally_failed:'+'\t'+str(sum(failedTxTracker)))
    fw_trax.close()
# Out:
# In time slot:0 | 2000 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:1 | 984 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:2 | 1045 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:3 | 977 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:4 | 1020 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:5 | 994 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:6 | 1009 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:7 | 1018 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:8 | 985 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:9 | 1012 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:10 | 1005 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:11 | 1002 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:12 | 948 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:13 | 994 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:14 | 1014 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:15 | 985 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:16 | 1015 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:17 | 959 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:18 | 1042 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:19 | 964 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:20 | 990 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:21 | 1026 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:22 | 968 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:23 | 1007 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:24 | 1041 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:25 | 986 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:26 | 982 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:27 | 952 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:28 | 1008 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:29 | 1013 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:30 | 1001 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:31 | 998 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:32 | 996 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:33 | 1017 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:34 | 1016 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:35 | 1008 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:36 | 1013 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:37 | 1023 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:38 | 1018 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:39 | 952 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:40 | 1034 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:41 | 998 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:42 | 979 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:43 | 970 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:44 | 981 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:45 | 975 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:46 | 1012 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:47 | 979 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:48 | 1020 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:49 | 984 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:50 | 991 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:51 | 1000 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:52 | 1028 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:53 | 1022 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:54 | 978 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:55 | 993 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:56 | 1053 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:57 | 996 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:58 | 988 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:59 | 972 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:60 | 1017 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:61 | 984 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:62 | 971 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:63 | 1017 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:64 | 1000 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:65 | 965 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:66 | 1019 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:67 | 1008 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:68 | 992 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:69 | 1031 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:70 | 977 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:71 | 1018 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:72 | 976 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:73 | 999 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:74 | 1017 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:75 | 988 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:76 | 1019 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:77 | 964 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:78 | 985 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:79 | 978 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:80 | 998 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:81 | 1014 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:82 | 1043 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:83 | 956 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:84 | 998 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:85 | 998 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:86 | 1010 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:87 | 1007 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:88 | 967 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:89 | 1001 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:90 | 962 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:91 | 1013 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:92 | 997 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:93 | 982 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:94 | 982 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:95 | 979 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:96 | 1006 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:97 | 1003 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:98 | 977 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:99 | 956 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:100 | 978 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:101 | 1001 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:102 | 989 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:103 | 929 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:104 | 967 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:105 | 974 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:106 | 945 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:107 | 958 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:108 | 1000 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:109 | 992 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:110 | 982 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:111 | 932 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:112 | 959 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:113 | 970 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:114 | 916 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:115 | 1013 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:116 | 961 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:117 | 967 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:118 | 951 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:119 | 935 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:120 | 990 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:121 | 965 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:122 | 950 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:123 | 966 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:124 | 971 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:125 | 944 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:126 | 973 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:127 | 935 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:128 | 974 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:129 | 941 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:130 | 915 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:131 | 933 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:132 | 972 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:133 | 958 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:134 | 927 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:135 | 896 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:136 | 891 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:137 | 968 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:138 | 951 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:139 | 925 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:140 | 968 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:141 | 903 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:142 | 929 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:143 | 903 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:144 | 953 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:145 | 910 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:146 | 931 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:147 | 911 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:148 | 932 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:149 | 920 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:150 | 928 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:151 | 904 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:152 | 884 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:153 | 895 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:154 | 895 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:155 | 911 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:156 | 941 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:157 | 868 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:158 | 918 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:159 | 936 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:160 | 877 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:161 | 857 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:162 | 886 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:163 | 859 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:164 | 844 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:165 | 881 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:166 | 858 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:167 | 903 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:168 | 915 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:169 | 876 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:170 | 869 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:171 | 903 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:172 | 856 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:173 | 876 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:174 | 880 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:175 | 859 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:176 | 870 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:177 | 880 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:178 | 875 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:179 | 858 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:180 | 862 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:181 | 871 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:182 | 852 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:183 | 850 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:184 | 882 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:185 | 864 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:186 | 851 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:187 | 849 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:188 | 844 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:189 | 835 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:190 | 838 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:191 | 839 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:192 | 852 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:193 | 810 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:194 | 811 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:195 | 816 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:196 | 843 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:197 | 811 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:198 | 843 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:199 | 810 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:200 | 832 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:201 | 591 happens. And 7 transactions are canceled. | And 0 totally failed.
# In time slot:202 | 598 happens. And 8 transactions are canceled. | And 1 totally failed.
# In time slot:203 | 618 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:204 | 607 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:205 | 675 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:206 | 592 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:207 | 629 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:208 | 629 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:209 | 605 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:210 | 612 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:211 | 620 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:212 | 633 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:213 | 574 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:214 | 596 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:215 | 563 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:216 | 601 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:217 | 606 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:218 | 573 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:219 | 564 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:220 | 568 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:221 | 569 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:222 | 564 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:223 | 547 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:224 | 585 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:225 | 546 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:226 | 551 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:227 | 554 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:228 | 548 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:229 | 541 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:230 | 529 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:231 | 552 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:232 | 548 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:233 | 525 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:234 | 538 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:235 | 556 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:236 | 511 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:237 | 514 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:238 | 548 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:239 | 484 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:240 | 515 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:241 | 525 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:242 | 507 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:243 | 501 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:244 | 492 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:245 | 512 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:246 | 515 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:247 | 502 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:248 | 514 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:249 | 498 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:250 | 518 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:251 | 516 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:252 | 503 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:253 | 474 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:254 | 506 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:255 | 483 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:256 | 477 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:257 | 480 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:258 | 479 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:259 | 483 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:260 | 490 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:261 | 477 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:262 | 460 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:263 | 464 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:264 | 442 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:265 | 462 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:266 | 435 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:267 | 450 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:268 | 464 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:269 | 444 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:270 | 440 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:271 | 469 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:272 | 445 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:273 | 432 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:274 | 454 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:275 | 426 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:276 | 431 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:277 | 451 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:278 | 430 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:279 | 441 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:280 | 408 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:281 | 424 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:282 | 438 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:283 | 423 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:284 | 431 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:285 | 414 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:286 | 425 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:287 | 431 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:288 | 415 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:289 | 390 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:290 | 410 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:291 | 406 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:292 | 425 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:293 | 428 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:294 | 416 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:295 | 395 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:296 | 397 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:297 | 419 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:298 | 388 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:299 | 393 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:300 | 381 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:301 | 395 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:302 | 414 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:303 | 383 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:304 | 382 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:305 | 377 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:306 | 404 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:307 | 388 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:308 | 391 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:309 | 366 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:310 | 373 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:311 | 376 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:312 | 368 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:313 | 365 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:314 | 361 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:315 | 394 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:316 | 384 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:317 | 380 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:318 | 370 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:319 | 353 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:320 | 370 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:321 | 404 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:322 | 372 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:323 | 379 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:324 | 348 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:325 | 348 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:326 | 358 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:327 | 356 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:328 | 385 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:329 | 341 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:330 | 353 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:331 | 347 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:332 | 331 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:333 | 344 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:334 | 349 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:335 | 336 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:336 | 354 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:337 | 338 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:338 | 331 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:339 | 353 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:340 | 344 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:341 | 334 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:342 | 355 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:343 | 348 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:344 | 331 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:345 | 334 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:346 | 329 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:347 | 333 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:348 | 325 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:349 | 352 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:350 | 335 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:351 | 341 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:352 | 329 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:353 | 334 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:354 | 325 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:355 | 335 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:356 | 331 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:357 | 325 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:358 | 322 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:359 | 311 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:360 | 315 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:361 | 319 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:362 | 333 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:363 | 342 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:364 | 296 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:365 | 326 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:366 | 315 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:367 | 317 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:368 | 320 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:369 | 324 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:370 | 307 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:371 | 309 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:372 | 296 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:373 | 315 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:374 | 316 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:375 | 311 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:376 | 299 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:377 | 311 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:378 | 313 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:379 | 281 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:380 | 314 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:381 | 303 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:382 | 324 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:383 | 305 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:384 | 303 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:385 | 289 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:386 | 306 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:387 | 307 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:388 | 290 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:389 | 298 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:390 | 290 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:391 | 288 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:392 | 283 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:393 | 296 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:394 | 309 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:395 | 308 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:396 | 286 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:397 | 285 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:398 | 303 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:399 | 290 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:400 | 290 happens. And 6 transactions are canceled. | And 0 totally failed.
# In time slot:401 | 236 happens. And 2 transactions are canceled. | And 0 totally failed.
# In time slot:402 | 273 happens. And 5 transactions are canceled. | And 0 totally failed.
# In time slot:403 | 250 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:404 | 233 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:405 | 225 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:406 | 261 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:407 | 261 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:408 | 255 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:409 | 266 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:410 | 256 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:411 | 217 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:412 | 254 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:413 | 246 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:414 | 245 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:415 | 239 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:416 | 238 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:417 | 232 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:418 | 235 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:419 | 237 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:420 | 236 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:421 | 218 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:422 | 239 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:423 | 226 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:424 | 218 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:425 | 238 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:426 | 216 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:427 | 237 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:428 | 246 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:429 | 239 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:430 | 245 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:431 | 225 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:432 | 231 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:433 | 234 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:434 | 231 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:435 | 215 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:436 | 224 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:437 | 221 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:438 | 232 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:439 | 229 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:440 | 230 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:441 | 205 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:442 | 222 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:443 | 207 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:444 | 217 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:445 | 225 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:446 | 205 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:447 | 227 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:448 | 220 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:449 | 216 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:450 | 213 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:451 | 205 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:452 | 187 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:453 | 220 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:454 | 199 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:455 | 213 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:456 | 207 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:457 | 215 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:458 | 211 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:459 | 221 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:460 | 215 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:461 | 201 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:462 | 201 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:463 | 192 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:464 | 197 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:465 | 224 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:466 | 196 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:467 | 209 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:468 | 202 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:469 | 213 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:470 | 207 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:471 | 209 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:472 | 203 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:473 | 204 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:474 | 199 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:475 | 201 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:476 | 206 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:477 | 204 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:478 | 202 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:479 | 193 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:480 | 205 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:481 | 196 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:482 | 191 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:483 | 196 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:484 | 179 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:485 | 192 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:486 | 182 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:487 | 193 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:488 | 206 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:489 | 201 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:490 | 185 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:491 | 202 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:492 | 189 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:493 | 192 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:494 | 185 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:495 | 204 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:496 | 190 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:497 | 189 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:498 | 186 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:499 | 191 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:500 | 181 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:501 | 189 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:502 | 186 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:503 | 203 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:504 | 186 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:505 | 184 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:506 | 179 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:507 | 178 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:508 | 189 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:509 | 169 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:510 | 185 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:511 | 175 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:512 | 166 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:513 | 164 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:514 | 195 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:515 | 179 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:516 | 200 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:517 | 180 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:518 | 179 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:519 | 180 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:520 | 170 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:521 | 171 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:522 | 186 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:523 | 193 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:524 | 161 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:525 | 202 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:526 | 173 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:527 | 190 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:528 | 188 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:529 | 177 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:530 | 182 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:531 | 152 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:532 | 182 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:533 | 172 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:534 | 176 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:535 | 190 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:536 | 167 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:537 | 161 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:538 | 173 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:539 | 163 happens. And 0 transactions are canceled. | And 0 totally failed.
# ...
# In time slot:859 | 36 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:860 | 34 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:861 | 33 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:862 | 45 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:863 | 34 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:864 | 35 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:865 | 36 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:866 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:867 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:868 | 42 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:869 | 34 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:870 | 37 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:871 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:872 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:873 | 36 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:874 | 27 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:875 | 36 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:876 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:877 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:878 | 36 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:879 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:880 | 33 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:881 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:882 | 33 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:883 | 36 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:884 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:885 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:886 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:887 | 37 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:888 | 36 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:889 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:890 | 40 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:891 | 31 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:892 | 38 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:893 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:894 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:895 | 23 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:896 | 37 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:897 | 35 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:898 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:899 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:900 | 37 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:901 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:902 | 24 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:903 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:904 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:905 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:906 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:907 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:908 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:909 | 24 happens. And 1 transactions are canceled. | And 0 totally failed.
# In time slot:910 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:911 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:912 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:913 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:914 | 34 happens. And 2 transactions are canceled. | And 0 totally failed.
# In time slot:915 | 30 happens. And 1 transactions are canceled. | And 0 totally failed.
# In time slot:916 | 33 happens. And 1 transactions are canceled. | And 0 totally failed.
# In time slot:917 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:918 | 34 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:919 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:920 | 27 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:921 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:922 | 31 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:923 | 27 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:924 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:925 | 24 happens. And 1 transactions are canceled. | And 0 totally failed.
# In time slot:926 | 35 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:927 | 31 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:928 | 29 happens. And 1 transactions are canceled. | And 0 totally failed.
# In time slot:929 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:930 | 24 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:931 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:932 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:933 | 21 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:934 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:935 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:936 | 34 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:937 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:938 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:939 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:940 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:941 | 31 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:942 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:943 | 32 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:944 | 31 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:945 | 27 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:946 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:947 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:948 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:949 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:950 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:951 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:952 | 27 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:953 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:954 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:955 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:956 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:957 | 21 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:958 | 22 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:959 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:960 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:961 | 22 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:962 | 24 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:963 | 22 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:964 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:965 | 21 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:966 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:967 | 22 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:968 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:969 | 23 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:970 | 29 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:971 | 27 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:972 | 30 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:973 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:974 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:975 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:976 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:977 | 22 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:978 | 18 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:979 | 28 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:980 | 20 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:981 | 23 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:982 | 23 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:983 | 21 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:984 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:985 | 25 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:986 | 22 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:987 | 24 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:988 | 19 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:989 | 16 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:990 | 26 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:991 | 21 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:992 | 29 happens. And 2 transactions are canceled. | And 0 totally failed.
# In time slot:993 | 23 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:994 | 21 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:995 | 19 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:996 | 18 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:997 | 19 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:998 | 20 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:999 | 17 happens. And 2 transactions are canceled. | And 0 totally failed.
# In time slot:0 | 2000 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:1 | 1044 happens. And 511 transactions are canceled. | And 510 totally failed.
# In time slot:2 | 999 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:3 | 992 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:4 | 996 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:5 | 1017 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:6 | 1013 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:7 | 996 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:8 | 1018 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:9 | 989 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:10 | 1055 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:11 | 1005 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:12 | 1002 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:13 | 980 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:14 | 988 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:15 | 1032 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:16 | 1022 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:17 | 1005 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:18 | 1008 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:19 | 991 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:20 | 1003 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:21 | 1012 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:22 | 997 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:23 | 989 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:24 | 1010 happens. And 0 transactions are canceled. | And 0 totally failed.
# In time slot:25 | 984 happens. And 0 transactions are canceled. | And 0 totally failed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-416868ba9819> in <module>()
#      81                 custList[i].changeValuation(0.001*currentMarketPrice)
#      82             else:
# ---> 83                 custList[i].changeValuation(custValuation_list[i])
#      84
#      85         txTracker.append(MyClassicMarket.getTransactionNum())
#
# <ipython-input-3-ee8ec83389b7> in changeValuation(self, newValuation)
#      64         If the previous order succeeds in the market, this function call will cancel nothing.
#      65         '''
# ---> 66         self._market.cancelOrder(self)
#      67         '''
#      68         What getCurrentPrice() returns in Bancor market should be different with the real time price of Smart Token.
#
# <ipython-input-4-5e77e58930f2> in cancelOrder(self, cust)
#     165         # Order format: [cust, transactionValue, buy_or_sell]
#     166         for s in range(len(self._OrderList)):
# --> 167             if self._OrderList[s][0] is cust:
#     168                 self._canceledTransactionNum = self._canceledTransactionNum + 1
#     169                 if cust not in self._ChangedOrderList:
#
# KeyboardInterrupt:
