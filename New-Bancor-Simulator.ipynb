# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
fw = open('Transaction-Record.txt','w')

# %%
class Customers(object):
    '''
    _smartToken: the token customers want to buy -- SmartToken()
    _ownedSmartToken: smart token's number customers have, being rounded as whitepaper
    _reserveTokens: reserve token's number customers have, being rounded as whitepaper
    _ownedvalue = _reserveValue + _smartValue: the total money cust has, using reserveToken as measurement
    _originalMoney: original money cust has
    _moneyBalance: value of money gained or lost, comparing to the original state
    _expectedPrice: how much money customers are willing to finish the transaction
    '''
    def __init__(self, smartToken, ownedSmartTokens = 0, reserveTokens = 0, expectedPrice = 0):
        self._smartToken = smartToken
        self._ownedSmartTokens = int(ownedSmartTokens)
        self._reserveTokens = int(reserveTokens)
        self._ownedvalue = float(smartToken.getPrice() * self._ownedSmartTokens + self._reserveTokens * 1)
        self._originalMoney = self._ownedvalue
        self._moneyBalance = float(0)
        self._expectedPrice = float(expectedPrice)
        
    def printinfo(self):
        # since new reserve will be converted into or out the smarttoken, Price will change
        # when print info, update the _ownedvalue
        self._ownedvalue = float(self._smartToken.getPrice() * self._ownedSmartTokens + self._reserveTokens * 1)
        self._moneyBalance = self._ownedvalue - self._originalMoney
        print '------'
        print 'smartToken Name:', self._smartToken._Name, '| expected price:', self._expectedPrice
        print 'ownedvalue:', self._ownedvalue, '| money Balance:', self._moneyBalance
    def getReserveTokens(self):
        return self._reserveTokens
    def getownedSmartTokens(self):
        return self._ownedSmartTokens
    def getmoneyBalance(self):
        self._ownedvalue = float(self._smartToken.getPrice() * self._ownedSmartTokens + self._reserveTokens * 1)
        self._moneyBalance = self._ownedvalue - self._originalMoney
        return self._moneyBalance
    def getExpectedPrice(self):
        return self._expectedPrice
    # add customer's reserve amount
    def addReserve(self, addAmount):
        if isinstance(addAmount,int):
            self._reserveTokens = self._reserveTokens + addAmount
            self._ownedvalue = float(self._smartToken.getPrice() * self._ownedSmartTokens + self._reserveTokens * 1)
            # this part money is independant with bancor balance
            self._originalMoney = self._originalMoney + addAmount * 1
        else:
            print "** ERROR, only can add integer # of reserveTokens to reserve"
    # change the expected price
    def changeExpectedPrice(self, newExpectedPrice):
        self._expectedPrice = newExpectedPrice

    '''
    use reserveToken to buy smartToken -> smartToken price increase
    call smartTokens.purchasing() function
    '''
    def buy(self, reserveTokenNumber):
        if reserveTokenNumber < 0:
            print '** ERROR, cannot buy negative number of smartToken'
            return
        if reserveTokenNumber > self._reserveTokens:
            print '** ERROR, invalid Operation in buy'
            return
        if not isinstance(reserveTokenNumber,int):
            print '** ERROR, should use integer number of reserveTokens to buy'
            return
        self._reserveTokens = self._reserveTokens - reserveTokenNumber
        issuedSmartToken = self._smartToken.purchasing(reserveTokenNumber)
        self._ownedSmartTokens = self._ownedSmartTokens + issuedSmartToken
        self._ownedvalue = float(self._smartToken.getPrice() * self._ownedSmartTokens + self._reserveTokens * 1)
        self._moneyBalance = self._ownedvalue - self._originalMoney
        
    '''
    sell smartToken to get reserveToken -> smartToken price decrease
    call smartTokens.destroying() function
    '''        
    def sell(self, smartTokenNumber):
        if smartTokenNumber < 0:
            print '** ERROR, cannot sell negative number of smartToken'
            return
        if self._ownedSmartTokens < smartTokenNumber:
            print '** ERROR, invalid Operation in sell'
            return
        if not isinstance(smartTokenNumber,int):
            print '** ERROR, should use integer number of smartTokens to sell'
            return
        self._ownedSmartTokens = self._ownedSmartTokens - smartTokenNumber
        ReceivedToken = self._smartToken.destroying(smartTokenNumber)
        self._reserveTokens = self._reserveTokens + ReceivedToken
        self._ownedvalue = float(self._smartToken.getPrice() * self._ownedSmartTokens + self._reserveTokens * 1)
        self._moneyBalance = self._ownedvalue - self._originalMoney

# %%
class Smartcoin(object):
	'''
	_Name: Name of Smart token
	_ReservetokenName: Name of Reserve Token
	_CRR: CRR
	_Price: the current Price of smart token
	_Supply: the number of issued smart tokens
	_ReserveBalance: the balance of the reserve pool
	'''
	def __init__(self, name='kennycoin', reservetokenName='aCoin', initCRR=0.5, initPrice=1, initIssueNum=100):
		self._Name = name
		self._ReservetokenName = reservetokenName
		self._CRR = float(initCRR)
		self._Price = float(initPrice)
		self._Supply = float(initIssueNum)
		self._ReserveBalance = float(initCRR * initIssueNum)   

	def printInfo(self):
		print '---------'
		print 'NAME:', self._Name, '| RESERVE NAME:', self._ReservetokenName, 'CRR:', self._CRR
		print 'PRICE:',self._Price
		print 'SUPPLY:', self._Supply, '| RESERVE BALANCE:', self._ReserveBalance

	def saveInfo(self, fw):
		fw.write('---------\n')
		fw.write('NAME: '+str(self._Name)+' | RESERVE NAME: '+str(self._ReservetokenName) + ' | CRR: '+str(self._CRR)+'\n')
		fw.write('PRICE: '+str(self._Price))
		fw.write('SUPPLY: '+str(self._Supply)+' | RESERVE BALANCE: '+str(self._ReserveBalance)+'\n')
        
	def updatePrice(self, reserveBalance, supply, CRR):
		newPrice = reserveBalance/(supply * CRR)
		return newPrice
    
	def setCRR(self, newCRR = 0.5):
		oldCRR = self._CRR
		self._CRR = newCRR
		print 'CRR', oldCRR, '->', newCRR

	def getPrice(self):
		return self._Price

	def purchasing(self, convertIntoNum=0):
		# e.g., ETH be convert into BNT, convertInto Num
		issuedtokenNum = round(self._Supply * (((self._ReserveBalance + convertIntoNum)/self._ReserveBalance)**(self._CRR) - 1))
		self._Supply = self._Supply + issuedtokenNum
		self._ReserveBalance = self._ReserveBalance + convertIntoNum
		# update the price after purchasing, e.g. ETH convert into BNT (cust use eth to buy bnt)
		oldPrice = self._Price
		self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
		increaseRatio = (self._Price - oldPrice)/oldPrice
		return int(issuedtokenNum)

	def destroying(self, convertOutNum=0):
		# e.g., BNT be converted out to ETH, convertOutNum is BNT's num
		destroyedtokenNum = convertOutNum
		reserveReceivedNum = round(self._ReserveBalance*(1 - ((self._Supply - convertOutNum)/float(self._Supply))**(1/self._CRR)))
		self._Supply = self._Supply - destroyedtokenNum
		self._ReserveBalance = self._ReserveBalance - reserveReceivedNum
		# update the price after destroying, e.g. BNT convert into ETH (cust sell bnt to get eth)
		oldPrice = self._Price
		self._Price = self.updatePrice(self._ReserveBalance, self._Supply, self._CRR)
		decreaseRatio = (oldPrice-self._Price)/oldPrice
		return int(reserveReceivedNum)

# %%
# issue a new smart token
initIssue = 3000000
CRR = 0.2
initTransaction = initIssue * (1-CRR)
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1, initIssueNum=initIssue)

# market initialization
# BancorMarket = Market()

'''
init properties: 
We have #TimeRound round, bouncing happens after every bouncing interval
Totally #custNum  customers come in
In each time round, #tx_round transactions, 
   with original reserve: #custOriginalReserve
   with original smarttokens: #custOriginalSmartTokens
'''
TimeRound = 1000
bouncingInterval = 200
bouncingRange = 1.9
tx_round = 100
custNum = 5000
sigma = 0.1
custOriginalReserve_mu = 200
custOriginalSmartTokens_mu = 200
custOriginalReserve = np.random.normal(custOriginalReserve_mu, 0.1, custNum) # 0.5 is sigma
custOriginalSmartTokens = np.random.normal(custOriginalSmartTokens_mu, 0.1, custNum) # 0.5 is sigma
'''
prevent the init money exhausts the balance, 
here we already set initIssue SmartToken to 300000000,
which actually is hard to exhaust,
also, we should consider the situation that the init issued smarttokens is comparably small,
      or the init smarttokens is held in customers in a large amount
'''
if sum(custOriginalSmartTokens) > initTransaction:
    print '&& WARNING, too many init smart tokens from customers'
    if sum(custOriginalSmartTokens) > initIssue:
        print '** ERROR, too many init smart tokens'
        turndown = 1 + 'klk'

#custmer initialization, first set all their expected Price to be -1
custlist = []
i = 0
while i < custNum:
    Joe = Customers(smartToken = KennyCoin, ownedSmartTokens = int(custOriginalSmartTokens[i]), reserveTokens = int(custOriginalReserve[i]), expectedPrice = -1)
    custlist.append(Joe)
    i = i + 1
# moneyTracker records the 
moneyTracker = []
# PriceTracker records the change of the price
PriceTracker = []
# failureTracker records the failure rate of transactions
failed_rateTracker = []
waitingTracker = []

# tx_list records the transaction order which remains in the market
tx_list = []
j=0
while j < TimeRound:
    buyNum = 0
    sellNum = 0
    CurrentPrice = KennyCoin.getPrice()
    '''
    scan the tx_list, follow the order to try transactions one by one, 
    if succeed, remove the tx element.
    P.S. the element in tx_list is (MARK, cust, tokenNum), 
         when MARK is 1, the cust tries to buy, when MARK is -1, cust tries to sell
    '''
    waitingTx_Num_Old = len(tx_list)
    s = 0
    while s < len(tx_list):
        tx_mark = tx_list[s][0]
        tx_cust = tx_list[s][1]
        tx_tokenNum = tx_list[s][2]
        if tx_mark == - 1:
            # try sell
            if tx_cust.getExpectedPrice() < KennyCoin.getPrice():
                # cust sells successfully
                tx_cust.sell(tx_tokenNum)
                # change expectedPrice, means could do transaction again
                tx_cust.changeExpectedPrice(-1)
                sellNum = sellNum + 1
                tx_list.pop(s)
                s = s - 1
        else:
            # try buy
            if tx_cust.getExpectedPrice() >= KennyCoin.getPrice():
                # cust buys successfully
                tx_cust.buy(tx_tokenNum)
                # change expectedPrice, means could do transaction again
                tx_cust.changeExpectedPrice(-1)
                buyNum = buyNum + 1
                tx_list.pop(s)
                s = s - 1
        s = s + 1

    flag = 0
    if (j > 0) and (j % bouncingInterval == 0):
        # here assume the bouncing_mu is generated by random
        Price_mu = random.uniform(0.1 * CurrentPrice, bouncingRange * CurrentPrice)
        # when Price_mu < than currentPrice, every one wants to sell, else every one wants to buy
        if Price_mu < CurrentPrice:
            flag = -1 # sell
        else:
            flag = 1 # buy
    else:
        Price_mu = CurrentPrice

    custExpectedPrice = np.random.normal(Price_mu, sigma, tx_round)
    i = 0
    for t in xrange(0,custNum):
        if i >= tx_round:
            break
        if custlist[t].getExpectedPrice() >= 0:
            continue
        if custExpectedPrice[i] > 0:
            # avoid newExpectedPrice <= 0
            # in fact newExpectedPrice should not be 0, otherwise will be dead buyer
            newExpectedPrice = custExpectedPrice[i]
        else:
            newExpectedPrice = 0.00001 * KennyCoin.getPrice()

        custlist[t].changeExpectedPrice(newExpectedPrice)
        if flag == -1:
            custSmartToken_Num = custlist[t].getownedSmartTokens()
            randomSell = random.randint(0,custSmartToken_Num)            
            if custlist[t].getExpectedPrice() < KennyCoin.getPrice():
                # cust sells successfully
                custlist[t].sell(randomSell)
                # change expectedPrice, means could do transaction again
                custlist[t].changeExpectedPrice(-1)
                sellNum = sellNum + 1
            else:
                # failed in selling, add cust to tx list, -1 means to sell
                tx_list.append((-1, custlist[t],randomSell))
                # BancorMarket.addSeller(custlist[t])

        elif flag == 1:
            custReserveToken_Num = custlist[t].getReserveTokens()
            randomBuy = random.randint(0, custReserveToken_Num)
            if custlist[t].getExpectedPrice() >= KennyCoin.getPrice():
                # cust buys successfully
                custlist[t].buy(randomBuy)
                custlist[t].changeExpectedPrice(-1)
                buyNum = buyNum + 1
            else:
                # failed in buying, add cust to tx list, 1 means to buy
                tx_list.append((1, custlist[t],randomBuy))
                # BancorMarket.addBuyer(custlist[t])

        else:
            '''
            Here we make an important asumption that customers are willing to finish the transaction,
            as they have already known the current price
            So buyers' expected price should be higher than current price, sellers' should be lower.
            
            In fact we are able to choose buy and sell operation by throwing a coin, 
            but the former situation seems to be more reasonable, 
            and the former market can always perform better than chosing by random. 
            So if we find the former one is flawed, the random's case can only be worse.
            '''
            if custlist[t].getExpectedPrice() >= CurrentPrice:
                # buy
                custReserveToken_Num = custlist[t].getReserveTokens()
                randomBuy = random.randint(0, custReserveToken_Num)
                if custlist[t].getExpectedPrice() >= KennyCoin.getPrice():
                    # cust buy successfully
                    custlist[t].buy(randomBuy)
                    # change expectedPrice for cust, means he could do transaction again
                    custlist[t].changeExpectedPrice(-1)
                    buyNum = buyNum + 1
                else:
                    # failed in buying, add cust to tx list, 1 means to buy
                    tx_list.append((1, custlist[t],randomBuy))
                    # BancorMarket.addBuyer(custlist[t])
            else:
                # sell
                custSmartToken_Num = custlist[t].getownedSmartTokens()
                randomSell = random.randint(0,custSmartToken_Num)            
                if custlist[t].getExpectedPrice() < KennyCoin.getPrice():
                    # cust sells successfully
                    custlist[t].sell(randomSell)
                    # change expectedPrice for cust, means he could do transaction again
                    custlist[t].changeExpectedPrice(-1)
                    sellNum = sellNum + 1
                else:
                    # failed in selling, add cust to tx list, -1 means to sell
                    tx_list.append((-1, custlist[t],randomSell))
                    # BancorMarket.addSeller(custlist[t])
        i = i + 1
    # here we shuffle the cust list to let all customer to get oppotunity to make transactions
    random.shuffle(custlist)
    moneyBalance_all = 0
    for Joe in custlist:
        moneyBalance_all = moneyBalance_all + Joe.getmoneyBalance()

    moneyTracker.append((moneyBalance_all,j))
    failed_rateTracker.append((len(tx_list)/float(waitingTx_Num_Old+tx_round),j))
    waitingTracker.append((len(tx_list),j))
    PriceTracker.append((KennyCoin.getPrice(),j))

    print 'The',j,'round:', buyNum, 'buy tx |', sellNum, 'sell tx |', len(tx_list), 'unfinished tx.'
    fw.write('The '+str(j)+' round: '+str(buyNum)+' buy tx | '+str(sellNum)+' sell tx | '+str(len(tx_list))+' unfinished tx.\n')
    j = j + 1

# draw failure rate
j = 0
failedRate = []
myX_FR = []
while j < TimeRound:
    myX_FR.append(j)
    failedRate.append(failed_rateTracker[j][0])
    j = j + 1
x_FR = np.asarray(myX_FR)
y_FR = np.asarray(failedRate)
plt.plot(x_FR,y_FR,'o-',color = 'navy',alpha = 0.8)
plt.title('Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Transaction', fontsize = 15)
plt.savefig('Figures/FailureRate.png', bbox_inches='tight')
plt.close()

# draw waiting list change
j = 0
waitingNum = []
myX_W = []
while j < TimeRound:
    myX_W.append(j)
    waitingNum.append(waitingTracker[j][0])
    j = j + 1
x_W = np.asarray(myX_W)
y_W = np.asarray(waitingNum)
plt.plot(x_W,y_W,'o-',color = 'navy',alpha = 0.8)
plt.title('Unfinished Transactions Num For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Unfinished Transactions Num', fontsize = 15)
plt.savefig('Figures/WaitingNum.png', bbox_inches='tight')
plt.close()

# draw price change figure
j = 0
PriceAllRound = []
myX_P = []
while j < TimeRound:
    PriceAllRound.append(PriceTracker[j][0])
    myX_P.append(j)
    j = j + 1
x_P = np.asarray(myX_P)
y_P = np.asarray(PriceAllRound)
plt.plot(x_P, y_P, 'o-',color = 'navy', alpha = 0.8)
plt.title('Price Change For All Round',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Price of Smart Token', fontsize = 15)
plt.savefig('Figures/Price_Change.png', bbox_inches='tight')
plt.close()

# draw money change figure
j = 0
moneyChange = []
myX_M = []
while j < TimeRound:
    moneyChange.append(moneyTracker[j][0])
    myX_M.append(j)
    j = j + 1
x_M = np.asarray(myX_M)
y_M = np.asarray(moneyChange)
plt.plot(x_M, y_M, 'o-', color = 'navy', alpha = 0.8)
plt.title('Money Balance Change For All Round',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Money Balance of All Custs', fontsize = 15)
plt.savefig('Figures/MoneyBalance_Change.png', bbox_inches='tight')
plt.close()
# Out:
# The 0 round: 54 buy tx | 46 sell tx | 0 unfinished tx.
# The 1 round: 42 buy tx | 58 sell tx | 0 unfinished tx.
# The 2 round: 50 buy tx | 50 sell tx | 0 unfinished tx.
# The 3 round: 54 buy tx | 46 sell tx | 0 unfinished tx.
# The 4 round: 58 buy tx | 42 sell tx | 0 unfinished tx.
# The 5 round: 51 buy tx | 48 sell tx | 1 unfinished tx.
# The 6 round: 60 buy tx | 39 sell tx | 2 unfinished tx.
# The 7 round: 61 buy tx | 38 sell tx | 3 unfinished tx.
# The 8 round: 47 buy tx | 53 sell tx | 3 unfinished tx.
# The 9 round: 44 buy tx | 56 sell tx | 3 unfinished tx.
# The 10 round: 53 buy tx | 47 sell tx | 3 unfinished tx.
# The 11 round: 51 buy tx | 49 sell tx | 3 unfinished tx.
# The 12 round: 43 buy tx | 56 sell tx | 4 unfinished tx.
# The 13 round: 47 buy tx | 54 sell tx | 3 unfinished tx.
# The 14 round: 47 buy tx | 53 sell tx | 3 unfinished tx.
# The 15 round: 51 buy tx | 49 sell tx | 3 unfinished tx.
# The 16 round: 46 buy tx | 53 sell tx | 4 unfinished tx.
# The 17 round: 43 buy tx | 57 sell tx | 4 unfinished tx.
# The 18 round: 57 buy tx | 45 sell tx | 2 unfinished tx.
# The 19 round: 56 buy tx | 45 sell tx | 1 unfinished tx.
# The 20 round: 55 buy tx | 45 sell tx | 1 unfinished tx.
# The 21 round: 51 buy tx | 49 sell tx | 1 unfinished tx.
# The 22 round: 54 buy tx | 47 sell tx | 0 unfinished tx.
# The 23 round: 45 buy tx | 55 sell tx | 0 unfinished tx.
# The 24 round: 45 buy tx | 55 sell tx | 0 unfinished tx.
# The 25 round: 58 buy tx | 42 sell tx | 0 unfinished tx.
# The 26 round: 57 buy tx | 43 sell tx | 0 unfinished tx.
# The 27 round: 56 buy tx | 44 sell tx | 0 unfinished tx.
# The 28 round: 43 buy tx | 56 sell tx | 1 unfinished tx.
# The 29 round: 55 buy tx | 45 sell tx | 1 unfinished tx.
# The 30 round: 47 buy tx | 54 sell tx | 0 unfinished tx.
# The 31 round: 56 buy tx | 44 sell tx | 0 unfinished tx.
# The 32 round: 46 buy tx | 54 sell tx | 0 unfinished tx.
# The 33 round: 46 buy tx | 54 sell tx | 0 unfinished tx.
# The 34 round: 46 buy tx | 53 sell tx | 1 unfinished tx.
# The 35 round: 46 buy tx | 53 sell tx | 2 unfinished tx.
# The 36 round: 47 buy tx | 52 sell tx | 3 unfinished tx.
# The 37 round: 53 buy tx | 47 sell tx | 3 unfinished tx.
# The 38 round: 58 buy tx | 42 sell tx | 3 unfinished tx.
# The 39 round: 56 buy tx | 44 sell tx | 3 unfinished tx.
# The 40 round: 54 buy tx | 48 sell tx | 1 unfinished tx.
# The 41 round: 56 buy tx | 44 sell tx | 1 unfinished tx.
# The 42 round: 48 buy tx | 52 sell tx | 1 unfinished tx.
# The 43 round: 53 buy tx | 47 sell tx | 1 unfinished tx.
# The 44 round: 52 buy tx | 48 sell tx | 1 unfinished tx.
# The 45 round: 51 buy tx | 49 sell tx | 1 unfinished tx.
# The 46 round: 54 buy tx | 47 sell tx | 0 unfinished tx.
# The 47 round: 51 buy tx | 49 sell tx | 0 unfinished tx.
# The 48 round: 53 buy tx | 47 sell tx | 0 unfinished tx.
# The 49 round: 52 buy tx | 48 sell tx | 0 unfinished tx.
# The 50 round: 34 buy tx | 66 sell tx | 0 unfinished tx.
# The 51 round: 54 buy tx | 46 sell tx | 0 unfinished tx.
# The 52 round: 55 buy tx | 44 sell tx | 1 unfinished tx.
# The 53 round: 49 buy tx | 51 sell tx | 1 unfinished tx.
# The 54 round: 37 buy tx | 62 sell tx | 2 unfinished tx.
# The 55 round: 55 buy tx | 46 sell tx | 1 unfinished tx.
# The 56 round: 52 buy tx | 48 sell tx | 1 unfinished tx.
# The 57 round: 62 buy tx | 37 sell tx | 2 unfinished tx.
# The 58 round: 44 buy tx | 56 sell tx | 2 unfinished tx.
# The 59 round: 50 buy tx | 51 sell tx | 1 unfinished tx.
# The 60 round: 51 buy tx | 49 sell tx | 1 unfinished tx.
# The 61 round: 42 buy tx | 58 sell tx | 1 unfinished tx.
# The 62 round: 60 buy tx | 40 sell tx | 1 unfinished tx.
# The 63 round: 48 buy tx | 52 sell tx | 1 unfinished tx.
# The 64 round: 47 buy tx | 53 sell tx | 1 unfinished tx.
# The 65 round: 50 buy tx | 49 sell tx | 2 unfinished tx.
# The 66 round: 49 buy tx | 51 sell tx | 2 unfinished tx.
# The 67 round: 45 buy tx | 54 sell tx | 3 unfinished tx.
# The 68 round: 52 buy tx | 49 sell tx | 2 unfinished tx.
# The 69 round: 54 buy tx | 46 sell tx | 2 unfinished tx.
# The 70 round: 48 buy tx | 54 sell tx | 0 unfinished tx.
# The 71 round: 51 buy tx | 49 sell tx | 0 unfinished tx.
# The 72 round: 48 buy tx | 52 sell tx | 0 unfinished tx.
# The 73 round: 53 buy tx | 47 sell tx | 0 unfinished tx.
# The 74 round: 59 buy tx | 41 sell tx | 0 unfinished tx.
# The 75 round: 49 buy tx | 51 sell tx | 0 unfinished tx.
# The 76 round: 45 buy tx | 54 sell tx | 1 unfinished tx.
# The 77 round: 50 buy tx | 50 sell tx | 1 unfinished tx.
# The 78 round: 57 buy tx | 44 sell tx | 0 unfinished tx.
# The 79 round: 41 buy tx | 59 sell tx | 0 unfinished tx.
# The 80 round: 47 buy tx | 53 sell tx | 0 unfinished tx.
# The 81 round: 48 buy tx | 52 sell tx | 0 unfinished tx.
# The 82 round: 50 buy tx | 50 sell tx | 0 unfinished tx.
# The 83 round: 49 buy tx | 51 sell tx | 0 unfinished tx.
# The 84 round: 40 buy tx | 60 sell tx | 0 unfinished tx.
# The 85 round: 44 buy tx | 56 sell tx | 0 unfinished tx.
# The 86 round: 54 buy tx | 46 sell tx | 0 unfinished tx.
# The 87 round: 52 buy tx | 47 sell tx | 1 unfinished tx.
# The 88 round: 51 buy tx | 49 sell tx | 1 unfinished tx.
# The 89 round: 50 buy tx | 51 sell tx | 0 unfinished tx.
# The 90 round: 50 buy tx | 48 sell tx | 2 unfinished tx.
# The 91 round: 45 buy tx | 55 sell tx | 2 unfinished tx.
# The 92 round: 50 buy tx | 52 sell tx | 0 unfinished tx.
# The 93 round: 45 buy tx | 55 sell tx | 0 unfinished tx.
# The 94 round: 51 buy tx | 49 sell tx | 0 unfinished tx.
# The 95 round: 57 buy tx | 43 sell tx | 0 unfinished tx.
# The 96 round: 54 buy tx | 46 sell tx | 0 unfinished tx.
# The 97 round: 69 buy tx | 31 sell tx | 0 unfinished tx.
# The 98 round: 51 buy tx | 49 sell tx | 0 unfinished tx.
# The 99 round: 52 buy tx | 48 sell tx | 0 unfinished tx.
# The 100 round: 49 buy tx | 51 sell tx | 0 unfinished tx.
# The 101 round: 47 buy tx | 53 sell tx | 0 unfinished tx.
# The 102 round: 47 buy tx | 53 sell tx | 0 unfinished tx.
# The 103 round: 49 buy tx | 51 sell tx | 0 unfinished tx.
# The 104 round: 58 buy tx | 41 sell tx | 1 unfinished tx.
# The 105 round: 51 buy tx | 49 sell tx | 1 unfinished tx.
# The 106 round: 57 buy tx | 43 sell tx | 1 unfinished tx.
# The 107 round: 52 buy tx | 47 sell tx | 2 unfinished tx.
# The 108 round: 53 buy tx | 47 sell tx | 2 unfinished tx.
# The 109 round: 54 buy tx | 46 sell tx | 2 unfinished tx.
# The 110 round: 46 buy tx | 53 sell tx | 3 unfinished tx.
# The 111 round: 51 buy tx | 50 sell tx | 2 unfinished tx.
# The 112 round: 55 buy tx | 45 sell tx | 2 unfinished tx.
# The 113 round: 47 buy tx | 51 sell tx | 4 unfinished tx.
# The 114 round: 54 buy tx | 48 sell tx | 2 unfinished tx.
# The 115 round: 48 buy tx | 52 sell tx | 2 unfinished tx.
# The 116 round: 45 buy tx | 55 sell tx | 2 unfinished tx.
# The 117 round: 52 buy tx | 48 sell tx | 2 unfinished tx.
# The 118 round: 35 buy tx | 65 sell tx | 2 unfinished tx.
# The 119 round: 51 buy tx | 50 sell tx | 1 unfinished tx.
# The 120 round: 46 buy tx | 53 sell tx | 2 unfinished tx.
# The 121 round: 52 buy tx | 48 sell tx | 2 unfinished tx.
# The 122 round: 45 buy tx | 55 sell tx | 2 unfinished tx.
# The 123 round: 50 buy tx | 51 sell tx | 1 unfinished tx.
# The 124 round: 44 buy tx | 56 sell tx | 1 unfinished tx.
# The 125 round: 49 buy tx | 51 sell tx | 1 unfinished tx.
# The 126 round: 45 buy tx | 56 sell tx | 0 unfinished tx.
# The 127 round: 53 buy tx | 46 sell tx | 1 unfinished tx.
# The 128 round: 41 buy tx | 59 sell tx | 1 unfinished tx.
# The 129 round: 40 buy tx | 61 sell tx | 0 unfinished tx.
# The 130 round: 50 buy tx | 50 sell tx | 0 unfinished tx.
# The 131 round: 58 buy tx | 42 sell tx | 0 unfinished tx.
# The 132 round: 50 buy tx | 50 sell tx | 0 unfinished tx.
# The 133 round: 54 buy tx | 44 sell tx | 2 unfinished tx.
# The 134 round: 46 buy tx | 54 sell tx | 2 unfinished tx.
# The 135 round: 50 buy tx | 50 sell tx | 2 unfinished tx.
# The 136 round: 52 buy tx | 48 sell tx | 2 unfinished tx.
# The 137 round: 58 buy tx | 43 sell tx | 1 unfinished tx.
# The 138 round: 56 buy tx | 43 sell tx | 2 unfinished tx.
# The 139 round: 45 buy tx | 54 sell tx | 3 unfinished tx.
# The 140 round: 50 buy tx | 50 sell tx | 3 unfinished tx.
# The 141 round: 51 buy tx | 49 sell tx | 3 unfinished tx.
# The 142 round: 50 buy tx | 50 sell tx | 3 unfinished tx.
# The 143 round: 57 buy tx | 43 sell tx | 3 unfinished tx.
# The 144 round: 49 buy tx | 52 sell tx | 2 unfinished tx.
# The 145 round: 57 buy tx | 43 sell tx | 2 unfinished tx.
# The 146 round: 43 buy tx | 56 sell tx | 3 unfinished tx.
# The 147 round: 48 buy tx | 53 sell tx | 2 unfinished tx.
# The 148 round: 46 buy tx | 52 sell tx | 4 unfinished tx.
# The 149 round: 63 buy tx | 38 sell tx | 3 unfinished tx.
# The 150 round: 49 buy tx | 51 sell tx | 3 unfinished tx.
# The 151 round: 46 buy tx | 54 sell tx | 3 unfinished tx.
# The 152 round: 57 buy tx | 43 sell tx | 3 unfinished tx.
# The 153 round: 47 buy tx | 53 sell tx | 3 unfinished tx.
# The 154 round: 55 buy tx | 45 sell tx | 3 unfinished tx.
# The 155 round: 48 buy tx | 52 sell tx | 3 unfinished tx.
# The 156 round: 49 buy tx | 51 sell tx | 3 unfinished tx.
# The 157 round: 54 buy tx | 46 sell tx | 3 unfinished tx.
# The 158 round: 48 buy tx | 52 sell tx | 3 unfinished tx.
# The 159 round: 53 buy tx | 48 sell tx | 2 unfinished tx.
# The 160 round: 47 buy tx | 53 sell tx | 2 unfinished tx.
# The 161 round: 55 buy tx | 45 sell tx | 2 unfinished tx.
# The 162 round: 42 buy tx | 57 sell tx | 3 unfinished tx.
# The 163 round: 41 buy tx | 58 sell tx | 4 unfinished tx.
# The 164 round: 41 buy tx | 57 sell tx | 6 unfinished tx.
# The 165 round: 47 buy tx | 53 sell tx | 6 unfinished tx.
# The 166 round: 55 buy tx | 45 sell tx | 6 unfinished tx.
# The 167 round: 47 buy tx | 53 sell tx | 6 unfinished tx.
# The 168 round: 47 buy tx | 53 sell tx | 6 unfinished tx.
# The 169 round: 46 buy tx | 54 sell tx | 6 unfinished tx.
# The 170 round: 54 buy tx | 46 sell tx | 6 unfinished tx.
# The 171 round: 44 buy tx | 55 sell tx | 7 unfinished tx.
# The 172 round: 44 buy tx | 55 sell tx | 8 unfinished tx.
# The 173 round: 53 buy tx | 47 sell tx | 8 unfinished tx.
# The 174 round: 48 buy tx | 51 sell tx | 9 unfinished tx.
# The 175 round: 49 buy tx | 52 sell tx | 8 unfinished tx.
# The 176 round: 44 buy tx | 55 sell tx | 9 unfinished tx.
# The 177 round: 45 buy tx | 56 sell tx | 8 unfinished tx.
# The 178 round: 50 buy tx | 50 sell tx | 8 unfinished tx.
# The 179 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 180 round: 42 buy tx | 58 sell tx | 8 unfinished tx.
# The 181 round: 53 buy tx | 47 sell tx | 8 unfinished tx.
# The 182 round: 50 buy tx | 50 sell tx | 8 unfinished tx.
# The 183 round: 57 buy tx | 43 sell tx | 8 unfinished tx.
# The 184 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 185 round: 47 buy tx | 55 sell tx | 6 unfinished tx.
# The 186 round: 48 buy tx | 53 sell tx | 5 unfinished tx.
# The 187 round: 51 buy tx | 49 sell tx | 5 unfinished tx.
# The 188 round: 58 buy tx | 41 sell tx | 6 unfinished tx.
# The 189 round: 54 buy tx | 45 sell tx | 7 unfinished tx.
# The 190 round: 44 buy tx | 57 sell tx | 6 unfinished tx.
# The 191 round: 59 buy tx | 43 sell tx | 4 unfinished tx.
# The 192 round: 46 buy tx | 54 sell tx | 4 unfinished tx.
# The 193 round: 44 buy tx | 55 sell tx | 5 unfinished tx.
# The 194 round: 48 buy tx | 51 sell tx | 6 unfinished tx.
# The 195 round: 51 buy tx | 50 sell tx | 5 unfinished tx.
# The 196 round: 55 buy tx | 46 sell tx | 4 unfinished tx.
# The 197 round: 55 buy tx | 46 sell tx | 3 unfinished tx.
# The 198 round: 41 buy tx | 60 sell tx | 2 unfinished tx.
# The 199 round: 47 buy tx | 53 sell tx | 2 unfinished tx.
# The 200 round: 0 buy tx | 100 sell tx | 2 unfinished tx.
# The 201 round: 44 buy tx | 57 sell tx | 1 unfinished tx.
# The 202 round: 49 buy tx | 50 sell tx | 2 unfinished tx.
# The 203 round: 58 buy tx | 43 sell tx | 1 unfinished tx.
# The 204 round: 45 buy tx | 54 sell tx | 2 unfinished tx.
# The 205 round: 56 buy tx | 42 sell tx | 4 unfinished tx.
# The 206 round: 47 buy tx | 53 sell tx | 4 unfinished tx.
# The 207 round: 51 buy tx | 47 sell tx | 6 unfinished tx.
# The 208 round: 56 buy tx | 43 sell tx | 7 unfinished tx.
# The 209 round: 45 buy tx | 54 sell tx | 8 unfinished tx.
# The 210 round: 54 buy tx | 49 sell tx | 5 unfinished tx.
# The 211 round: 51 buy tx | 46 sell tx | 8 unfinished tx.
# The 212 round: 55 buy tx | 47 sell tx | 6 unfinished tx.
# The 213 round: 52 buy tx | 47 sell tx | 7 unfinished tx.
# The 214 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 215 round: 48 buy tx | 51 sell tx | 8 unfinished tx.
# The 216 round: 47 buy tx | 51 sell tx | 10 unfinished tx.
# The 217 round: 60 buy tx | 42 sell tx | 8 unfinished tx.
# The 218 round: 55 buy tx | 46 sell tx | 7 unfinished tx.
# The 219 round: 55 buy tx | 45 sell tx | 7 unfinished tx.
# The 220 round: 57 buy tx | 43 sell tx | 7 unfinished tx.
# The 221 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 222 round: 50 buy tx | 50 sell tx | 7 unfinished tx.
# The 223 round: 39 buy tx | 59 sell tx | 9 unfinished tx.
# The 224 round: 50 buy tx | 51 sell tx | 8 unfinished tx.
# The 225 round: 48 buy tx | 51 sell tx | 9 unfinished tx.
# The 226 round: 45 buy tx | 55 sell tx | 9 unfinished tx.
# The 227 round: 51 buy tx | 50 sell tx | 8 unfinished tx.
# The 228 round: 47 buy tx | 53 sell tx | 8 unfinished tx.
# The 229 round: 55 buy tx | 45 sell tx | 8 unfinished tx.
# The 230 round: 48 buy tx | 51 sell tx | 9 unfinished tx.
# The 231 round: 51 buy tx | 48 sell tx | 10 unfinished tx.
# The 232 round: 54 buy tx | 47 sell tx | 9 unfinished tx.
# The 233 round: 54 buy tx | 47 sell tx | 8 unfinished tx.
# The 234 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 235 round: 41 buy tx | 59 sell tx | 8 unfinished tx.
# The 236 round: 40 buy tx | 61 sell tx | 7 unfinished tx.
# The 237 round: 51 buy tx | 48 sell tx | 8 unfinished tx.
# The 238 round: 55 buy tx | 45 sell tx | 8 unfinished tx.
# The 239 round: 47 buy tx | 53 sell tx | 8 unfinished tx.
# The 240 round: 50 buy tx | 50 sell tx | 8 unfinished tx.
# The 241 round: 43 buy tx | 57 sell tx | 8 unfinished tx.
# The 242 round: 51 buy tx | 49 sell tx | 8 unfinished tx.
# The 243 round: 44 buy tx | 55 sell tx | 9 unfinished tx.
# The 244 round: 58 buy tx | 43 sell tx | 8 unfinished tx.
# The 245 round: 51 buy tx | 50 sell tx | 7 unfinished tx.
# The 246 round: 46 buy tx | 54 sell tx | 7 unfinished tx.
# The 247 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 248 round: 44 buy tx | 56 sell tx | 7 unfinished tx.
# The 249 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 250 round: 47 buy tx | 53 sell tx | 7 unfinished tx.
# The 251 round: 39 buy tx | 60 sell tx | 8 unfinished tx.
# The 252 round: 53 buy tx | 48 sell tx | 7 unfinished tx.
# The 253 round: 49 buy tx | 50 sell tx | 8 unfinished tx.
# The 254 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 255 round: 46 buy tx | 54 sell tx | 8 unfinished tx.
# The 256 round: 53 buy tx | 47 sell tx | 8 unfinished tx.
# The 257 round: 57 buy tx | 43 sell tx | 8 unfinished tx.
# The 258 round: 47 buy tx | 54 sell tx | 7 unfinished tx.
# The 259 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 260 round: 54 buy tx | 44 sell tx | 9 unfinished tx.
# The 261 round: 52 buy tx | 48 sell tx | 9 unfinished tx.
# The 262 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 263 round: 50 buy tx | 52 sell tx | 7 unfinished tx.
# The 264 round: 45 buy tx | 55 sell tx | 7 unfinished tx.
# The 265 round: 45 buy tx | 55 sell tx | 7 unfinished tx.
# The 266 round: 47 buy tx | 52 sell tx | 8 unfinished tx.
# The 267 round: 52 buy tx | 49 sell tx | 7 unfinished tx.
# The 268 round: 47 buy tx | 53 sell tx | 7 unfinished tx.
# The 269 round: 57 buy tx | 41 sell tx | 9 unfinished tx.
# The 270 round: 49 buy tx | 50 sell tx | 10 unfinished tx.
# The 271 round: 49 buy tx | 52 sell tx | 9 unfinished tx.
# The 272 round: 56 buy tx | 43 sell tx | 10 unfinished tx.
# The 273 round: 45 buy tx | 56 sell tx | 9 unfinished tx.
# The 274 round: 50 buy tx | 50 sell tx | 9 unfinished tx.
# The 275 round: 58 buy tx | 41 sell tx | 10 unfinished tx.
# The 276 round: 51 buy tx | 47 sell tx | 12 unfinished tx.
# The 277 round: 44 buy tx | 58 sell tx | 10 unfinished tx.
# The 278 round: 48 buy tx | 53 sell tx | 9 unfinished tx.
# The 279 round: 51 buy tx | 48 sell tx | 10 unfinished tx.
# The 280 round: 54 buy tx | 46 sell tx | 10 unfinished tx.
# The 281 round: 52 buy tx | 49 sell tx | 9 unfinished tx.
# The 282 round: 53 buy tx | 47 sell tx | 9 unfinished tx.
# The 283 round: 46 buy tx | 54 sell tx | 9 unfinished tx.
# The 284 round: 40 buy tx | 60 sell tx | 9 unfinished tx.
# The 285 round: 47 buy tx | 53 sell tx | 9 unfinished tx.
# The 286 round: 54 buy tx | 46 sell tx | 9 unfinished tx.
# The 287 round: 53 buy tx | 47 sell tx | 9 unfinished tx.
# The 288 round: 50 buy tx | 50 sell tx | 9 unfinished tx.
# The 289 round: 46 buy tx | 54 sell tx | 9 unfinished tx.
# The 290 round: 45 buy tx | 55 sell tx | 9 unfinished tx.
# The 291 round: 47 buy tx | 52 sell tx | 10 unfinished tx.
# The 292 round: 36 buy tx | 64 sell tx | 10 unfinished tx.
# The 293 round: 50 buy tx | 50 sell tx | 10 unfinished tx.
# The 294 round: 50 buy tx | 51 sell tx | 9 unfinished tx.
# The 295 round: 48 buy tx | 53 sell tx | 8 unfinished tx.
# The 296 round: 49 buy tx | 52 sell tx | 7 unfinished tx.
# The 297 round: 58 buy tx | 40 sell tx | 9 unfinished tx.
# The 298 round: 46 buy tx | 55 sell tx | 8 unfinished tx.
# The 299 round: 46 buy tx | 54 sell tx | 8 unfinished tx.
# The 300 round: 51 buy tx | 50 sell tx | 7 unfinished tx.
# The 301 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 302 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 303 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 304 round: 35 buy tx | 63 sell tx | 9 unfinished tx.
# The 305 round: 51 buy tx | 51 sell tx | 7 unfinished tx.
# The 306 round: 45 buy tx | 55 sell tx | 7 unfinished tx.
# The 307 round: 50 buy tx | 49 sell tx | 8 unfinished tx.
# The 308 round: 53 buy tx | 48 sell tx | 7 unfinished tx.
# The 309 round: 51 buy tx | 49 sell tx | 7 unfinished tx.
# The 310 round: 53 buy tx | 46 sell tx | 8 unfinished tx.
# The 311 round: 44 buy tx | 56 sell tx | 8 unfinished tx.
# The 312 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 313 round: 52 buy tx | 48 sell tx | 8 unfinished tx.
# The 314 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 315 round: 49 buy tx | 50 sell tx | 9 unfinished tx.
# The 316 round: 43 buy tx | 55 sell tx | 11 unfinished tx.
# The 317 round: 46 buy tx | 55 sell tx | 10 unfinished tx.
# The 318 round: 47 buy tx | 53 sell tx | 10 unfinished tx.
# The 319 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 320 round: 54 buy tx | 46 sell tx | 10 unfinished tx.
# The 321 round: 53 buy tx | 47 sell tx | 10 unfinished tx.
# The 322 round: 50 buy tx | 50 sell tx | 10 unfinished tx.
# The 323 round: 42 buy tx | 58 sell tx | 10 unfinished tx.
# The 324 round: 47 buy tx | 54 sell tx | 9 unfinished tx.
# The 325 round: 61 buy tx | 39 sell tx | 9 unfinished tx.
# The 326 round: 52 buy tx | 49 sell tx | 8 unfinished tx.
# The 327 round: 55 buy tx | 45 sell tx | 8 unfinished tx.
# The 328 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 329 round: 51 buy tx | 49 sell tx | 8 unfinished tx.
# The 330 round: 43 buy tx | 57 sell tx | 8 unfinished tx.
# The 331 round: 45 buy tx | 55 sell tx | 8 unfinished tx.
# The 332 round: 42 buy tx | 58 sell tx | 8 unfinished tx.
# The 333 round: 50 buy tx | 51 sell tx | 7 unfinished tx.
# The 334 round: 49 buy tx | 52 sell tx | 6 unfinished tx.
# The 335 round: 56 buy tx | 45 sell tx | 5 unfinished tx.
# The 336 round: 55 buy tx | 45 sell tx | 5 unfinished tx.
# The 337 round: 51 buy tx | 46 sell tx | 8 unfinished tx.
# The 338 round: 46 buy tx | 54 sell tx | 8 unfinished tx.
# The 339 round: 56 buy tx | 44 sell tx | 8 unfinished tx.
# The 340 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 341 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 342 round: 46 buy tx | 54 sell tx | 8 unfinished tx.
# The 343 round: 48 buy tx | 50 sell tx | 10 unfinished tx.
# The 344 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 345 round: 49 buy tx | 52 sell tx | 9 unfinished tx.
# The 346 round: 54 buy tx | 47 sell tx | 8 unfinished tx.
# The 347 round: 51 buy tx | 49 sell tx | 8 unfinished tx.
# The 348 round: 50 buy tx | 50 sell tx | 8 unfinished tx.
# The 349 round: 50 buy tx | 50 sell tx | 8 unfinished tx.
# The 350 round: 40 buy tx | 60 sell tx | 8 unfinished tx.
# The 351 round: 52 buy tx | 51 sell tx | 5 unfinished tx.
# The 352 round: 42 buy tx | 57 sell tx | 6 unfinished tx.
# The 353 round: 58 buy tx | 42 sell tx | 6 unfinished tx.
# The 354 round: 49 buy tx | 51 sell tx | 6 unfinished tx.
# The 355 round: 49 buy tx | 51 sell tx | 6 unfinished tx.
# The 356 round: 49 buy tx | 50 sell tx | 7 unfinished tx.
# The 357 round: 51 buy tx | 50 sell tx | 6 unfinished tx.
# The 358 round: 64 buy tx | 36 sell tx | 6 unfinished tx.
# The 359 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 360 round: 43 buy tx | 57 sell tx | 6 unfinished tx.
# The 361 round: 53 buy tx | 47 sell tx | 6 unfinished tx.
# The 362 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 363 round: 43 buy tx | 58 sell tx | 5 unfinished tx.
# The 364 round: 45 buy tx | 55 sell tx | 5 unfinished tx.
# The 365 round: 52 buy tx | 48 sell tx | 5 unfinished tx.
# The 366 round: 56 buy tx | 44 sell tx | 5 unfinished tx.
# The 367 round: 42 buy tx | 58 sell tx | 5 unfinished tx.
# The 368 round: 47 buy tx | 53 sell tx | 5 unfinished tx.
# The 369 round: 42 buy tx | 57 sell tx | 6 unfinished tx.
# The 370 round: 50 buy tx | 50 sell tx | 6 unfinished tx.
# The 371 round: 52 buy tx | 47 sell tx | 7 unfinished tx.
# The 372 round: 51 buy tx | 50 sell tx | 6 unfinished tx.
# The 373 round: 46 buy tx | 54 sell tx | 6 unfinished tx.
# The 374 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 375 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 376 round: 50 buy tx | 49 sell tx | 7 unfinished tx.
# The 377 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 378 round: 44 buy tx | 58 sell tx | 5 unfinished tx.
# The 379 round: 46 buy tx | 54 sell tx | 5 unfinished tx.
# The 380 round: 51 buy tx | 48 sell tx | 6 unfinished tx.
# The 381 round: 47 buy tx | 53 sell tx | 6 unfinished tx.
# The 382 round: 54 buy tx | 46 sell tx | 6 unfinished tx.
# The 383 round: 51 buy tx | 50 sell tx | 5 unfinished tx.
# The 384 round: 49 buy tx | 48 sell tx | 8 unfinished tx.
# The 385 round: 46 buy tx | 55 sell tx | 7 unfinished tx.
# The 386 round: 43 buy tx | 57 sell tx | 7 unfinished tx.
# The 387 round: 58 buy tx | 42 sell tx | 7 unfinished tx.
# The 388 round: 46 buy tx | 54 sell tx | 7 unfinished tx.
# The 389 round: 55 buy tx | 45 sell tx | 7 unfinished tx.
# The 390 round: 53 buy tx | 48 sell tx | 6 unfinished tx.
# The 391 round: 52 buy tx | 47 sell tx | 7 unfinished tx.
# The 392 round: 57 buy tx | 44 sell tx | 6 unfinished tx.
# The 393 round: 51 buy tx | 50 sell tx | 5 unfinished tx.
# The 394 round: 46 buy tx | 54 sell tx | 5 unfinished tx.
# The 395 round: 49 buy tx | 51 sell tx | 5 unfinished tx.
# The 396 round: 53 buy tx | 47 sell tx | 5 unfinished tx.
# The 397 round: 50 buy tx | 50 sell tx | 5 unfinished tx.
# The 398 round: 54 buy tx | 46 sell tx | 5 unfinished tx.
# The 399 round: 50 buy tx | 50 sell tx | 5 unfinished tx.
# The 400 round: 100 buy tx | 0 sell tx | 5 unfinished tx.
# The 401 round: 51 buy tx | 50 sell tx | 4 unfinished tx.
# The 402 round: 46 buy tx | 54 sell tx | 4 unfinished tx.
# The 403 round: 47 buy tx | 52 sell tx | 5 unfinished tx.
# The 404 round: 52 buy tx | 47 sell tx | 6 unfinished tx.
# The 405 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 406 round: 51 buy tx | 50 sell tx | 5 unfinished tx.
# The 407 round: 52 buy tx | 49 sell tx | 4 unfinished tx.
# The 408 round: 51 buy tx | 47 sell tx | 6 unfinished tx.
# The 409 round: 57 buy tx | 44 sell tx | 5 unfinished tx.
# The 410 round: 45 buy tx | 55 sell tx | 5 unfinished tx.
# The 411 round: 48 buy tx | 51 sell tx | 6 unfinished tx.
# The 412 round: 55 buy tx | 45 sell tx | 6 unfinished tx.
# The 413 round: 49 buy tx | 51 sell tx | 6 unfinished tx.
# The 414 round: 56 buy tx | 44 sell tx | 6 unfinished tx.
# The 415 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 416 round: 54 buy tx | 46 sell tx | 6 unfinished tx.
# The 417 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 418 round: 53 buy tx | 46 sell tx | 7 unfinished tx.
# The 419 round: 53 buy tx | 48 sell tx | 6 unfinished tx.
# The 420 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 421 round: 50 buy tx | 50 sell tx | 6 unfinished tx.
# The 422 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 423 round: 49 buy tx | 50 sell tx | 7 unfinished tx.
# The 424 round: 51 buy tx | 49 sell tx | 7 unfinished tx.
# The 425 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 426 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 427 round: 49 buy tx | 49 sell tx | 9 unfinished tx.
# The 428 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 429 round: 49 buy tx | 51 sell tx | 9 unfinished tx.
# The 430 round: 47 buy tx | 54 sell tx | 8 unfinished tx.
# The 431 round: 57 buy tx | 42 sell tx | 9 unfinished tx.
# The 432 round: 48 buy tx | 52 sell tx | 9 unfinished tx.
# The 433 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 434 round: 56 buy tx | 45 sell tx | 8 unfinished tx.
# The 435 round: 40 buy tx | 60 sell tx | 8 unfinished tx.
# The 436 round: 51 buy tx | 51 sell tx | 6 unfinished tx.
# The 437 round: 55 buy tx | 45 sell tx | 6 unfinished tx.
# The 438 round: 55 buy tx | 45 sell tx | 6 unfinished tx.
# The 439 round: 46 buy tx | 53 sell tx | 7 unfinished tx.
# The 440 round: 51 buy tx | 49 sell tx | 7 unfinished tx.
# The 441 round: 44 buy tx | 56 sell tx | 7 unfinished tx.
# The 442 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 443 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 444 round: 57 buy tx | 41 sell tx | 9 unfinished tx.
# The 445 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 446 round: 52 buy tx | 49 sell tx | 8 unfinished tx.
# The 447 round: 61 buy tx | 38 sell tx | 9 unfinished tx.
# The 448 round: 55 buy tx | 46 sell tx | 8 unfinished tx.
# The 449 round: 57 buy tx | 43 sell tx | 8 unfinished tx.
# The 450 round: 52 buy tx | 47 sell tx | 9 unfinished tx.
# The 451 round: 54 buy tx | 46 sell tx | 9 unfinished tx.
# The 452 round: 49 buy tx | 51 sell tx | 9 unfinished tx.
# The 453 round: 47 buy tx | 53 sell tx | 9 unfinished tx.
# The 454 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 455 round: 45 buy tx | 54 sell tx | 10 unfinished tx.
# The 456 round: 47 buy tx | 53 sell tx | 10 unfinished tx.
# The 457 round: 45 buy tx | 56 sell tx | 9 unfinished tx.
# The 458 round: 48 buy tx | 52 sell tx | 9 unfinished tx.
# The 459 round: 49 buy tx | 52 sell tx | 8 unfinished tx.
# The 460 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 461 round: 51 buy tx | 49 sell tx | 8 unfinished tx.
# The 462 round: 46 buy tx | 54 sell tx | 8 unfinished tx.
# The 463 round: 54 buy tx | 46 sell tx | 8 unfinished tx.
# The 464 round: 53 buy tx | 47 sell tx | 8 unfinished tx.
# The 465 round: 52 buy tx | 48 sell tx | 8 unfinished tx.
# The 466 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 467 round: 48 buy tx | 50 sell tx | 10 unfinished tx.
# The 468 round: 56 buy tx | 44 sell tx | 10 unfinished tx.
# The 469 round: 47 buy tx | 54 sell tx | 9 unfinished tx.
# The 470 round: 57 buy tx | 42 sell tx | 10 unfinished tx.
# The 471 round: 55 buy tx | 44 sell tx | 11 unfinished tx.
# The 472 round: 59 buy tx | 41 sell tx | 11 unfinished tx.
# The 473 round: 51 buy tx | 48 sell tx | 12 unfinished tx.
# The 474 round: 51 buy tx | 51 sell tx | 10 unfinished tx.
# The 475 round: 49 buy tx | 51 sell tx | 10 unfinished tx.
# The 476 round: 47 buy tx | 53 sell tx | 10 unfinished tx.
# The 477 round: 53 buy tx | 47 sell tx | 10 unfinished tx.
# The 478 round: 51 buy tx | 48 sell tx | 11 unfinished tx.
# The 479 round: 52 buy tx | 49 sell tx | 10 unfinished tx.
# The 480 round: 49 buy tx | 50 sell tx | 11 unfinished tx.
# The 481 round: 52 buy tx | 50 sell tx | 9 unfinished tx.
# The 482 round: 40 buy tx | 60 sell tx | 9 unfinished tx.
# The 483 round: 60 buy tx | 39 sell tx | 10 unfinished tx.
# The 484 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 485 round: 63 buy tx | 38 sell tx | 9 unfinished tx.
# The 486 round: 44 buy tx | 56 sell tx | 9 unfinished tx.
# The 487 round: 48 buy tx | 52 sell tx | 9 unfinished tx.
# The 488 round: 47 buy tx | 53 sell tx | 9 unfinished tx.
# The 489 round: 48 buy tx | 52 sell tx | 9 unfinished tx.
# The 490 round: 36 buy tx | 62 sell tx | 11 unfinished tx.
# The 491 round: 49 buy tx | 51 sell tx | 11 unfinished tx.
# The 492 round: 45 buy tx | 54 sell tx | 12 unfinished tx.
# The 493 round: 46 buy tx | 55 sell tx | 11 unfinished tx.
# The 494 round: 44 buy tx | 59 sell tx | 8 unfinished tx.
# The 495 round: 50 buy tx | 52 sell tx | 6 unfinished tx.
# The 496 round: 57 buy tx | 43 sell tx | 6 unfinished tx.
# The 497 round: 47 buy tx | 52 sell tx | 7 unfinished tx.
# The 498 round: 55 buy tx | 46 sell tx | 6 unfinished tx.
# The 499 round: 56 buy tx | 44 sell tx | 6 unfinished tx.
# The 500 round: 51 buy tx | 48 sell tx | 7 unfinished tx.
# The 501 round: 52 buy tx | 47 sell tx | 8 unfinished tx.
# The 502 round: 47 buy tx | 54 sell tx | 7 unfinished tx.
# The 503 round: 54 buy tx | 44 sell tx | 9 unfinished tx.
# The 504 round: 47 buy tx | 54 sell tx | 8 unfinished tx.
# The 505 round: 56 buy tx | 44 sell tx | 8 unfinished tx.
# The 506 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 507 round: 51 buy tx | 50 sell tx | 7 unfinished tx.
# The 508 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 509 round: 50 buy tx | 50 sell tx | 7 unfinished tx.
# The 510 round: 48 buy tx | 53 sell tx | 6 unfinished tx.
# The 511 round: 56 buy tx | 44 sell tx | 6 unfinished tx.
# The 512 round: 45 buy tx | 55 sell tx | 6 unfinished tx.
# The 513 round: 42 buy tx | 58 sell tx | 6 unfinished tx.
# The 514 round: 49 buy tx | 50 sell tx | 7 unfinished tx.
# The 515 round: 44 buy tx | 57 sell tx | 6 unfinished tx.
# The 516 round: 61 buy tx | 38 sell tx | 7 unfinished tx.
# The 517 round: 51 buy tx | 48 sell tx | 8 unfinished tx.
# The 518 round: 46 buy tx | 55 sell tx | 7 unfinished tx.
# The 519 round: 56 buy tx | 43 sell tx | 8 unfinished tx.
# The 520 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 521 round: 51 buy tx | 49 sell tx | 8 unfinished tx.
# The 522 round: 57 buy tx | 43 sell tx | 8 unfinished tx.
# The 523 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 524 round: 48 buy tx | 51 sell tx | 9 unfinished tx.
# The 525 round: 46 buy tx | 54 sell tx | 9 unfinished tx.
# The 526 round: 52 buy tx | 50 sell tx | 7 unfinished tx.
# The 527 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 528 round: 47 buy tx | 53 sell tx | 7 unfinished tx.
# The 529 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 530 round: 51 buy tx | 49 sell tx | 7 unfinished tx.
# The 531 round: 51 buy tx | 49 sell tx | 7 unfinished tx.
# The 532 round: 46 buy tx | 54 sell tx | 7 unfinished tx.
# The 533 round: 44 buy tx | 56 sell tx | 7 unfinished tx.
# The 534 round: 49 buy tx | 50 sell tx | 8 unfinished tx.
# The 535 round: 42 buy tx | 58 sell tx | 8 unfinished tx.
# The 536 round: 58 buy tx | 42 sell tx | 8 unfinished tx.
# The 537 round: 55 buy tx | 44 sell tx | 9 unfinished tx.
# The 538 round: 48 buy tx | 53 sell tx | 8 unfinished tx.
# The 539 round: 45 buy tx | 54 sell tx | 9 unfinished tx.
# The 540 round: 49 buy tx | 49 sell tx | 11 unfinished tx.
# The 541 round: 53 buy tx | 47 sell tx | 11 unfinished tx.
# The 542 round: 44 buy tx | 58 sell tx | 9 unfinished tx.
# The 543 round: 53 buy tx | 47 sell tx | 9 unfinished tx.
# The 544 round: 44 buy tx | 55 sell tx | 10 unfinished tx.
# The 545 round: 53 buy tx | 48 sell tx | 9 unfinished tx.
# The 546 round: 56 buy tx | 44 sell tx | 9 unfinished tx.
# The 547 round: 50 buy tx | 51 sell tx | 8 unfinished tx.
# The 548 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 549 round: 47 buy tx | 53 sell tx | 8 unfinished tx.
# The 550 round: 49 buy tx | 50 sell tx | 9 unfinished tx.
# The 551 round: 47 buy tx | 52 sell tx | 10 unfinished tx.
# The 552 round: 54 buy tx | 47 sell tx | 9 unfinished tx.
# The 553 round: 50 buy tx | 50 sell tx | 9 unfinished tx.
# The 554 round: 52 buy tx | 47 sell tx | 10 unfinished tx.
# The 555 round: 57 buy tx | 43 sell tx | 10 unfinished tx.
# The 556 round: 63 buy tx | 37 sell tx | 10 unfinished tx.
# The 557 round: 49 buy tx | 51 sell tx | 10 unfinished tx.
# The 558 round: 40 buy tx | 60 sell tx | 10 unfinished tx.
# The 559 round: 49 buy tx | 50 sell tx | 11 unfinished tx.
# The 560 round: 48 buy tx | 52 sell tx | 11 unfinished tx.
# The 561 round: 59 buy tx | 42 sell tx | 10 unfinished tx.
# The 562 round: 47 buy tx | 53 sell tx | 10 unfinished tx.
# The 563 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 564 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 565 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 566 round: 41 buy tx | 59 sell tx | 10 unfinished tx.
# The 567 round: 43 buy tx | 58 sell tx | 9 unfinished tx.
# The 568 round: 52 buy tx | 47 sell tx | 10 unfinished tx.
# The 569 round: 57 buy tx | 43 sell tx | 10 unfinished tx.
# The 570 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 571 round: 46 buy tx | 54 sell tx | 10 unfinished tx.
# The 572 round: 38 buy tx | 62 sell tx | 10 unfinished tx.
# The 573 round: 54 buy tx | 48 sell tx | 8 unfinished tx.
# The 574 round: 51 buy tx | 49 sell tx | 8 unfinished tx.
# The 575 round: 45 buy tx | 55 sell tx | 8 unfinished tx.
# The 576 round: 50 buy tx | 51 sell tx | 7 unfinished tx.
# The 577 round: 56 buy tx | 44 sell tx | 7 unfinished tx.
# The 578 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 579 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 580 round: 47 buy tx | 53 sell tx | 7 unfinished tx.
# The 581 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 582 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 583 round: 46 buy tx | 54 sell tx | 7 unfinished tx.
# The 584 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 585 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 586 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 587 round: 43 buy tx | 57 sell tx | 7 unfinished tx.
# The 588 round: 42 buy tx | 57 sell tx | 8 unfinished tx.
# The 589 round: 53 buy tx | 45 sell tx | 10 unfinished tx.
# The 590 round: 57 buy tx | 42 sell tx | 11 unfinished tx.
# The 591 round: 45 buy tx | 56 sell tx | 10 unfinished tx.
# The 592 round: 50 buy tx | 51 sell tx | 9 unfinished tx.
# The 593 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 594 round: 50 buy tx | 50 sell tx | 9 unfinished tx.
# The 595 round: 44 buy tx | 56 sell tx | 9 unfinished tx.
# The 596 round: 49 buy tx | 51 sell tx | 9 unfinished tx.
# The 597 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 598 round: 49 buy tx | 50 sell tx | 10 unfinished tx.
# The 599 round: 54 buy tx | 46 sell tx | 10 unfinished tx.
# The 600 round: 100 buy tx | 1 sell tx | 9 unfinished tx.
# The 601 round: 48 buy tx | 54 sell tx | 7 unfinished tx.
# The 602 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 603 round: 41 buy tx | 59 sell tx | 7 unfinished tx.
# The 604 round: 43 buy tx | 56 sell tx | 8 unfinished tx.
# The 605 round: 47 buy tx | 53 sell tx | 8 unfinished tx.
# The 606 round: 44 buy tx | 55 sell tx | 9 unfinished tx.
# The 607 round: 48 buy tx | 52 sell tx | 9 unfinished tx.
# The 608 round: 54 buy tx | 46 sell tx | 9 unfinished tx.
# The 609 round: 55 buy tx | 45 sell tx | 9 unfinished tx.
# The 610 round: 52 buy tx | 48 sell tx | 9 unfinished tx.
# The 611 round: 44 buy tx | 55 sell tx | 10 unfinished tx.
# The 612 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 613 round: 48 buy tx | 51 sell tx | 11 unfinished tx.
# The 614 round: 52 buy tx | 48 sell tx | 11 unfinished tx.
# The 615 round: 45 buy tx | 55 sell tx | 11 unfinished tx.
# The 616 round: 59 buy tx | 40 sell tx | 12 unfinished tx.
# The 617 round: 48 buy tx | 54 sell tx | 10 unfinished tx.
# The 618 round: 45 buy tx | 55 sell tx | 10 unfinished tx.
# The 619 round: 45 buy tx | 55 sell tx | 10 unfinished tx.
# The 620 round: 44 buy tx | 55 sell tx | 11 unfinished tx.
# The 621 round: 47 buy tx | 53 sell tx | 11 unfinished tx.
# The 622 round: 38 buy tx | 62 sell tx | 11 unfinished tx.
# The 623 round: 51 buy tx | 50 sell tx | 10 unfinished tx.
# The 624 round: 47 buy tx | 52 sell tx | 11 unfinished tx.
# The 625 round: 51 buy tx | 49 sell tx | 11 unfinished tx.
# The 626 round: 50 buy tx | 50 sell tx | 11 unfinished tx.
# The 627 round: 47 buy tx | 53 sell tx | 11 unfinished tx.
# The 628 round: 44 buy tx | 55 sell tx | 12 unfinished tx.
# The 629 round: 48 buy tx | 53 sell tx | 11 unfinished tx.
# The 630 round: 42 buy tx | 58 sell tx | 11 unfinished tx.
# The 631 round: 48 buy tx | 52 sell tx | 11 unfinished tx.
# The 632 round: 51 buy tx | 49 sell tx | 11 unfinished tx.
# The 633 round: 52 buy tx | 48 sell tx | 11 unfinished tx.
# The 634 round: 50 buy tx | 50 sell tx | 11 unfinished tx.
# The 635 round: 49 buy tx | 49 sell tx | 13 unfinished tx.
# The 636 round: 49 buy tx | 53 sell tx | 11 unfinished tx.
# The 637 round: 44 buy tx | 56 sell tx | 11 unfinished tx.
# The 638 round: 59 buy tx | 42 sell tx | 10 unfinished tx.
# The 639 round: 50 buy tx | 50 sell tx | 10 unfinished tx.
# The 640 round: 44 buy tx | 56 sell tx | 10 unfinished tx.
# The 641 round: 55 buy tx | 45 sell tx | 10 unfinished tx.
# The 642 round: 50 buy tx | 50 sell tx | 10 unfinished tx.
# The 643 round: 58 buy tx | 42 sell tx | 10 unfinished tx.
# The 644 round: 53 buy tx | 46 sell tx | 11 unfinished tx.
# The 645 round: 46 buy tx | 55 sell tx | 10 unfinished tx.
# The 646 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 647 round: 49 buy tx | 51 sell tx | 10 unfinished tx.
# The 648 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 649 round: 49 buy tx | 52 sell tx | 9 unfinished tx.
# The 650 round: 44 buy tx | 56 sell tx | 9 unfinished tx.
# The 651 round: 51 buy tx | 48 sell tx | 10 unfinished tx.
# The 652 round: 50 buy tx | 50 sell tx | 10 unfinished tx.
# The 653 round: 51 buy tx | 49 sell tx | 10 unfinished tx.
# The 654 round: 57 buy tx | 43 sell tx | 10 unfinished tx.
# The 655 round: 50 buy tx | 50 sell tx | 10 unfinished tx.
# The 656 round: 52 buy tx | 48 sell tx | 10 unfinished tx.
# The 657 round: 48 buy tx | 52 sell tx | 10 unfinished tx.
# The 658 round: 45 buy tx | 54 sell tx | 11 unfinished tx.
# The 659 round: 47 buy tx | 52 sell tx | 12 unfinished tx.
# The 660 round: 53 buy tx | 48 sell tx | 11 unfinished tx.
# The 661 round: 43 buy tx | 57 sell tx | 11 unfinished tx.
# The 662 round: 52 buy tx | 48 sell tx | 11 unfinished tx.
# The 663 round: 42 buy tx | 59 sell tx | 10 unfinished tx.
# The 664 round: 50 buy tx | 52 sell tx | 8 unfinished tx.
# The 665 round: 46 buy tx | 53 sell tx | 9 unfinished tx.
# The 666 round: 47 buy tx | 53 sell tx | 9 unfinished tx.
# The 667 round: 46 buy tx | 55 sell tx | 8 unfinished tx.
# The 668 round: 57 buy tx | 43 sell tx | 8 unfinished tx.
# The 669 round: 55 buy tx | 44 sell tx | 9 unfinished tx.
# The 670 round: 56 buy tx | 44 sell tx | 9 unfinished tx.
# The 671 round: 56 buy tx | 44 sell tx | 9 unfinished tx.
# The 672 round: 41 buy tx | 57 sell tx | 11 unfinished tx.
# The 673 round: 59 buy tx | 42 sell tx | 10 unfinished tx.
# The 674 round: 45 buy tx | 58 sell tx | 7 unfinished tx.
# The 675 round: 46 buy tx | 54 sell tx | 7 unfinished tx.
# The 676 round: 58 buy tx | 41 sell tx | 8 unfinished tx.
# The 677 round: 45 buy tx | 55 sell tx | 8 unfinished tx.
# The 678 round: 40 buy tx | 60 sell tx | 8 unfinished tx.
# The 679 round: 55 buy tx | 46 sell tx | 7 unfinished tx.
# The 680 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 681 round: 45 buy tx | 55 sell tx | 7 unfinished tx.
# The 682 round: 60 buy tx | 40 sell tx | 7 unfinished tx.
# The 683 round: 43 buy tx | 58 sell tx | 6 unfinished tx.
# The 684 round: 44 buy tx | 55 sell tx | 7 unfinished tx.
# The 685 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 686 round: 51 buy tx | 50 sell tx | 6 unfinished tx.
# The 687 round: 44 buy tx | 55 sell tx | 7 unfinished tx.
# The 688 round: 58 buy tx | 42 sell tx | 7 unfinished tx.
# The 689 round: 45 buy tx | 56 sell tx | 6 unfinished tx.
# The 690 round: 53 buy tx | 47 sell tx | 6 unfinished tx.
# The 691 round: 59 buy tx | 41 sell tx | 6 unfinished tx.
# The 692 round: 45 buy tx | 55 sell tx | 6 unfinished tx.
# The 693 round: 56 buy tx | 44 sell tx | 6 unfinished tx.
# The 694 round: 43 buy tx | 57 sell tx | 6 unfinished tx.
# The 695 round: 40 buy tx | 59 sell tx | 7 unfinished tx.
# The 696 round: 50 buy tx | 50 sell tx | 7 unfinished tx.
# The 697 round: 40 buy tx | 58 sell tx | 9 unfinished tx.
# The 698 round: 45 buy tx | 55 sell tx | 9 unfinished tx.
# The 699 round: 53 buy tx | 48 sell tx | 8 unfinished tx.
# The 700 round: 35 buy tx | 63 sell tx | 10 unfinished tx.
# The 701 round: 50 buy tx | 50 sell tx | 10 unfinished tx.
# The 702 round: 51 buy tx | 49 sell tx | 10 unfinished tx.
# The 703 round: 49 buy tx | 51 sell tx | 10 unfinished tx.
# The 704 round: 51 buy tx | 48 sell tx | 11 unfinished tx.
# The 705 round: 59 buy tx | 42 sell tx | 10 unfinished tx.
# The 706 round: 55 buy tx | 47 sell tx | 8 unfinished tx.
# The 707 round: 53 buy tx | 49 sell tx | 6 unfinished tx.
# The 708 round: 49 buy tx | 51 sell tx | 6 unfinished tx.
# The 709 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 710 round: 49 buy tx | 51 sell tx | 6 unfinished tx.
# The 711 round: 44 buy tx | 56 sell tx | 6 unfinished tx.
# The 712 round: 53 buy tx | 47 sell tx | 6 unfinished tx.
# The 713 round: 45 buy tx | 54 sell tx | 7 unfinished tx.
# The 714 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 715 round: 57 buy tx | 42 sell tx | 8 unfinished tx.
# The 716 round: 52 buy tx | 47 sell tx | 9 unfinished tx.
# The 717 round: 51 buy tx | 49 sell tx | 9 unfinished tx.
# The 718 round: 49 buy tx | 52 sell tx | 8 unfinished tx.
# The 719 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 720 round: 48 buy tx | 51 sell tx | 9 unfinished tx.
# The 721 round: 51 buy tx | 48 sell tx | 10 unfinished tx.
# The 722 round: 48 buy tx | 53 sell tx | 9 unfinished tx.
# The 723 round: 54 buy tx | 47 sell tx | 8 unfinished tx.
# The 724 round: 43 buy tx | 58 sell tx | 7 unfinished tx.
# The 725 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 726 round: 47 buy tx | 52 sell tx | 8 unfinished tx.
# The 727 round: 46 buy tx | 55 sell tx | 7 unfinished tx.
# The 728 round: 54 buy tx | 47 sell tx | 6 unfinished tx.
# The 729 round: 50 buy tx | 50 sell tx | 6 unfinished tx.
# The 730 round: 53 buy tx | 47 sell tx | 6 unfinished tx.
# The 731 round: 55 buy tx | 46 sell tx | 5 unfinished tx.
# The 732 round: 49 buy tx | 51 sell tx | 5 unfinished tx.
# The 733 round: 47 buy tx | 53 sell tx | 5 unfinished tx.
# The 734 round: 56 buy tx | 44 sell tx | 5 unfinished tx.
# The 735 round: 56 buy tx | 44 sell tx | 5 unfinished tx.
# The 736 round: 51 buy tx | 49 sell tx | 5 unfinished tx.
# The 737 round: 45 buy tx | 54 sell tx | 6 unfinished tx.
# The 738 round: 54 buy tx | 44 sell tx | 8 unfinished tx.
# The 739 round: 54 buy tx | 47 sell tx | 7 unfinished tx.
# The 740 round: 59 buy tx | 41 sell tx | 7 unfinished tx.
# The 741 round: 51 buy tx | 50 sell tx | 6 unfinished tx.
# The 742 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 743 round: 45 buy tx | 55 sell tx | 6 unfinished tx.
# The 744 round: 44 buy tx | 56 sell tx | 6 unfinished tx.
# The 745 round: 46 buy tx | 53 sell tx | 7 unfinished tx.
# The 746 round: 48 buy tx | 53 sell tx | 6 unfinished tx.
# The 747 round: 48 buy tx | 53 sell tx | 5 unfinished tx.
# The 748 round: 52 buy tx | 48 sell tx | 5 unfinished tx.
# The 749 round: 51 buy tx | 49 sell tx | 5 unfinished tx.
# The 750 round: 50 buy tx | 50 sell tx | 5 unfinished tx.
# The 751 round: 47 buy tx | 53 sell tx | 5 unfinished tx.
# The 752 round: 49 buy tx | 51 sell tx | 5 unfinished tx.
# The 753 round: 47 buy tx | 52 sell tx | 6 unfinished tx.
# The 754 round: 50 buy tx | 49 sell tx | 7 unfinished tx.
# The 755 round: 51 buy tx | 50 sell tx | 6 unfinished tx.
# The 756 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 757 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 758 round: 63 buy tx | 35 sell tx | 8 unfinished tx.
# The 759 round: 52 buy tx | 48 sell tx | 8 unfinished tx.
# The 760 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 761 round: 45 buy tx | 54 sell tx | 9 unfinished tx.
# The 762 round: 47 buy tx | 55 sell tx | 7 unfinished tx.
# The 763 round: 47 buy tx | 53 sell tx | 7 unfinished tx.
# The 764 round: 56 buy tx | 44 sell tx | 7 unfinished tx.
# The 765 round: 47 buy tx | 53 sell tx | 7 unfinished tx.
# The 766 round: 50 buy tx | 49 sell tx | 8 unfinished tx.
# The 767 round: 47 buy tx | 53 sell tx | 8 unfinished tx.
# The 768 round: 55 buy tx | 46 sell tx | 7 unfinished tx.
# The 769 round: 45 buy tx | 55 sell tx | 7 unfinished tx.
# The 770 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 771 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 772 round: 55 buy tx | 44 sell tx | 8 unfinished tx.
# The 773 round: 50 buy tx | 50 sell tx | 8 unfinished tx.
# The 774 round: 52 buy tx | 48 sell tx | 8 unfinished tx.
# The 775 round: 57 buy tx | 43 sell tx | 8 unfinished tx.
# The 776 round: 45 buy tx | 55 sell tx | 8 unfinished tx.
# The 777 round: 48 buy tx | 51 sell tx | 9 unfinished tx.
# The 778 round: 43 buy tx | 57 sell tx | 9 unfinished tx.
# The 779 round: 51 buy tx | 48 sell tx | 10 unfinished tx.
# The 780 round: 57 buy tx | 43 sell tx | 10 unfinished tx.
# The 781 round: 43 buy tx | 58 sell tx | 9 unfinished tx.
# The 782 round: 50 buy tx | 51 sell tx | 8 unfinished tx.
# The 783 round: 54 buy tx | 46 sell tx | 8 unfinished tx.
# The 784 round: 48 buy tx | 51 sell tx | 9 unfinished tx.
# The 785 round: 46 buy tx | 55 sell tx | 8 unfinished tx.
# The 786 round: 49 buy tx | 52 sell tx | 7 unfinished tx.
# The 787 round: 50 buy tx | 50 sell tx | 7 unfinished tx.
# The 788 round: 58 buy tx | 43 sell tx | 6 unfinished tx.
# The 789 round: 54 buy tx | 46 sell tx | 6 unfinished tx.
# The 790 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 791 round: 51 buy tx | 49 sell tx | 6 unfinished tx.
# The 792 round: 56 buy tx | 44 sell tx | 6 unfinished tx.
# The 793 round: 53 buy tx | 47 sell tx | 6 unfinished tx.
# The 794 round: 52 buy tx | 47 sell tx | 7 unfinished tx.
# The 795 round: 48 buy tx | 51 sell tx | 8 unfinished tx.
# The 796 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 797 round: 53 buy tx | 46 sell tx | 9 unfinished tx.
# The 798 round: 45 buy tx | 56 sell tx | 8 unfinished tx.
# The 799 round: 56 buy tx | 46 sell tx | 6 unfinished tx.
# The 800 round: 1 buy tx | 100 sell tx | 5 unfinished tx.
# The 801 round: 53 buy tx | 48 sell tx | 4 unfinished tx.
# The 802 round: 50 buy tx | 50 sell tx | 4 unfinished tx.
# The 803 round: 51 buy tx | 48 sell tx | 5 unfinished tx.
# The 804 round: 53 buy tx | 47 sell tx | 5 unfinished tx.
# The 805 round: 49 buy tx | 51 sell tx | 5 unfinished tx.
# The 806 round: 44 buy tx | 57 sell tx | 4 unfinished tx.
# The 807 round: 45 buy tx | 55 sell tx | 4 unfinished tx.
# The 808 round: 50 buy tx | 51 sell tx | 3 unfinished tx.
# The 809 round: 47 buy tx | 52 sell tx | 4 unfinished tx.
# The 810 round: 50 buy tx | 51 sell tx | 3 unfinished tx.
# The 811 round: 51 buy tx | 48 sell tx | 4 unfinished tx.
# The 812 round: 41 buy tx | 60 sell tx | 3 unfinished tx.
# The 813 round: 49 buy tx | 51 sell tx | 3 unfinished tx.
# The 814 round: 52 buy tx | 48 sell tx | 3 unfinished tx.
# The 815 round: 58 buy tx | 42 sell tx | 3 unfinished tx.
# The 816 round: 53 buy tx | 44 sell tx | 6 unfinished tx.
# The 817 round: 50 buy tx | 50 sell tx | 6 unfinished tx.
# The 818 round: 43 buy tx | 57 sell tx | 6 unfinished tx.
# The 819 round: 51 buy tx | 49 sell tx | 6 unfinished tx.
# The 820 round: 47 buy tx | 53 sell tx | 6 unfinished tx.
# The 821 round: 63 buy tx | 38 sell tx | 5 unfinished tx.
# The 822 round: 52 buy tx | 47 sell tx | 6 unfinished tx.
# The 823 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 824 round: 45 buy tx | 54 sell tx | 7 unfinished tx.
# The 825 round: 46 buy tx | 56 sell tx | 5 unfinished tx.
# The 826 round: 50 buy tx | 50 sell tx | 5 unfinished tx.
# The 827 round: 47 buy tx | 53 sell tx | 5 unfinished tx.
# The 828 round: 43 buy tx | 57 sell tx | 5 unfinished tx.
# The 829 round: 49 buy tx | 51 sell tx | 5 unfinished tx.
# The 830 round: 57 buy tx | 43 sell tx | 5 unfinished tx.
# The 831 round: 43 buy tx | 57 sell tx | 5 unfinished tx.
# The 832 round: 56 buy tx | 44 sell tx | 5 unfinished tx.
# The 833 round: 52 buy tx | 48 sell tx | 5 unfinished tx.
# The 834 round: 56 buy tx | 44 sell tx | 5 unfinished tx.
# The 835 round: 50 buy tx | 50 sell tx | 5 unfinished tx.
# The 836 round: 57 buy tx | 43 sell tx | 5 unfinished tx.
# The 837 round: 50 buy tx | 50 sell tx | 5 unfinished tx.
# The 838 round: 53 buy tx | 47 sell tx | 5 unfinished tx.
# The 839 round: 44 buy tx | 56 sell tx | 5 unfinished tx.
# The 840 round: 48 buy tx | 52 sell tx | 5 unfinished tx.
# The 841 round: 49 buy tx | 51 sell tx | 5 unfinished tx.
# The 842 round: 44 buy tx | 56 sell tx | 5 unfinished tx.
# The 843 round: 45 buy tx | 55 sell tx | 5 unfinished tx.
# The 844 round: 56 buy tx | 45 sell tx | 4 unfinished tx.
# The 845 round: 56 buy tx | 43 sell tx | 5 unfinished tx.
# The 846 round: 59 buy tx | 41 sell tx | 5 unfinished tx.
# The 847 round: 50 buy tx | 49 sell tx | 6 unfinished tx.
# The 848 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 849 round: 47 buy tx | 53 sell tx | 6 unfinished tx.
# The 850 round: 47 buy tx | 54 sell tx | 5 unfinished tx.
# The 851 round: 53 buy tx | 44 sell tx | 8 unfinished tx.
# The 852 round: 48 buy tx | 53 sell tx | 7 unfinished tx.
# The 853 round: 43 buy tx | 57 sell tx | 7 unfinished tx.
# The 854 round: 54 buy tx | 47 sell tx | 6 unfinished tx.
# The 855 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 856 round: 55 buy tx | 45 sell tx | 6 unfinished tx.
# The 857 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 858 round: 48 buy tx | 51 sell tx | 7 unfinished tx.
# The 859 round: 55 buy tx | 46 sell tx | 6 unfinished tx.
# The 860 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 861 round: 47 buy tx | 52 sell tx | 7 unfinished tx.
# The 862 round: 49 buy tx | 51 sell tx | 7 unfinished tx.
# The 863 round: 46 buy tx | 55 sell tx | 6 unfinished tx.
# The 864 round: 49 buy tx | 51 sell tx | 6 unfinished tx.
# The 865 round: 52 buy tx | 47 sell tx | 7 unfinished tx.
# The 866 round: 52 buy tx | 49 sell tx | 6 unfinished tx.
# The 867 round: 62 buy tx | 39 sell tx | 5 unfinished tx.
# The 868 round: 57 buy tx | 43 sell tx | 5 unfinished tx.
# The 869 round: 47 buy tx | 53 sell tx | 5 unfinished tx.
# The 870 round: 51 buy tx | 49 sell tx | 5 unfinished tx.
# The 871 round: 56 buy tx | 44 sell tx | 5 unfinished tx.
# The 872 round: 57 buy tx | 43 sell tx | 5 unfinished tx.
# The 873 round: 48 buy tx | 52 sell tx | 5 unfinished tx.
# The 874 round: 46 buy tx | 53 sell tx | 6 unfinished tx.
# The 875 round: 36 buy tx | 63 sell tx | 7 unfinished tx.
# The 876 round: 51 buy tx | 49 sell tx | 7 unfinished tx.
# The 877 round: 44 buy tx | 56 sell tx | 7 unfinished tx.
# The 878 round: 55 buy tx | 44 sell tx | 8 unfinished tx.
# The 879 round: 52 buy tx | 50 sell tx | 6 unfinished tx.
# The 880 round: 59 buy tx | 40 sell tx | 7 unfinished tx.
# The 881 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 882 round: 44 buy tx | 56 sell tx | 7 unfinished tx.
# The 883 round: 49 buy tx | 52 sell tx | 6 unfinished tx.
# The 884 round: 45 buy tx | 55 sell tx | 6 unfinished tx.
# The 885 round: 45 buy tx | 54 sell tx | 7 unfinished tx.
# The 886 round: 49 buy tx | 52 sell tx | 6 unfinished tx.
# The 887 round: 45 buy tx | 54 sell tx | 7 unfinished tx.
# The 888 round: 40 buy tx | 60 sell tx | 7 unfinished tx.
# The 889 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 890 round: 46 buy tx | 54 sell tx | 7 unfinished tx.
# The 891 round: 57 buy tx | 43 sell tx | 7 unfinished tx.
# The 892 round: 50 buy tx | 50 sell tx | 7 unfinished tx.
# The 893 round: 41 buy tx | 58 sell tx | 8 unfinished tx.
# The 894 round: 47 buy tx | 52 sell tx | 9 unfinished tx.
# The 895 round: 48 buy tx | 53 sell tx | 8 unfinished tx.
# The 896 round: 50 buy tx | 52 sell tx | 6 unfinished tx.
# The 897 round: 52 buy tx | 46 sell tx | 8 unfinished tx.
# The 898 round: 51 buy tx | 49 sell tx | 8 unfinished tx.
# The 899 round: 59 buy tx | 41 sell tx | 8 unfinished tx.
# The 900 round: 52 buy tx | 49 sell tx | 7 unfinished tx.
# The 901 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 902 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 903 round: 51 buy tx | 49 sell tx | 7 unfinished tx.
# The 904 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 905 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 906 round: 52 buy tx | 50 sell tx | 5 unfinished tx.
# The 907 round: 51 buy tx | 49 sell tx | 5 unfinished tx.
# The 908 round: 47 buy tx | 52 sell tx | 6 unfinished tx.
# The 909 round: 50 buy tx | 49 sell tx | 7 unfinished tx.
# The 910 round: 47 buy tx | 54 sell tx | 6 unfinished tx.
# The 911 round: 58 buy tx | 43 sell tx | 5 unfinished tx.
# The 912 round: 47 buy tx | 52 sell tx | 6 unfinished tx.
# The 913 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 914 round: 48 buy tx | 53 sell tx | 5 unfinished tx.
# The 915 round: 53 buy tx | 47 sell tx | 5 unfinished tx.
# The 916 round: 57 buy tx | 43 sell tx | 5 unfinished tx.
# The 917 round: 50 buy tx | 49 sell tx | 6 unfinished tx.
# The 918 round: 39 buy tx | 61 sell tx | 6 unfinished tx.
# The 919 round: 54 buy tx | 46 sell tx | 6 unfinished tx.
# The 920 round: 51 buy tx | 49 sell tx | 6 unfinished tx.
# The 921 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 922 round: 45 buy tx | 55 sell tx | 6 unfinished tx.
# The 923 round: 52 buy tx | 48 sell tx | 6 unfinished tx.
# The 924 round: 49 buy tx | 50 sell tx | 7 unfinished tx.
# The 925 round: 43 buy tx | 57 sell tx | 7 unfinished tx.
# The 926 round: 52 buy tx | 49 sell tx | 6 unfinished tx.
# The 927 round: 57 buy tx | 43 sell tx | 6 unfinished tx.
# The 928 round: 55 buy tx | 45 sell tx | 6 unfinished tx.
# The 929 round: 48 buy tx | 48 sell tx | 10 unfinished tx.
# The 930 round: 42 buy tx | 60 sell tx | 8 unfinished tx.
# The 931 round: 55 buy tx | 44 sell tx | 9 unfinished tx.
# The 932 round: 50 buy tx | 51 sell tx | 8 unfinished tx.
# The 933 round: 59 buy tx | 41 sell tx | 8 unfinished tx.
# The 934 round: 46 buy tx | 55 sell tx | 7 unfinished tx.
# The 935 round: 53 buy tx | 47 sell tx | 7 unfinished tx.
# The 936 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 937 round: 53 buy tx | 48 sell tx | 6 unfinished tx.
# The 938 round: 51 buy tx | 49 sell tx | 6 unfinished tx.
# The 939 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 940 round: 50 buy tx | 49 sell tx | 7 unfinished tx.
# The 941 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 942 round: 41 buy tx | 58 sell tx | 8 unfinished tx.
# The 943 round: 46 buy tx | 55 sell tx | 7 unfinished tx.
# The 944 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 945 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 946 round: 43 buy tx | 57 sell tx | 7 unfinished tx.
# The 947 round: 59 buy tx | 41 sell tx | 7 unfinished tx.
# The 948 round: 45 buy tx | 53 sell tx | 9 unfinished tx.
# The 949 round: 57 buy tx | 44 sell tx | 8 unfinished tx.
# The 950 round: 53 buy tx | 47 sell tx | 8 unfinished tx.
# The 951 round: 52 buy tx | 48 sell tx | 8 unfinished tx.
# The 952 round: 49 buy tx | 50 sell tx | 9 unfinished tx.
# The 953 round: 49 buy tx | 52 sell tx | 8 unfinished tx.
# The 954 round: 57 buy tx | 43 sell tx | 8 unfinished tx.
# The 955 round: 44 buy tx | 56 sell tx | 8 unfinished tx.
# The 956 round: 43 buy tx | 56 sell tx | 9 unfinished tx.
# The 957 round: 52 buy tx | 48 sell tx | 9 unfinished tx.
# The 958 round: 48 buy tx | 53 sell tx | 8 unfinished tx.
# The 959 round: 48 buy tx | 53 sell tx | 7 unfinished tx.
# The 960 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 961 round: 52 buy tx | 48 sell tx | 7 unfinished tx.
# The 962 round: 45 buy tx | 54 sell tx | 8 unfinished tx.
# The 963 round: 52 buy tx | 47 sell tx | 9 unfinished tx.
# The 964 round: 42 buy tx | 58 sell tx | 9 unfinished tx.
# The 965 round: 53 buy tx | 48 sell tx | 8 unfinished tx.
# The 966 round: 46 buy tx | 52 sell tx | 10 unfinished tx.
# The 967 round: 38 buy tx | 61 sell tx | 11 unfinished tx.
# The 968 round: 51 buy tx | 51 sell tx | 9 unfinished tx.
# The 969 round: 52 buy tx | 49 sell tx | 8 unfinished tx.
# The 970 round: 55 buy tx | 45 sell tx | 8 unfinished tx.
# The 971 round: 53 buy tx | 47 sell tx | 8 unfinished tx.
# The 972 round: 34 buy tx | 66 sell tx | 8 unfinished tx.
# The 973 round: 58 buy tx | 42 sell tx | 8 unfinished tx.
# The 974 round: 49 buy tx | 50 sell tx | 9 unfinished tx.
# The 975 round: 51 buy tx | 50 sell tx | 8 unfinished tx.
# The 976 round: 48 buy tx | 52 sell tx | 8 unfinished tx.
# The 977 round: 56 buy tx | 43 sell tx | 9 unfinished tx.
# The 978 round: 60 buy tx | 41 sell tx | 8 unfinished tx.
# The 979 round: 45 buy tx | 57 sell tx | 6 unfinished tx.
# The 980 round: 53 buy tx | 44 sell tx | 9 unfinished tx.
# The 981 round: 47 buy tx | 55 sell tx | 7 unfinished tx.
# The 982 round: 49 buy tx | 50 sell tx | 8 unfinished tx.
# The 983 round: 52 buy tx | 50 sell tx | 6 unfinished tx.
# The 984 round: 53 buy tx | 47 sell tx | 6 unfinished tx.
# The 985 round: 52 buy tx | 47 sell tx | 7 unfinished tx.
# The 986 round: 48 buy tx | 52 sell tx | 7 unfinished tx.
# The 987 round: 48 buy tx | 50 sell tx | 9 unfinished tx.
# The 988 round: 53 buy tx | 49 sell tx | 7 unfinished tx.
# The 989 round: 54 buy tx | 46 sell tx | 7 unfinished tx.
# The 990 round: 46 buy tx | 53 sell tx | 8 unfinished tx.
# The 991 round: 49 buy tx | 51 sell tx | 8 unfinished tx.
# The 992 round: 41 buy tx | 61 sell tx | 6 unfinished tx.
# The 993 round: 48 buy tx | 52 sell tx | 6 unfinished tx.
# The 994 round: 48 buy tx | 50 sell tx | 8 unfinished tx.
# The 995 round: 54 buy tx | 46 sell tx | 8 unfinished tx.
# The 996 round: 50 buy tx | 50 sell tx | 8 unfinished tx.
# The 997 round: 52 buy tx | 48 sell tx | 8 unfinished tx.
# The 998 round: 52 buy tx | 48 sell tx | 8 unfinished tx.
# The 999 round: 48 buy tx | 52 sell tx | 8 unfinished tx.

# %%
'''
here the case is the customers are just sell or buy in random -- throwing a coin to decide sell or buy,
while ignoring the current price might be lower than expected sell price, or higher than expected buy price
'''
# issue a new smart token
initIssue = 3000000
CRR = 0.2
initTransaction = initIssue * (1-CRR)
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=initIssue)

# market initialization
# BancorMarket = Market()

'''
init properties: 
We have #TimeRound round, bouncing happens after every bouncing interval
Totally #custNum  customers come in
In each time round, #tx_round transactions, 
   with original reserve: #custOriginalReserve
   with original smarttokens: #custOriginalSmartTokens
'''
TimeRound = 1000
bouncingInterval = 200
bouncingRange = 10
tx_round = 100
custNum = 5000
sigma = 0.1
custOriginalReserve_mu = 200
custOriginalSmartTokens_mu = 200
custOriginalReserve = np.random.normal(custOriginalReserve_mu, 0.1, custNum) # 0.5 is sigma
custOriginalSmartTokens = np.random.normal(custOriginalSmartTokens_mu, 0.1, custNum) # 0.5 is sigma
'''
prevent the init money exhausts the balance, 
here we already set initIssue SmartToken to a large number,
which actually is hard to be exhausted,
also, we should consider the situation that the init issued smarttokens is comparably small,
      or the init smarttokens is held in customers in a large amount
'''
if sum(custOriginalSmartTokens) > initTransaction:
    print '&& WARNING, too many init smart tokens from customers'
    if sum(custOriginalSmartTokens) > initIssue:
        print '** ERROR, too many init smart tokens'
        turndown = 1 + 'klk'

#custmer initialization, first set all their expected Price to be -1
custlist = []
i = 0
while i < custNum:
    Joe = Customers(smartToken = KennyCoin, ownedSmartTokens = int(custOriginalSmartTokens[i]), reserveTokens=int(custOriginalReserve[i]), expectedPrice=-1)
    custlist.append(Joe)
    i = i + 1
# moneyTracker records the money
moneyTracker = []
# PriceTracker records the change of the price
PriceTracker = []
# failureTracker records the failure rate of transactions
failed_rateTracker = []
waitingTracker = []

# tx_list records the transaction order which remains in the market
tx_list = []
j=0
while j < TimeRound:
    buyNum = 0
    sellNum = 0
    CurrentPrice = KennyCoin.getPrice()
    '''
    scan the tx_list, follow the order to try transactions one by one, 
    if succeed, remove the tx element.
    P.S. the element in tx_list is (MARK, cust, tokenNum), 
         when MARK is 1, the cust tries to buy, when MARK is -1, cust tries to sell
    '''
    waitingTx_Num_Old = len(tx_list)
    s = 0
    while s < len(tx_list):
        tx_mark = tx_list[s][0]
        tx_cust = tx_list[s][1]
        tx_tokenNum = tx_list[s][2]
        if tx_mark == - 1:
            # try sell
            if tx_cust.getExpectedPrice() < KennyCoin.getPrice():
                # cust sells successfully
                tx_cust.sell(tx_tokenNum)
                # change expectedPrice, means could do transaction again
                tx_cust.changeExpectedPrice(-1)
                sellNum = sellNum + 1
                tx_list.pop(s)
                s = s - 1
        else:
            # try buy
            if tx_cust.getExpectedPrice() >= KennyCoin.getPrice():
                # cust buys successfully
                tx_cust.buy(tx_tokenNum)
                # change expectedPrice, means could do transaction again
                tx_cust.changeExpectedPrice(-1)
                buyNum = buyNum + 1
                tx_list.pop(s)
                s = s - 1
        s = s + 1

    flag = 0
    if (j > 0) and (j % bouncingInterval == 0):
        # here assume the bouncing_mu is generated by random, range is determined by bouncing range
        Price_mu = random.uniform(0.1 * CurrentPrice, bouncingRange * CurrentPrice)
        # when Price_mu < than currentPrice, every one wants to sell, else every one wants to buy
        if Price_mu < CurrentPrice:
            flag = -1 # sell
        else:
            flag = 1 # buy
    else:
        Price_mu = CurrentPrice

    custExpectedPrice = np.random.normal(Price_mu, sigma, tx_round)
    i = 0
    for t in xrange(0,custNum):
        if i >= tx_round:
            break
        if custlist[t].getExpectedPrice() >= 0:
            continue
        if custExpectedPrice[i] > 0:
            # avoid newExpectedPrice <= 0
            # in fact newExpectedPrice should not be 0, otherwise will be dead buyer
            newExpectedPrice = custExpectedPrice[i]
        else:
            newExpectedPrice = 0.00001 * KennyCoin.getPrice()

        custlist[t].changeExpectedPrice(newExpectedPrice)
        if flag == -1:
            custSmartToken_Num = custlist[t].getownedSmartTokens()
            randomSell = random.randint(0,custSmartToken_Num)            
            if custlist[t].getExpectedPrice() < KennyCoin.getPrice():
                # cust sells successfully
                custlist[t].sell(randomSell)
                # change expectedPrice, means could do transaction again
                custlist[t].changeExpectedPrice(-1)
                sellNum = sellNum + 1
            else:
                # failed in selling, add cust to tx list, -1 means to sell
                tx_list.append((-1, custlist[t],randomSell))
                # BancorMarket.addSeller(custlist[t])

        elif flag == 1:
            custReserveToken_Num = custlist[t].getReserveTokens()
            randomBuy = random.randint(0, custReserveToken_Num)
            if custlist[t].getExpectedPrice() >= KennyCoin.getPrice():
                # cust buys successfully
                custlist[t].buy(randomBuy)
                custlist[t].changeExpectedPrice(-1)
                buyNum = buyNum + 1
            else:
                # failed in buying, add cust to tx list, 1 means to buy
                tx_list.append((1, custlist[t],randomBuy))
                # BancorMarket.addBuyer(custlist[t])

        else:
            '''
            Here customers choose buy and sell operation by throwing a coin, half-half probability 
            '''
            coin = random.randint(0, 100)
            if coin < 50:
                # buy
                custReserveToken_Num = custlist[t].getReserveTokens()
                randomBuy = random.randint(0, custReserveToken_Num)
                if custlist[t].getExpectedPrice() >= KennyCoin.getPrice():
                    # cust buy successfully
                    custlist[t].buy(randomBuy)
                    # change expectedPrice for cust, means he could do transaction again
                    custlist[t].changeExpectedPrice(-1)
                    buyNum = buyNum + 1
                else:
                    # failed in buying, add cust to tx list, 1 means to buy
                    tx_list.append((1, custlist[t],randomBuy))
                    # BancorMarket.addBuyer(custlist[t])
            else:
                # sell
                custSmartToken_Num = custlist[t].getownedSmartTokens()
                randomSell = random.randint(0,custSmartToken_Num)            
                if custlist[t].getExpectedPrice() < KennyCoin.getPrice():
                    # cust sells successfully
                    custlist[t].sell(randomSell)
                    # change expectedPrice for cust, means he could do transaction again
                    custlist[t].changeExpectedPrice(-1)
                    sellNum = sellNum + 1
                else:
                    # failed in selling, add cust to tx list, -1 means to sell
                    tx_list.append((-1, custlist[t],randomSell))
                    # BancorMarket.addSeller(custlist[t])
        i = i + 1
    # here we shuffle the cust list to let all customer to get oppotunity to make transactions
    random.shuffle(custlist)
    moneyBalance_all = 0
    for Joe in custlist:
        moneyBalance_all = moneyBalance_all + Joe.getmoneyBalance()

    moneyTracker.append((moneyBalance_all,j))
    failed_rateTracker.append((len(tx_list)/float(waitingTx_Num_Old+tx_round),j))
    waitingTracker.append((len(tx_list),j))
    PriceTracker.append((KennyCoin.getPrice(),j))

    print 'The',j,'round:', buyNum, 'buy tx |', sellNum, 'sell tx |', len(tx_list), 'unfinished tx.'
    fw.write('The '+str(j)+' round: '+str(buyNum)+' buy tx | '+str(sellNum)+' sell tx | '+str(len(tx_list))+' unfinished tx.\n')
    j = j + 1

# draw failure rate
j = 0
failedRate = []
myX_FR = []
while j < TimeRound:
    myX_FR.append(j)
    failedRate.append(failed_rateTracker[j][0])
    j = j + 1
x_FR = np.asarray(myX_FR)
y_FR = np.asarray(failedRate)
plt.plot(x_FR,y_FR,'o-',color = 'navy',alpha = 0.8)
plt.title('Failure Rate Change For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Failure Rate of Transaction', fontsize = 15)
plt.savefig('Figures/Coin-FailureRate.png', bbox_inches='tight')
plt.close()

# draw waiting list change
j = 0
waitingNum = []
myX_W = []
while j < TimeRound:
    myX_W.append(j)
    waitingNum.append(waitingTracker[j][0])
    j = j + 1
x_W = np.asarray(myX_W)
y_W = np.asarray(waitingNum)
plt.plot(x_W,y_W,'o-',color = 'navy',alpha = 0.8)
plt.title('Unfinished Transactions Num For All Rounds',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Unfinished Transactions Num', fontsize = 15)
plt.savefig('Figures/Coin-WaitingNum.png', bbox_inches='tight')
plt.close()

# draw price change figure
j = 0
PriceAllRound = []
myX_P = []
while j < TimeRound:
    PriceAllRound.append(PriceTracker[j][0])
    myX_P.append(j)
    j = j + 1
x_P = np.asarray(myX_P)
y_P = np.asarray(PriceAllRound)
plt.plot(x_P, y_P, 'o-',color = 'navy', alpha = 0.8)
plt.title('Price Change For All Round',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Price of Smart Token', fontsize = 15)
plt.savefig('Figures/Coin-Price_Change.png', bbox_inches='tight')
plt.close()

# draw money change figure
j = 0
moneyChange = []
myX_M = []
while j < TimeRound:
    moneyChange.append(moneyTracker[j][0])
    myX_M.append(j)
    j = j + 1
x_M = np.asarray(myX_M)
y_M = np.asarray(moneyChange)
plt.plot(x_M, y_M, 'o-', color = 'navy', alpha = 0.8)
plt.title('Money Balance Change For All Round',fontsize = 25)
plt.xlabel('Round #',fontsize = 15)
plt.ylabel('Money Balance of All Custs', fontsize = 15)
plt.savefig('Figures/Coin-MoneyBalance_Change.png', bbox_inches='tight')
plt.close()
# Out:
# The 0 round: 29 buy tx | 20 sell tx | 51 unfinished tx.
# The 1 round: 23 buy tx | 25 sell tx | 103 unfinished tx.
# The 2 round: 23 buy tx | 32 sell tx | 148 unfinished tx.
# The 3 round: 22 buy tx | 31 sell tx | 195 unfinished tx.
# The 4 round: 21 buy tx | 22 sell tx | 252 unfinished tx.
# The 5 round: 27 buy tx | 21 sell tx | 304 unfinished tx.
# The 6 round: 20 buy tx | 24 sell tx | 360 unfinished tx.
# The 7 round: 20 buy tx | 22 sell tx | 418 unfinished tx.
# The 8 round: 26 buy tx | 20 sell tx | 472 unfinished tx.
# The 9 round: 26 buy tx | 19 sell tx | 527 unfinished tx.
# The 10 round: 28 buy tx | 27 sell tx | 572 unfinished tx.
# The 11 round: 24 buy tx | 14 sell tx | 634 unfinished tx.
# The 12 round: 33 buy tx | 25 sell tx | 676 unfinished tx.
# The 13 round: 22 buy tx | 24 sell tx | 730 unfinished tx.
# The 14 round: 27 buy tx | 27 sell tx | 776 unfinished tx.
# The 15 round: 19 buy tx | 16 sell tx | 841 unfinished tx.
# The 16 round: 27 buy tx | 26 sell tx | 888 unfinished tx.
# The 17 round: 24 buy tx | 24 sell tx | 940 unfinished tx.
# The 18 round: 15 buy tx | 33 sell tx | 992 unfinished tx.
# The 19 round: 30 buy tx | 22 sell tx | 1040 unfinished tx.
# The 20 round: 29 buy tx | 25 sell tx | 1086 unfinished tx.
# The 21 round: 26 buy tx | 31 sell tx | 1129 unfinished tx.
# The 22 round: 25 buy tx | 20 sell tx | 1184 unfinished tx.
# The 23 round: 28 buy tx | 30 sell tx | 1226 unfinished tx.
# The 24 round: 23 buy tx | 21 sell tx | 1282 unfinished tx.
# The 25 round: 30 buy tx | 27 sell tx | 1325 unfinished tx.
# The 26 round: 34 buy tx | 28 sell tx | 1363 unfinished tx.
# The 27 round: 21 buy tx | 27 sell tx | 1415 unfinished tx.
# The 28 round: 25 buy tx | 28 sell tx | 1462 unfinished tx.
# The 29 round: 18 buy tx | 37 sell tx | 1507 unfinished tx.
# The 30 round: 38 buy tx | 17 sell tx | 1552 unfinished tx.
# The 31 round: 21 buy tx | 24 sell tx | 1607 unfinished tx.
# The 32 round: 24 buy tx | 31 sell tx | 1652 unfinished tx.
# The 33 round: 16 buy tx | 36 sell tx | 1700 unfinished tx.
# The 34 round: 16 buy tx | 29 sell tx | 1755 unfinished tx.
# The 35 round: 30 buy tx | 23 sell tx | 1802 unfinished tx.
# The 36 round: 28 buy tx | 25 sell tx | 1849 unfinished tx.
# The 37 round: 32 buy tx | 31 sell tx | 1886 unfinished tx.
# The 38 round: 25 buy tx | 21 sell tx | 1940 unfinished tx.
# The 39 round: 21 buy tx | 29 sell tx | 1990 unfinished tx.
# The 40 round: 27 buy tx | 27 sell tx | 2036 unfinished tx.
# The 41 round: 22 buy tx | 26 sell tx | 2088 unfinished tx.
# The 42 round: 27 buy tx | 19 sell tx | 2142 unfinished tx.
# The 43 round: 24 buy tx | 18 sell tx | 2200 unfinished tx.
# The 44 round: 25 buy tx | 22 sell tx | 2253 unfinished tx.
# The 45 round: 22 buy tx | 22 sell tx | 2309 unfinished tx.
# The 46 round: 14 buy tx | 30 sell tx | 2365 unfinished tx.
# The 47 round: 25 buy tx | 30 sell tx | 2410 unfinished tx.
# The 48 round: 32 buy tx | 16 sell tx | 2462 unfinished tx.
# The 49 round: 21 buy tx | 21 sell tx | 2520 unfinished tx.
# The 50 round: 100 buy tx | 0 sell tx | 2520 unfinished tx.
# The 51 round: 27 buy tx | 89 sell tx | 2504 unfinished tx.
# The 52 round: 18 buy tx | 27 sell tx | 2559 unfinished tx.
# The 53 round: 24 buy tx | 26 sell tx | 2609 unfinished tx.
# The 54 round: 23 buy tx | 31 sell tx | 2655 unfinished tx.
# The 55 round: 33 buy tx | 28 sell tx | 2694 unfinished tx.
# The 56 round: 32 buy tx | 29 sell tx | 2733 unfinished tx.
# The 57 round: 20 buy tx | 22 sell tx | 2791 unfinished tx.
# The 58 round: 27 buy tx | 24 sell tx | 2840 unfinished tx.
# The 59 round: 30 buy tx | 24 sell tx | 2886 unfinished tx.
# The 60 round: 23 buy tx | 29 sell tx | 2934 unfinished tx.
# The 61 round: 20 buy tx | 33 sell tx | 2981 unfinished tx.
# The 62 round: 24 buy tx | 32 sell tx | 3025 unfinished tx.
# The 63 round: 26 buy tx | 23 sell tx | 3076 unfinished tx.
# The 64 round: 25 buy tx | 22 sell tx | 3129 unfinished tx.
# The 65 round: 28 buy tx | 27 sell tx | 3174 unfinished tx.
# The 66 round: 31 buy tx | 21 sell tx | 3222 unfinished tx.
# The 67 round: 21 buy tx | 26 sell tx | 3275 unfinished tx.
# The 68 round: 26 buy tx | 23 sell tx | 3326 unfinished tx.
# The 69 round: 24 buy tx | 26 sell tx | 3376 unfinished tx.
# The 70 round: 20 buy tx | 19 sell tx | 3437 unfinished tx.
# The 71 round: 25 buy tx | 26 sell tx | 3486 unfinished tx.
# The 72 round: 28 buy tx | 26 sell tx | 3532 unfinished tx.
# The 73 round: 26 buy tx | 23 sell tx | 3583 unfinished tx.
# The 74 round: 25 buy tx | 19 sell tx | 3639 unfinished tx.
# The 75 round: 21 buy tx | 29 sell tx | 3689 unfinished tx.
# The 76 round: 33 buy tx | 23 sell tx | 3733 unfinished tx.
# The 77 round: 25 buy tx | 22 sell tx | 3786 unfinished tx.
# The 78 round: 28 buy tx | 21 sell tx | 3837 unfinished tx.
# The 79 round: 25 buy tx | 29 sell tx | 3883 unfinished tx.
# The 80 round: 31 buy tx | 26 sell tx | 3926 unfinished tx.
# The 81 round: 26 buy tx | 31 sell tx | 3969 unfinished tx.
# The 82 round: 20 buy tx | 29 sell tx | 4020 unfinished tx.
# The 83 round: 24 buy tx | 27 sell tx | 4069 unfinished tx.
# The 84 round: 24 buy tx | 30 sell tx | 4115 unfinished tx.
# The 85 round: 22 buy tx | 20 sell tx | 4173 unfinished tx.
# The 86 round: 27 buy tx | 24 sell tx | 4222 unfinished tx.
# The 87 round: 25 buy tx | 23 sell tx | 4274 unfinished tx.
# The 88 round: 27 buy tx | 27 sell tx | 4320 unfinished tx.
# The 89 round: 34 buy tx | 27 sell tx | 4359 unfinished tx.
# The 90 round: 24 buy tx | 32 sell tx | 4403 unfinished tx.
# The 91 round: 23 buy tx | 23 sell tx | 4457 unfinished tx.
# The 92 round: 30 buy tx | 26 sell tx | 4501 unfinished tx.
# The 93 round: 27 buy tx | 30 sell tx | 4544 unfinished tx.
# The 94 round: 23 buy tx | 24 sell tx | 4597 unfinished tx.
# The 95 round: 26 buy tx | 26 sell tx | 4645 unfinished tx.
# The 96 round: 23 buy tx | 24 sell tx | 4698 unfinished tx.
# The 97 round: 22 buy tx | 24 sell tx | 4752 unfinished tx.
# The 98 round: 29 buy tx | 20 sell tx | 4803 unfinished tx.
# The 99 round: 22 buy tx | 33 sell tx | 4848 unfinished tx.
# The 100 round: 14 buy tx | 100 sell tx | 4834 unfinished tx.
# The 101 round: 123 buy tx | 24 sell tx | 4787 unfinished tx.
# The 102 round: 24 buy tx | 22 sell tx | 4841 unfinished tx.
# The 103 round: 26 buy tx | 28 sell tx | 4887 unfinished tx.
# The 104 round: 27 buy tx | 27 sell tx | 4933 unfinished tx.
# The 105 round: 15 buy tx | 20 sell tx | 4965 unfinished tx.
# The 106 round: 7 buy tx | 7 sell tx | 4986 unfinished tx.
# The 107 round: 5 buy tx | 3 sell tx | 4992 unfinished tx.
# The 108 round: 2 buy tx | 3 sell tx | 4995 unfinished tx.
# The 109 round: 2 buy tx | 2 sell tx | 4997 unfinished tx.
# The 110 round: 1 buy tx | 1 sell tx | 4998 unfinished tx.
# The 111 round: 0 buy tx | 1 sell tx | 5000 unfinished tx.
# The 112 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 113 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 114 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 115 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 116 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 117 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 118 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 119 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 120 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 121 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 122 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 123 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 124 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 125 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 126 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 127 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 128 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 129 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 130 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 131 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 132 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 133 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 134 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 135 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 136 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 137 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 138 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 139 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 140 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 141 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 142 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 143 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 144 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 145 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 146 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 147 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 148 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 149 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 150 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 151 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 152 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 153 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 154 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 155 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 156 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 157 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 158 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 159 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 160 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 161 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 162 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 163 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 164 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 165 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 166 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 167 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 168 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 169 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 170 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 171 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 172 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 173 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 174 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 175 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 176 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 177 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 178 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 179 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 180 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 181 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 182 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 183 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 184 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 185 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 186 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 187 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 188 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 189 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 190 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 191 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 192 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 193 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 194 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 195 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 196 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 197 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 198 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 199 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 200 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 201 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 202 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 203 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 204 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 205 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 206 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 207 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 208 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 209 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 210 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 211 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 212 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 213 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 214 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 215 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 216 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 217 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 218 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 219 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 220 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 221 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 222 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 223 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 224 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 225 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 226 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 227 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 228 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 229 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 230 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 231 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 232 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 233 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 234 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 235 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 236 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 237 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 238 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 239 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 240 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 241 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 242 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 243 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 244 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 245 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 246 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 247 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 248 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 249 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 250 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 251 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 252 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 253 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 254 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 255 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 256 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 257 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 258 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 259 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 260 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 261 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 262 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 263 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 264 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 265 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 266 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 267 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 268 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 269 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 270 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 271 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 272 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 273 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 274 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 275 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 276 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 277 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 278 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 279 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 280 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 281 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 282 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 283 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 284 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 285 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 286 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 287 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 288 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 289 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 290 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 291 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 292 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 293 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 294 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 295 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 296 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 297 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 298 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 299 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 300 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 301 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 302 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 303 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 304 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 305 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 306 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 307 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 308 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 309 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 310 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 311 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 312 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 313 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 314 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 315 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 316 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 317 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 318 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 319 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 320 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 321 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 322 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 323 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 324 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 325 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 326 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 327 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 328 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 329 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 330 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 331 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 332 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 333 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 334 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 335 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 336 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 337 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 338 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 339 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 340 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 341 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 342 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 343 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 344 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 345 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 346 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 347 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 348 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 349 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 350 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 351 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 352 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 353 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 354 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 355 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 356 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 357 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 358 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 359 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 360 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 361 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 362 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 363 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 364 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 365 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 366 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 367 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 368 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 369 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 370 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 371 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 372 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 373 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 374 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 375 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 376 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 377 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 378 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 379 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 380 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 381 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 382 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 383 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 384 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 385 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 386 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 387 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 388 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 389 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 390 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 391 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 392 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 393 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 394 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 395 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 396 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 397 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 398 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 399 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 400 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 401 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 402 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 403 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 404 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 405 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 406 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 407 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 408 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 409 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 410 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 411 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 412 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 413 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 414 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 415 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 416 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 417 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 418 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 419 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 420 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 421 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 422 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 423 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 424 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 425 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 426 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 427 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 428 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 429 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 430 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 431 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 432 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 433 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 434 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 435 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 436 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 437 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 438 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 439 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 440 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 441 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 442 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 443 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 444 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 445 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 446 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 447 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 448 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 449 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 450 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 451 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 452 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 453 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 454 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 455 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 456 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 457 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 458 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 459 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 460 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 461 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 462 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 463 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 464 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 465 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 466 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 467 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 468 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 469 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 470 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 471 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 472 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 473 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 474 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 475 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 476 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 477 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 478 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 479 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 480 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 481 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 482 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 483 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 484 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 485 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 486 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 487 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 488 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 489 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 490 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 491 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 492 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 493 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 494 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 495 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 496 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 497 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 498 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 499 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 500 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 501 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 502 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 503 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 504 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 505 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 506 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 507 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 508 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 509 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 510 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 511 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 512 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 513 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 514 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 515 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 516 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 517 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 518 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 519 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 520 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 521 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 522 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 523 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 524 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 525 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 526 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 527 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 528 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 529 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 530 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 531 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 532 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 533 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 534 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 535 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 536 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 537 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 538 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 539 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 540 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 541 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 542 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 543 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 544 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 545 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 546 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 547 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 548 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 549 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 550 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 551 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 552 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 553 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 554 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 555 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 556 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 557 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 558 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 559 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 560 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 561 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 562 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 563 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 564 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 565 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 566 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 567 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 568 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 569 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 570 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 571 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 572 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 573 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 574 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 575 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 576 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 577 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 578 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 579 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 580 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 581 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 582 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 583 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 584 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 585 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 586 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 587 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 588 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 589 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 590 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 591 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 592 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 593 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 594 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 595 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 596 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 597 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 598 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 599 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 600 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 601 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 602 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 603 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 604 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 605 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 606 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 607 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 608 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 609 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 610 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 611 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 612 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 613 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 614 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 615 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 616 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 617 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 618 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 619 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 620 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 621 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 622 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 623 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 624 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 625 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 626 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 627 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 628 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 629 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 630 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 631 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 632 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 633 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 634 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 635 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 636 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 637 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 638 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 639 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 640 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 641 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 642 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 643 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 644 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 645 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 646 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 647 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 648 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 649 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 650 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 651 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 652 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 653 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 654 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 655 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 656 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 657 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 658 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 659 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 660 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 661 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 662 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 663 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 664 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 665 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 666 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 667 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 668 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 669 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 670 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 671 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 672 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 673 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 674 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 675 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 676 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 677 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 678 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 679 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 680 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 681 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 682 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 683 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 684 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 685 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 686 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 687 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 688 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 689 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 690 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 691 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 692 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 693 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 694 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 695 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 696 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 697 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 698 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 699 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 700 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 701 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 702 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 703 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 704 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 705 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 706 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 707 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 708 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 709 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 710 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 711 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 712 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 713 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 714 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 715 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 716 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 717 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 718 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 719 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 720 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 721 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 722 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 723 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 724 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 725 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 726 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 727 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 728 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 729 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 730 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 731 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 732 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 733 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 734 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 735 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 736 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 737 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 738 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 739 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 740 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 741 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 742 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 743 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 744 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 745 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 746 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 747 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 748 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 749 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 750 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 751 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 752 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 753 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 754 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 755 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 756 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 757 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 758 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 759 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 760 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 761 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 762 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 763 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 764 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 765 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 766 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 767 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 768 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 769 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 770 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 771 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 772 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 773 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 774 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 775 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 776 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 777 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 778 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 779 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 780 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 781 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 782 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 783 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 784 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 785 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 786 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 787 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 788 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 789 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 790 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 791 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 792 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 793 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 794 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 795 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 796 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 797 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 798 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 799 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 800 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 801 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 802 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 803 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 804 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 805 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 806 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 807 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 808 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 809 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 810 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 811 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 812 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 813 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 814 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 815 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 816 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 817 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 818 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 819 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 820 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 821 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 822 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 823 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 824 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 825 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 826 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 827 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 828 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 829 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 830 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 831 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 832 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 833 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 834 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 835 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 836 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 837 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 838 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 839 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 840 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 841 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 842 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 843 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 844 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 845 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 846 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 847 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 848 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 849 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 850 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 851 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 852 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 853 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 854 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 855 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 856 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 857 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 858 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 859 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 860 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 861 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 862 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 863 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 864 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 865 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 866 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 867 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 868 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 869 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 870 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 871 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 872 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 873 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 874 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 875 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 876 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 877 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 878 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 879 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 880 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 881 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 882 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 883 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 884 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 885 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 886 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 887 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 888 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 889 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 890 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 891 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 892 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 893 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 894 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 895 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 896 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 897 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 898 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 899 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 900 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 901 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 902 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 903 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 904 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 905 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 906 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 907 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 908 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 909 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 910 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 911 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 912 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 913 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 914 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 915 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 916 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 917 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 918 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 919 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 920 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 921 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 922 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 923 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 924 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 925 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 926 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 927 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 928 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 929 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 930 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 931 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 932 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 933 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 934 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 935 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 936 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 937 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 938 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 939 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 940 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 941 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 942 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 943 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 944 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 945 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 946 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 947 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 948 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 949 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 950 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 951 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 952 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 953 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 954 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 955 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 956 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 957 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 958 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 959 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 960 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 961 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 962 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 963 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 964 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 965 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 966 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 967 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 968 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 969 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 970 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 971 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 972 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 973 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 974 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 975 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 976 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 977 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 978 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 979 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 980 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 981 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 982 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 983 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 984 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 985 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 986 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 987 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 988 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 989 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 990 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 991 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 992 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 993 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 994 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 995 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 996 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 997 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 998 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.
# The 999 round: 0 buy tx | 0 sell tx | 5000 unfinished tx.

# %%
# example of using smartcoin class
BNTCoin = Smartcoin(name='BNT',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=300000)
print BNTCoin.destroying(10)
BNTCoin.printInfo()
# print BNTCoin.purchasing(300)
# print BNTCoin.purchasing(700)
# BNTCoin.printInfo()
print BNTCoin.destroying(177)
BNTCoin.printInfo()
# Out:
# 10
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 0.999866662222
# SUPPLY: 299990.0 | RESERVE BALANCE: 59990.0
# 177
# ---------
# NAME: BNT | RESERVE NAME: ETH CRR: 0.2
# PRICE: 0.99750511152
# SUPPLY: 299813.0 | RESERVE BALANCE: 59813.0

# %%
KennyCoin = Smartcoin(name='Kenny',reservetokenName='ETH',initCRR=0.2, initPrice=1,initIssueNum=300000)
# test for customers class
Alice = Customers(smartToken=KennyCoin,ownedSmartTokens=100,reserveTokens=100,expectedPrice= 2)
Alice.printinfo()
Alice.buy(-1)
Alice.printinfo()
Alice.printinfo()
# Out:
# ------
# smartToken Name: Kenny | expected price: 2.0
# ownedvalue: 200.0 | money Balance: 0.0
# ** ERROR, cannot buy negative number of smartToken
# ------
# smartToken Name: Kenny | expected price: 2.0
# ownedvalue: 200.0 | money Balance: 0.0
# ------
# smartToken Name: Kenny | expected price: 2.0
# ownedvalue: 200.0 | money Balance: 0.0
